# %% [markdown]
# # BIKE DEMAND VISUALIZATION CAPSTONE PROJECT

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from pandas.plotting import register_matplotlib_converters
from pylab import rcParams
sns.set_style("darkgrid")

# import lux

import warnings
warnings.filterwarnings("ignore")

# Set it None to display all rows in the dataframe
# pd.set_option('display.max_rows', None)

# Set it to None to display all columns in the dataframe
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Task 01. Reading the dataset

# %% [markdown]
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">ABOUT THE FEATURES</p>
#
# <a id="00"></a>
# <a href="#toc" class="btn btn-primary btn-sm" role="button" aria-pressed="true"
# style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# **- ``timestamp``** - timestamp field for grouping the data<br>
# **- ``cnt``** - the count of a new bike shares<br>
# **- ``t1``** - real temperature in C<br>
# **- ``t2``** - temperature in C “feels like”<br>
# **- ``hum``** - humidity in percentage<br>
# **- ``wind_speed``** - wind speed in km/h<br>
# **- ``weather_code``** - category of the weather<br>
# **- ``is_holiday``** - boolean field - 1 holiday / 0 non holiday<br>
# **- ``is_weekend``** - boolean field - 1 if the day is weekend<br>
# **- ``season``** - category field meteorological seasons: 0-spring ; 1-summer; 2-fall; 3-winter.<br>
#
# **"weather_code" category description:**<br>
# **``1``** = Clear ; mostly clear but have some values with haze/fog/patches of fog/ fog in vicinity<br>
# **``2``** = scattered clouds / few clouds<br>
# **``3``** = Broken clouds<br>
# **``4``** = Cloudy<br>
# **``7``** = Rain/ light Rain shower/ Light rain<br>
# **``10``** = rain with thunderstorm<br>
# **``26``** = snowfall<br>
# **``94``** = Freezing Fog<br>

# %%
df0 = pd.read_csv("store_sharing.csv")
df = df0.copy()
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# ...

# %% [markdown]
# # Task 02.** Check missing values and if there are any dublicate rows or not.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
df.isnull().value_counts()
# Out:
# timestamp  cnt    t1     t2     hum    wind_speed  weather_code  is_holiday  is_weekend  season
# False      False  False  False  False  False       False         False       False       False     17414
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    17414
# dtype: int64

# %% [markdown]
# # Task 03.** Plotting the distribution of various discrete features on (Season, holiday, weekend and weathercode)

# %%
df.describe()
# Out:
#                 cnt            t1            t2           hum    wind_speed  \
# count  17414.000000  17414.000000  17414.000000  17414.000000  17414.000000
# mean    1143.101642     12.468091     11.520836     72.324954     15.913063
# std     1085.108068      5.571818      6.615145     14.313186      7.894570
# min        0.000000     -1.500000     -6.000000     20.500000      0.000000
# 25%      257.000000      8.000000      6.000000     63.000000     10.000000
# 50%      844.000000     12.500000     12.500000     74.500000     15.000000
# 75%     1671.750000     16.000000     16.000000     83.000000     20.500000
# max     7860.000000     34.000000     34.000000    100.000000     56.500000
#
#        weather_code    is_holiday    is_weekend        season
# count  17414.000000  17414.000000  17414.000000  17414.000000
# mean       2.722752      0.022051      0.285403      1.492075
# std        2.341163      0.146854      0.451619      1.118911
# ...

# %%
sns.boxplot(data=df, y="cnt", x="is_holiday")
# Out:
# <AxesSubplot:xlabel='is_holiday', ylabel='cnt'>

# %%
fig, ax = plt.subplots()

sns.countplot(x="season", data=df)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.3, p.get_height()+20))

# %%
fig, ax = plt.subplots()

sns.countplot(x="is_weekend", data=df)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.3, p.get_height()+20))

# %%
fig, ax = plt.subplots()

sns.countplot(x="weather_code", data=df)

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.15, p.get_height()+20))

# %% [markdown]
# # Task 4 Looking at the data type of each variable, transform timestamp in type, and set it as index.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
type(df["timestamp"])
# Out:
# pandas.core.series.Series

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %% [markdown]
#  # Task 05.** Making feature engineering. Extract new columns (day of the week, day of the month, hour, month, season, year etc.)

# %%
df["day"]= df.timestamp.dt.day_name()

# %%
df["day_int"]= df.timestamp.dt.day

# %%
df["month"]= df.timestamp.dt.month_name()

# %%
df["year"]= df.timestamp.dt.year

# %%
df["hour"] = df.timestamp.dt.hour

# %%
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
# ...

# %% [markdown]
#  # Task 06.** Visualizing the correlation with a heatmap

# %%
df.corr()
# Out:
#                    cnt        t1        t2       hum  wind_speed  \
# cnt           1.000000  0.388798  0.369035 -0.462901    0.116295
# t1            0.388798  1.000000  0.988344 -0.447781    0.145471
# t2            0.369035  0.988344  1.000000 -0.403495    0.088409
# hum          -0.462901 -0.447781 -0.403495  1.000000   -0.287789
# wind_speed    0.116295  0.145471  0.088409 -0.287789    1.000000
# weather_code -0.166633 -0.097114 -0.098385  0.334750    0.124803
# is_holiday   -0.051698 -0.042233 -0.040051  0.032068   -0.002606
# is_weekend   -0.096499 -0.005342 -0.008510  0.028098    0.011479
# season       -0.116180 -0.285851 -0.285900  0.290381    0.010305
# year          0.010046 -0.037959 -0.044972  0.072443   -0.094739
# hour          0.324423  0.168708  0.153956 -0.295653    0.141792
#
#               weather_code  is_holiday  is_weekend    season      year  \
# cnt              -0.166633   -0.051698   -0.096499 -0.116180  0.010046
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm");

# %% [markdown]
# # Task 07. Visualizing the correlation of the target variable and the other features with barplot

# %%
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season      day    month  year  hour
# ...

# %%
plt.figure(figsize=(8,5))
df.corr()["cnt"].sort_values().plot.barh()
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,5))
df.corr()["cnt"].sort_values().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Task 8 PLOTTING BIKE SHARES OVER TIME BY USING LINEPLOT

# %%
plt.figure(figsize=(13,8))
sns.lineplot(data=df, y="cnt", x="timestamp", hue="season")
# Out:
# <AxesSubplot:xlabel='timestamp', ylabel='cnt'>

# %% [markdown]
# # TASK 09 - PLOTTING BIKE SHARES BY MONTHS & YEAR_OF_MONTH (USE LINEPLOT, POINTPOT, BARPLOT)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, y="cnt", x="month")
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %%
plt.figure(figsize=(10,5))
sns.pointplot(data=df, y="cnt", x="month")
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, y="cnt", x="month")
# Out:
# <AxesSubplot:xlabel='month', ylabel='cnt'>

# %% [markdown]
# # TASK 10 - PLOTTING BIKE SHARES BY HOURS ON (HOLIDAYS, WEEKEND, SEASON)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df, y="cnt", x="hour")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, y="cnt", x="hour")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, y="cnt", x="hour", hue="season")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, y="cnt", x="hour", hue="is_holiday")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, y="cnt", x="hour", hue="is_weekend")
# Out:
# <AxesSubplot:xlabel='hour', ylabel='cnt'>

# %% [markdown]
# # TASK 11 - PLOTTING BIKE SHARES BY DAY OF WEEK

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df, y="cnt", x="day")
# Out:
# <AxesSubplot:xlabel='day', ylabel='cnt'>

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.barplot(x="day",y="cnt", data=df)
# Out:
# <AxesSubplot:xlabel='day', ylabel='cnt'>

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.barplot(x="day",y="cnt", data=df, hue="is_weekend");
# Out:
# <AxesSubplot:xlabel='day', ylabel='cnt'>

# %% [markdown]
# # TASK 12 - PLOTTING BIKE SHARES BY DAY OF MONTH

# %%
plt.figure(figsize=(17,5))
sns.lineplot(data=df, y="cnt", x="day_int");
# Out:
# <AxesSubplot:xlabel='day_int', ylabel='cnt'>

# %%
plt.figure(figsize=(17,5))
sns.lineplot(data=df, y="cnt", x="day_int", hue="is_weekend");

# %% [markdown]
# # TASK 13 - PLOTTING BIKE SHARES BY YEAR & PLOTTING BIKE SHARES ON HOLIDAYS BY SEASON

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.barplot(x="year",y="cnt", data=df, hue="season");

# %%
fig, ax = plt.subplots(figsize=(10,5))

sns.countplot(x="year", data=df, hue="is_holiday")

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.15, p.get_height()+20))

# %%
df.groupby("is_holiday").count()
# Out:
#             timestamp    cnt     t1     t2    hum  wind_speed  weather_code  \
# is_holiday
# 0.0             17030  17030  17030  17030  17030       17030         17030
# 1.0               384    384    384    384    384         384           384
#
#             is_weekend  season    day  month   year   hour
# is_holiday
# 0.0              17030   17030  17030  17030  17030  17030
# 1.0                384     384    384    384    384    384

# %%
df.groupby

# %%
fig, ax = plt.subplots(figsize=(13,6))

sns.countplot(x="year", data=df, hue="season")

for p in ax.patches:
    ax.annotate((p.get_height()),(p.get_x()+0.015, p.get_height()+20))

# %% [markdown]
# # TASK 14 - VISUALIZING THE DISTRIBUTION OF BIKE SHARES BY WEEKDAY-WEEKEND WITH USING PIECHART & BARPLOT

# %%
# tips.groupby("day").sum().plot.pie(subplots=True, figsize=(18, 5), autopct="%.2f", labeldistance=0.8)

df[["cnt", "is_weekend"]].groupby("is_weekend").sum().plot.pie(subplots=True, figsize=(18, 5), autopct="%.2f", labeldistance=0.8)
plt.legend()
plt.show()

# %%
df["holiday"] = df["is_weekend"].apply(lambda x: "holiday" if x == 1 else "workday")

# %%
df[["cnt", "holiday"]].groupby("holiday").sum().plot.pie(explode = (0, 0.1),subplots=True, 
                                                         figsize=(18, 5), autopct="%.2f", labeldistance=0.8)
plt.legend()
plt.show()
