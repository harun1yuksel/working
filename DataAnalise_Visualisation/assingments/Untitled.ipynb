# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sales_082020.csv')
df2 = pd.read_csv("currency_rates_082020_EUR.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237671 entries, 0 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   buyer_id        237671 non-null  object
#  1   buyer_country   237671 non-null  object
#  2   seller_id       237671 non-null  object
#  3   seller_country  237671 non-null  object
#  4   product_code    237671 non-null  object
#  5   category        237655 non-null  object
#  6   brand           119330 non-null  object
#  7   currency        237671 non-null  object
#  8   price           237671 non-null  float64
#  9   date            237671 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 18.1+ MB

# %%
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
df.describe()
# Out:
#                price
# count  237671.000000
# mean       28.357384
# std        92.895281
# min         0.010000
# 25%        11.270000
# 50%        18.480000
# 75%        31.180000
# max     36919.180000

# %%
df.seller_id.nunique()
# Out:
# 114227

# %%
df.nunique()
# Out:
# buyer_id          139700
# buyer_country          9
# seller_id         114227
# seller_country         9
# product_code      226311
# category              24
# brand               1134
# currency              22
# price              15336
# date                   7
# dtype: int64

# %%
df.sample(30)
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 188799  49hz9tbikw            US  ot8qb91y             US  wa5bacnybgxu
# 172048  1l9wyhu2yy            GB  knzh4emw             GB  o66y363fjo34
# 63080   z2uagfez4l            GB  3m4cb0hy             GB  yrffghn0ufvm
# 44524   qwx2pkxk8z            US  jtg7xfza             US  xig0yjkmqks4
# 44770   a8nyrd3vvr            GB  ybjxxk84             GB  jxvdssbzpzqp
# 17598   2yriyb4gle            US  bsenraly             US  hqjg8dkf3ne3
# 41495   j7weqazj1q            US  ch0qod43             US  96l8z874q8o0
# 98235   04g57jw303            GB  3ndsxoqe             GB  vsie5shy7e4c
# 215195  6rilu5trwq            AU  cigu8lbo             AU  r3wvn2rzijld
# 188143  e8ef7cu4ya            US  48nrgh3w             US  dvq8233l49mc
# 10516   u99429pzaa            IE  h4v2qiv1             GB  f11vcobp4p2z
# 12137   ylrtzj59ek            GB  0crwo20e             GB  4fn0q7lec4q8
# ...

# %%
df.groupby("brand").max("price").sort_values(by="price", ascending=False)
# Out:
#                    price
# brand
# Louis Vuitton    1287.08
# Chanel           1184.22
# Jordan           1112.99
# Acne Studios     1034.92
# Givenchy         1030.20
# ...                  ...
# Tiger of Sweden     5.50
# Kevyn Aucoin        5.44
# Popular Sports      5.26
# 360 Cashmere        1.15
# 36572               1.12
#
# [1134 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['buyer_id', 'buyer_country', 'seller_id', 'seller_country',
#        'product_code', 'category', 'brand', 'currency', 'price', 'date'],
#       dtype='object')

# %%
df.groupby("category").describe()
# Out:
#                      price                                                \
#                      count       mean         std   min      25%     50%
# category
# Accessories        21153.0  34.254349  115.873514  1.05   9.9600  16.640
# Art                 1777.0  19.092718   71.648583  1.05   3.4500   8.820
# Beauty              8746.0  16.304477   18.136557  0.01   6.8900  12.040
# Books & magazines   1081.0  14.199130   21.885747  1.05   5.7000  10.520
# Bottoms - Mens      5763.0  31.065679   34.033147  1.05  15.9050  22.800
# Bottoms - Womens   30001.0  23.209290   18.758262  1.05  12.4100  18.440
# Dresses            19238.0  27.387409   62.841437  1.05  13.4400  20.175
# Film                 466.0  32.707618   46.582596  1.05   7.3600  15.980
# Home                3477.0  22.160923   27.494821  1.05  10.5700  14.480
# Jewellery          14923.0  15.686624   24.487313  1.05   5.5600  10.330
# Kids                2135.0  17.115082   18.601452  1.05   7.4600  11.760
# ...

# %%
df.loc[(df["category"] == "Jewellery")][["brand"]].value_counts(dropna=False)
# Out:
# brand
# NaN                  13525
# PANDORA                493
# Brandy Melville        190
# Vivienne Westwood       94
# Unbranded               56
#                      ...
# Karen Millen             1
# JW Anderson              1
# A.P.C.                   1
# Céline                   1
# Hublot                   1
# Length: 83, dtype: int64

# %%
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
df[(df["category"] == "Shoes")]
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 90      00o20yp92h            GB  wx6eh9y6             GB  cpoydpxkpb1v
# 105     68b6pm3g9o            GB  it8zg6ad             GB  m78mo3yg6pke
# 108     9cpim1easn            GB  nuzwv3rq             GB  z2fsqm6vqm8h
# 109     9cpim1easn            GB  nuzwv3rq             GB  geg4rsikwbcu
# 110     ainix8217a            GB  nuzwv3rq             GB  wsnhrhlm86j6
# ...            ...           ...       ...            ...           ...
# 237652  tgennawdzs            US  2z0tgg71             US  gywe3zpzond3
# 237656  qbtdzd37kh            GB  ta47is8q             GB  vvf5b2i0rs2p
# 237660  f9jbvr90xu            US  quu0ky19             US  50vyfd46inih
# 237663  jji9og2wj0            US  w8g31gsr             US  gjwpt7hxl03u
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
#
#        category             brand currency   price        date
# ...

# %%
df[(df["category"] == "Shoes")].groupby(by="buyer_country").count()
# Out:
#                buyer_id  seller_id  seller_country  product_code  category  \
# buyer_country
# AU                  658        658             658           658       658
# CA                  115        115             115           115       115
# DE                   31         31              31            31        31
# FR                   44         44              44            44        44
# GB                13585      13585           13585         13585     13585
# IE                  315        315             315           315       315
# IT                  329        329             329           329       329
# RoW                 296        296             296           296       296
# US                 6391       6391            6391          6391      6391
#
#                brand  currency  price   date
# buyer_country
# AU                81       658    658    658
# CA                30       115    115    115
# DE                20        31     31     31
# ...

# %%
df[(df["category"] == "Jewellery")][["brand"]].nunique()
# Out:
# brand    82
# dtype: int64

# %%
df[(df["category"] == "Jewellery")][["brand"]].count()
# Out:
# brand    1398
# dtype: int64

# %%
df[(df["category"] == "Jewellery")][["brand"]].sample(50)
# Out:
#                     brand
# 11971                 NaN
# 35728                 NaN
# 12113                 NaN
# 140985              Guess
# 176150                NaN
# 49636                 NaN
# 55685                 NaN
# 163891            PANDORA
# 195296                NaN
# 9537                  NaN
# 40453                 NaN
# 154909               Dior
# 143617                NaN
# 20363                 NaN
# 62285                 NaN
# 9494                  NaN
# 123752                NaN
# 167465                NaN
# 120225                NaN
# 96727                 NaN
# 27745                 NaN
# 182413                NaN
# 59881                 NaN
# 68006             PANDORA
# 5943                  NaN
# 139311                NaN
# 23896                 NaN
# 92669                 NaN
# 194943                NaN
# 144969              Gucci
# 59625                 NaN
# 196466           Madewell
# 194491                NaN
# 136381  Vivienne Westwood
# ...

# %%
df[(df["category"] == "Jewellery")][["brand"]].sort_values(by="brand")
# Out:
#                   brand
# 136506  & Other Stories
# 136505  & Other Stories
# 136504  & Other Stories
# 136503  & Other Stories
# 108260  & Other Stories
# ...                 ...
# 237545              NaN
# 237568              NaN
# 237569              NaN
# 237616              NaN
# 237643              NaN
#
# [14923 rows x 1 columns]

# %%
df2
# Out:
#     currency       date    rate
# 0        EUR   8/1/2020  1.0000
# 1        EUR   8/2/2020  1.0000
# 2        EUR   8/3/2020  1.0000
# 3        EUR   8/4/2020  1.0000
# 4        EUR   8/5/2020  1.0000
# ..       ...        ...     ...
# 215      BRL   8/6/2020  6.3324
# 216      BRL   8/7/2020  6.4111
# 217      BRL   8/8/2020  6.4111
# 218      BRL   8/9/2020  6.4111
# 219      BRL  8/10/2020  6.4351
#
# [220 rows x 3 columns]

# %%
df[(df["buyer_country"] == "GB")]["price"].sum()
# Out:
# 3252484.65

# %%
df[(df["seller_country"] == "US")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82111 entries, 23 to 237670
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   buyer_id        82111 non-null  object
#  1   buyer_country   82111 non-null  object
#  2   seller_id       82111 non-null  object
#  3   seller_country  82111 non-null  object
#  4   product_code    82111 non-null  object
#  5   category        82105 non-null  object
#  6   brand           38743 non-null  object
#  7   currency        82111 non-null  object
#  8   price           82111 non-null  float64
#  9   date            82111 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 6.9+ MB

# %%
df[(df["seller_country"] == "US") & (df["buyer_country"] == "US")].
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 23      94lh9gu3bu            US  dhsa2q6o             US  1m846u2l2dyl
# 24      fmdcxftbp1            US  dhsa2q6o             US  9xo46id3ggkm
# 79      nk167akpfw            US  zhu1ajrz             US  431v9gn7ouiw
# 80      nk167akpfw            US  zhu1ajrz             US  36o939nzswpa
# 81      nk167akpfw            US  zhu1ajrz             US  8mli531pzaba
# ...            ...           ...       ...            ...           ...
# 237660  f9jbvr90xu            US  quu0ky19             US  50vyfd46inih
# 237662  say6ah2869            US  2jwn7shh             US  dfo3ztaga4de
# 237663  jji9og2wj0            US  w8g31gsr             US  gjwpt7hxl03u
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#              category             brand currency   price        date
# ...

# %%
len(df[(df["seller_country"] == "US") & (df["buyer_country"] == "US")])
# Out:
# 80658

# %%
80658 / 82111
# Out:
# 0.9823044415486354

# %%
0.9823044415486354 * 100
# Out:
# 98.23044415486353

# %%
df
# Out:
#           buyer_id buyer_country seller_id seller_country  product_code  \
# 0       qzpjsi9t0o            GB  6oufpaot             GB  ydecnydr6obf
# 1       o79pns1qwo            GB  50xki2yg             GB  38chj507o6h2
# 2       sjgbjdkhqx            GB  50xki2yg             GB  i9ynyxj5tdp8
# 3       o79pns1qwo            GB  s0p322hh             GB  t50xe7moye8v
# 4       o79pns1qwo            GB  dpkx192v             GB  hp4r9bjq68af
# ...            ...           ...       ...            ...           ...
# 237666  p7ibf7soot            GB  ss7jy9ks             GB  hzc7pmjxmsb6
# 237667  2hg8zirueq            US  bk6apusi             US  fskn84lfyrvz
# 237668  k5hmcfxcs6            GB  n2ez0xph             GB  5afe7yhdpcmz
# 237669  ca8nc8qv1x            GB  j1s4nqxb             GB  ktdrjbrq0fo2
# 237670  z09h7w9zcd            US  0au7baxi             US  0r1qni2g1zi4
#
#                 category             brand currency   price        date
# ...

# %%
dfB = df.groupby("brand").count()
dfB
# Out:
#                  buyer_id  buyer_country  seller_id  seller_country  \
# brand
# & Other Stories       151            151        151             151
# 032c                   11             11         11              11
# 11 Degrees             33             33         33              33
# 1822 Denim              8              8          8               8
# 3.1 Phillip Lim        10             10         10              10
# ...                   ...            ...        ...             ...
# ghd                    35             35         35              35
# kensie                  1              1          1               1
# liquid blue            52             52         52              52
# mixxmix                12             12         12              12
# philosophy              4              4          4               4
#
#                  product_code  category  currency  price  date
# brand
# & Other Stories           151       151       151    151   151
# ...

# %%
dfB[dfB[35 =< df["buyer_country"] => 55]]
# Out:
#   File "/tmp/ipykernel_12654/2054279176.py", line 1
#     dfB[dfB[35 =< "buyer_country" => 55]]
#                ^
# SyntaxError: invalid syntax

# %%
df2
# Out:
#     currency       date    rate
# 0        EUR   8/1/2020  1.0000
# 1        EUR   8/2/2020  1.0000
# 2        EUR   8/3/2020  1.0000
# 3        EUR   8/4/2020  1.0000
# 4        EUR   8/5/2020  1.0000
# ..       ...        ...     ...
# 215      BRL   8/6/2020  6.3324
# 216      BRL   8/7/2020  6.4111
# 217      BRL   8/8/2020  6.4111
# 218      BRL   8/9/2020  6.4111
# 219      BRL  8/10/2020  6.4351
#
# [220 rows x 3 columns]
