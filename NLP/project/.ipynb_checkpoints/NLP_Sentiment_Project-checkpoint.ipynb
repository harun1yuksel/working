# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to the "***Sentiment Analysis and Classification Project***" project, the first and only project of the ***Natural Language Processing (NLP)*** course.
#
# This analysis will focus on using Natural Language techniques to find broad trends in the written thoughts of the customers.
# The goal in this project is to predict whether customers recommend the product they purchased using the information in their review text.
#
# One of the challenges in this project is to extract useful information from the *Review Text* variable using text mining techniques. The other challenge is that you need to convert text files into numeric feature vectors to run machine learning algorithms.
#
# At the end of this project, you will learn how to build sentiment classification models using Machine Learning algorithms (***Logistic Regression, Naive Bayes, Support Vector Machine, Random Forest*** and ***Ada Boosting***), **Deep Learning algorithms** and **BERT algorithm**.
#
# Before diving into the project, please take a look at the Determines and Tasks.
#
# - ***NOTE:*** *This tutorial assumes that you already know the basics of coding in Python and are familiar with the theory behind the algorithms mentioned above as well as NLP techniques.*

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Determines
# The data is a collection of 22641 Rows and 10 column variables. Each row includes a written comment as well as additional customer information.
# Also each row corresponds to a customer review, and includes the variables:
#
#
# **Feature Information:**
#
# **Clothing ID:** Integer Categorical variable that refers to the specific piece being reviewed.
#
# **Age:** Positive Integer variable of the reviewers age.
#
# **Title:** String variable for the title of the review.
#
# **Review Text:** String variable for the review body.
#
# **Rating:** Positive Ordinal Integer variable for the product score granted by the customer from 1 Worst, to 5 Best.
#
# **Recommended IND:** Binary variable stating where the customer recommends the product where 1 is recommended, 0 is not recommended.
#
# **Positive Feedback Count:** Positive Integer documenting the number of other customers who found this review positive.
#
# **Division Name:** Categorical name of the product high level division.
#
# **Department Name:** Categorical name of the product department name.
#
# **Class Name:** Categorical name of the product class name.
#
# ---
#
# The basic goal in this project is to predict whether customers recommend the product they purchased using the information in their *Review Text*.
# Especially, it should be noted that the expectation in this project is to use only the "Review Text" variable and neglect the other ones.
# Of course, if you want, you can work on other variables individually.
#
# Project Structure is separated in five tasks: ***EDA, Feature Selection and Data Cleaning , Text Mining, Word Cloud*** and ***Sentiment Classification with Machine Learning, Deep Learning and BERT model***.
#
# Classically, you can start to know the data after doing the import and load operations.
# You need to do missing value detection for Review Text, which is the only variable you need to care about. You can drop other variables.
#
# You will need to apply ***noise removal*** and ***lexicon normalization*** processes by using the capabilities of the ***nltk*** library to the data set that is ready for text mining.
#
# Afterwards, you will implement ***Word Cloud*** as a visual analysis of word repetition.
#
# Finally, You will build models with five different algorithms and compare their performance. Thus, you will determine the algorithm that makes the most accurate emotion estimation by using the information obtained from the * Review Text * variable.

# %% [markdown]
# ---
# ---

# %% [markdown]
# # #Tasks
#
# #### 1. Exploratory Data Analysis
#
# - Import Modules, Load Discover the Data
#
# #### 2. Feature Selection and Data Cleaning
#
# - Feature Selection and Rename Column Name
# - Missing Value Detection
#
# #### 3. Text Mining
#
# - Tokenization
# - Noise Removal
# - Lexicon Normalization
#
# #### 4. WordCloud - Repetition of Words
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud
#
#
# #### 5. Sentiment Classification with Machine Learning, Deep Learning and BERT Model
#
# - Train - Test Split
# - Vectorization
# - TF-IDF
# - Logistic Regression
# - Naive Bayes
# - Support Vector Machine
# - Random Forest
# - AdaBoost
# - Deep Learning Model
# - BERT Model
# - Model Comparison

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Sentiment analysis of women's clothes reviews
#
#
# In this project we used sentiment analysis to determined whether the product is recommended or not. We used different machine learning algorithms to get more accurate predictions. The following classification algorithms have been used: ML algorithms(Logistic Regression, Naive Bayes, Support Vector Machine (SVM), Random Forest and Ada Boosting), Deep learning algorithm and BERT algorithm. The dataset comes from Woman Clothing Review that can be find at (https://www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews.

# %% [markdown]
# ## 1. Exploratory Data Analysis

# %% [markdown]
# ### Import Libraries, Load and Discover the Data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from collections import Counter
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"] = (10,6)
pd.set_option('display.max_columns', 50)

# %%
import tensorflow as tf
import os

resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='grpc://' + os.environ['COLAB_TPU_ADDR'])

tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
print("All devices: ", tf.config.list_logical_devices('TPU'))
# Out:
# WARNING:tensorflow:TPU system grpc://10.10.26.74:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# All devices:  [LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:0', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:1', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:2', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:3', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:4', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:5', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:6', device_type='TPU'), LogicalDevice(name='/job:worker/replica:0/task:0/device:TPU:7', device_type='TPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Data Wrangling

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Womens Clothing E-Commerce Reviews.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# 1                        4         General         Dresses    Dresses
# 2                        0         General         Dresses    Dresses
# 3                        0  General Petite         Bottoms      Pants
# 4                        6         General            Tops    Blouses

# %% [markdown]
# #### Check Proportion of Target Class Variable:

# %%
plt.figure(figsize=(6,4))
plt.title("Review Counts")
ax = sns.countplot(df["Recommended IND"])
# ax.bar_label(ax.containers, fontsize="small");
plt.savefig("RC.png")

# %% [markdown]
# The target class variable is imbalanced, where "Recommended" values are more dominating then "Not Recommendation".

# %% [markdown]
# ## 2. Feature Selection and Data Cleaning
#
# From now on, the DataFrame you will work with should contain two columns: **"Review Text"** and **"Recommended IND"**. You can do the missing value detection operations from now on. You can also rename the column names if you want.

# %%
df = df[["Review Text", "Recommended IND"]]
df
# Out:
#                                              Review Text  Recommended IND
# 0      Absolutely wonderful - silky and sexy and comf...                1
# 1      Love this dress!  it's sooo pretty.  i happene...                1
# 2      I had such high hopes for this dress and reall...                0
# 3      I love, love, love this jumpsuit. it's fun, fl...                1
# 4      This shirt is very flattering to all due to th...                1
# ...                                                  ...              ...
# 23481  I was very happy to snag this dress at such a ...                1
# 23482  It reminds me of maternity clothes. soft, stre...                1
# 23483  This fit well, but the top was very see throug...                0
# 23484  I bought this dress for a wedding i have this ...                1
# 23485  This dress in a lovely platinum is feminine an...                1
#
# [23486 rows x 2 columns]

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Feature Selection and Rename Column Name

# %%
df["Recommended IND"] = df["Recommended IND"].map({0:1, 1:0})

# %%
plt.figure(figsize=(6,4))
ax = sns.countplot(df["Recommended IND"])
#ax.bar_label(ax.containers[0]);

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Missing Value Detection

# %%
df["Review Text"].isnull().any()
# Out:
# False

# %%
df["Recommended IND"].isnull().any()
# Out:
# False

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 3. Text Mining
#
# Text is the most unstructured form of all the available data, therefore various types of noise are present in it. This means that the data is not readily analyzable without any pre-processing. The entire process of cleaning and standardization of text, making it noise-free and ready for analysis is known as **text preprocessing**.
#
# The three key steps of text preprocessing:
#
# - **Tokenization:**
# This step is one of the top priorities when it comes to working on text mining. Tokenization is essentially splitting a phrase, sentence, paragraph, or an entire text document into smaller units, such as individual words or terms. Each of these smaller units are called tokens.
#
# - **Noise Removal:**
# Any piece of text which is not relevant to the context of the data and the end-output can be specified as the noise.
# For example – language stopwords (commonly used words of a language – is, am, the, of, in etc), URLs or links, upper and lower case differentiation, punctuations and industry specific words. This step deals with removal of all types of noisy entities present in the text.
#
#
# - **Lexicon Normalization:**
# Another type of textual noise is about the multiple representations exhibited by single word.
# For example – “play”, “player”, “played”, “plays” and “playing” are the different variations of the word – “play”. Though they mean different things, contextually they all are similar. This step converts all the disparities of a word into their normalized form (also known as lemma).
# There are two methods of lexicon normalisation; **[Stemming or Lemmatization](https://www.guru99.com/stemming-lemmatization-python-nltk.html)**. Lemmatization is recommended for this case, because Lemmatization as this will return the root form of each word (rather than just stripping suffixes, which is stemming).
#
# As the first step change text to tokens and convertion all of the words to lower case.  Next remove punctuation, bad characters, numbers and stop words. The second step is aimed to normalization them throught the Lemmatization method.
#
#
# ***Note:*** *Use the functions of the ***[nltk Library](https://www.guru99.com/nltk-tutorial.html)*** for all the above operations.*

# %% [markdown]
# ### Tokenization, Noise Removal, Lexicon Normalization

# %%
df["Review Text"].sample(20)
# Out:
# 12865    Such a beautiful, well-made dress! the color o...
# 18991    I give this sweater a five star review. i am a...
# 20720    This is a very beautiful summer dress with ple...
# 20886    I adore this dress. i wanted/needed to add a f...
# 10320    I wanted to love this dress but the sizing was...
# 20000    I purchased this skirt on super-sale but i'm h...
# 2010     I absolutely love this dress! i wore it with t...
# 6925     The pictures of this dress do not do it justic...
# 21066    You've probably read through the other reviews...
# 11359    I fell in love with this poncho at first sight...
# 17707    This dress is a potato sack! from the picture ...
# 11678    Love this blouse--looks like a fp blouse yet a...
# 17218    This shirt is nothing like the online pictures...
# 14959    Now i would've been scared off by the fabrics ...
# 2433     This top is so cute! love the stripes in the r...
# 9892     I bought the bronze color which was nice but t...
# 5850     I was so excited to receive this sweater in th...
# 21576    I really love this dress but i am still strugg...
# 306      This dress first caught my eye online. due to ...
# 22853    Love this sweater. super comfy. can wear with ...
# Name: Review Text, dtype: object

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger') 
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
stop_words = stopwords.words('english')
for i in ["not", "no"]:
        stop_words.remove(i)

# %%
def cleaning(data):
    
    import re
    
    #1. Removing URLS
    data = re.sub('http\S+', '', data).strip()
    data = re.sub('www\S+', '', data).strip()

    #2. Removing Tags
    data = re.sub('#\S+', '', data).strip()

    #3. Removing Mentions
    data = re.sub('@\S+', '', data).strip()
    
    #4. Removing upper brackets to keep negative auxiliary verbs in text
    data = data.replace("'", "")
    
    #5. Tokenize
    text_tokens = word_tokenize(data.lower())
    
    #6. Remove Puncs and number
    tokens_without_punc = [w for w in text_tokens if w.isalpha()]
    
    #7. Removing Stopwords
    tokens_without_sw = [t for t in tokens_without_punc if t not in stop_words]
    
    #8. lemma
    text_cleaned = [WordNetLemmatizer().lemmatize(t) for t in tokens_without_sw]
    
    #joining
    return " ".join(text_cleaned)

# %%
df["Review Text"] = df["Review Text"].apply(cleaning)

# %%
df["Review Text"].sample(20)
# Out:
# 4816     im bough size regular short wear jean see midr...
# 13579    dress look cute online enormous bought small l...
# 12032    yes need comfortable wash perfectly workout wa...
# 4379     love dress quality material nice good weight s...
# 1903     love jean well not worn yet not sure stretch t...
# 14776    nice comfy sweatshirt wish tad longer tends ru...
# 9098     hourglass shape dress good fit think dress loo...
# 17939    loved sweater coat first time saw online price...
# 1749     im glad got skirt prettier person picture fian...
# 11481    love look simplicity top casual also super cut...
# 10149    agree previous reviewer bit short top kind lik...
# 10778    ordered two pair red cord one typical size one...
# 228      cute top jean spring summer warmer climate fre...
# 22410    excited see top sale watching week unfortunate...
# 22322    love skorts saw online ordered usual size arri...
# 14832    ordered looked good fit casual lifestyle doesn...
# 3851     ordered taupe version tee medium brown black s...
# 4422     putting two cent regarding fantastic dress bou...
# 9623     lightweight knit flattering color made top per...
# 9329     purchased dress garden wedding received many c...
# Name: Review Text, dtype: object

# %% [markdown]
# ## 4. WordCloud - Repetition of Words
#
# Now you'll create a Word Clouds for reviews, representing most common words in each target class.
#
# Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance. Significant textual data points can be highlighted using a word cloud.
#
# You are expected to create separate word clouds for positive and negative reviews. You can qualify a review as positive or negative, by looking at its recommended status. You may need to use capabilities of matplotlib for visualizations.
#
# You can follow the steps below:
#
# - Detect Reviews
# - Collect Words
# - Create Word Cloud

# %%
# pip install wordcloud
from wordcloud import WordCloud
worldcloud = WordCloud(background_color="white", max_words =250)

# %% [markdown]
# ### Detect Reviews (positive and negative separately)

# %%
positive_reviews = df[df["Recommended IND"] == 0]["Review Text"]

# %%
negative_reviews = df[df["Recommended IND"] == 1]["Review Text"]

# %% [markdown]
# ### Collect Words (positive and negative separately)

# %% [markdown]
# ### Create Word Cloud (for most common words in recommended not recommended reviews separately)

# %% [markdown]
# ### positive

# %%
all_words = " ".join(positive_reviews)
worldcloud.generate(all_words)
plt.figure(figsize = (13,13))
plt.imshow(worldcloud, interpolation="bilinear",)                 # interpolation : renklendirme
plt.axis("off")                                                   # Cerceve olsun mu?
plt.show();

# %% [markdown]
# ### Negative

# %%
all_words = " ".join(negative_reviews)
worldcloud.generate(all_words)
plt.figure(figsize = (13,13))
plt.imshow(worldcloud, interpolation="bilinear",)                 # interpolation : renklendirme
plt.axis("off")                                                   # Cerceve olsun mu?
plt.show();

# %% [markdown]
# ## 5. Sentiment Classification with Machine Learning, Deep Learning and BERT model
#
# Before moving on to modeling, as data preprocessing steps you will need to perform **[vectorization](https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/)** and **train-test split**. You have performed many times train test split process before.
# But you will perform the vectorization for the first time.
#
# Machine learning algorithms most often take numeric feature vectors as input. Thus, when working with text documents, you need a way to convert each document into a numeric vector. This process is known as text vectorization. Commonly used vectorization approach that you will use here is to represent each text as a vector of word counts.
#
# At this moment, you have your review text column as a token (which has no punctuations and stopwords). You can use Scikit-learn’s CountVectorizer to convert the text collection into a matrix of token counts. You can imagine this resulting matrix as a 2-D matrix, where each row is a unique word, and each column is a review.
#
# Train all models using TFIDF and Count vectorizer data.
#
# **For Deep learning model, use embedding layer for all words.**
#
# **For BERT model, use TF tensor**
#
# After performing data preprocessing, build your models using following classification algorithms:
#
# - Logistic Regression,
# - Naive Bayes,
# - Support Vector Machine,
# - Random Forest,
# - Ada Boosting
# - Deep Learning Model
# - BERT Model

# %% [markdown]
# ### Train - Test Split

# %% [markdown]
# To run machine learning algorithms we need to convert text files into numerical feature vectors. We will use bag of words model for our analysis.
#
# First we spliting the data into train and test sets:

# %%
X = df["Review Text"]
y = df["Recommended IND"]

# %% [markdown]
# In the next step we create a numerical feature vector for each document:

# %% [markdown]
# ### Count Vectorization

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=101)

# %%
vectorizer = CountVectorizer(preprocessor=cleaning, min_df=3) 
X_train_count = vectorizer.fit_transform(X_train)
X_test_count = vectorizer.transform(X_test)

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf_idf_vectorizer = TfidfVectorizer(preprocessor=cleaning, min_df=3)
X_train_tf_idf = tf_idf_vectorizer.fit_transform(X_train)
X_test_tf_idf = tf_idf_vectorizer.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### CountVectorizer

# %%
type(X_train_count)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(C = 0.02, max_iter=1000) 
log.fit(X_train_count, y_train)
# Out:
# LogisticRegression(C=0.02, max_iter=1000)

# %%
from sklearn.metrics import confusion_matrix, classification_report, f1_score, recall_score

# %%
def eval(model, X_train, X_test):
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    print(confusion_matrix(y_test, y_pred))
    print("Test_Set")
    print(classification_report(y_test,y_pred))
    print("Train_Set")
    print(classification_report(y_train,y_pred_train))

# %%
print("LOG MODEL")
eval(log, X_train_count, X_test_count)
# Out:
# LOG MODEL
# [[3591  118]
#  [ 424  396]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.89      0.97      0.93      3709
#            1       0.77      0.48      0.59       820
#
#     accuracy                           0.88      4529
#    macro avg       0.83      0.73      0.76      4529
# weighted avg       0.87      0.88      0.87      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.93     14831
#            1       0.81      0.50      0.62      3281
#
#     accuracy                           0.89     18112
#    macro avg       0.85      0.74      0.78     18112
# weighted avg       0.88      0.89      0.88     18112

# %%
from sklearn.model_selection import GridSearchCV

# %%
log.get_params()
# Out:
# {'C': 0.02,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 1000,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': None,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
param_grid = {"C" :[0.005, 0.01, 0.02, 0.05],  'class_weight': ["balanced", None]}

log_model_grid = GridSearchCV(log, param_grid, scoring="recall", cv=10)

# %%
log_model_grid.fit(X_train_count, y_train)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(C=0.02, max_iter=1000),
#              param_grid={'C': [0.005, 0.01, 0.02, 0.05],
#                          'class_weight': ['balanced', None]},
#              scoring='recall')

# %%
log_model_grid.best_params_
# Out:
# {'C': 0.01, 'class_weight': 'balanced'}

# %%
log = LogisticRegression(C = 0.01, max_iter=1000, class_weight = 'balanced') 
log.fit(X_train_count, y_train)
# Out:
# LogisticRegression(C=0.01, class_weight='balanced', max_iter=1000)

# %%
print("LOG MODEL")
eval(log, X_train_count, X_test_count)
# Out:
# LOG MODEL
# [[3137  572]
#  [ 122  698]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90      3709
#            1       0.55      0.85      0.67       820
#
#     accuracy                           0.85      4529
#    macro avg       0.76      0.85      0.78      4529
# weighted avg       0.89      0.85      0.86      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.86      0.91     14831
#            1       0.58      0.88      0.70      3281
#
#     accuracy                           0.86     18112
#    macro avg       0.77      0.87      0.80     18112
# weighted avg       0.90      0.86      0.87     18112

# %% [markdown]
# ### TF-IDF

# %%
log = LogisticRegression(C = 0.01, max_iter=1000, class_weight='balanced') #class_weight='balanced'
log.fit(X_train_tf_idf, y_train)
# Out:
# LogisticRegression(C=0.01, class_weight='balanced', max_iter=1000)

# %%
print("LOG MODEL")
eval(log, X_train_tf_idf, X_test_tf_idf)
# Out:
# LOG MODEL
# [[3033  676]
#  [ 129  691]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.88      3709
#            1       0.51      0.84      0.63       820
#
#     accuracy                           0.82      4529
#    macro avg       0.73      0.83      0.76      4529
# weighted avg       0.88      0.82      0.84      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.82      0.89     14831
#            1       0.52      0.87      0.65      3281
#
#     accuracy                           0.83     18112
#    macro avg       0.74      0.85      0.77     18112
# weighted avg       0.89      0.83      0.85     18112

# %%
param_grid = {"C" :[0.02, 0.05, 0.1, 0.3, 0.7],  'class_weight': ["balanced", None]}

log_model_grid = GridSearchCV(log, param_grid, scoring="recall", cv=10)

# %%
log_model_grid.fit(X_train_tf_idf, y_train)
# Out:
# GridSearchCV(cv=10,
#              estimator=LogisticRegression(C=0.01, class_weight='balanced',
#                                           max_iter=1000),
#              param_grid={'C': [0.02, 0.05, 0.1, 0.3, 0.7],
#                          'class_weight': ['balanced', None]},
#              scoring='recall')

# %%
log_model_grid.best_params_
# Out:
# {'C': 0.05, 'class_weight': 'balanced'}

# %%
log = LogisticRegression(C = 0.05, max_iter=1000, class_weight='balanced') #class_weight='balanced'
log.fit(X_train_tf_idf, y_train)
# Out:
# LogisticRegression(C=0.05, class_weight='balanced', max_iter=1000)

# %%
print("LOG MODEL")
eval(log, X_train_tf_idf, X_test_tf_idf)
# Out:
# LOG MODEL
# [[3093  616]
#  [ 120  700]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89      3709
#            1       0.53      0.85      0.66       820
#
#     accuracy                           0.84      4529
#    macro avg       0.75      0.84      0.77      4529
# weighted avg       0.88      0.84      0.85      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90     14831
#            1       0.55      0.88      0.68      3281
#
#     accuracy                           0.85     18112
#    macro avg       0.76      0.86      0.79     18112
# weighted avg       0.89      0.85      0.86     18112

# %%
from yellowbrick.classifier import PrecisionRecallCurve

# %%
viz = PrecisionRecallCurve(
    log,
    classes=log.classes_,
    cmap="Set1"
)
viz.fit(X_train_tf_idf,y_train)
viz.score(X_test_tf_idf, y_test)
viz.show();

# %%
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score

scoring = {'accuracy': make_scorer(accuracy_score),
            'precision-1': make_scorer(precision_score, average=None, labels=[1]),
            'recall-1': make_scorer(recall_score, average=None, labels = [1]),
            'f1-1': make_scorer(f1_score, average=None, labels = [1])}

model = log
scores = cross_validate(model, X_train_tf_idf, y_train, scoring = scoring, cv = 10, return_train_score=True)
df_scores = pd.DataFrame(scores, index = range(1, 11))
df_scores.mean()[2:]
# Out:
# test_accuracy        0.839278
# train_accuracy       0.847222
# test_precision-1     0.535104
# train_precision-1    0.548619
# test_recall-1        0.862843
# train_recall-1       0.883741
# test_f1-1            0.660464
# train_f1-1           0.676974
# dtype: float64

# %% [markdown]
# ## Naive Bayes
#
# ### Countvectorizer

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB # BernoulliNB for binary model

# %%
nb = BernoulliNB(alpha=10)
nb.fit(X_train_count,y_train)
# Out:
# BernoulliNB(alpha=10)

# %%
print("NB MODEL")
eval(nb, X_train_count, X_test_count)
# Out:
# NB MODEL
# [[3648   61]
#  [ 654  166]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.85      0.98      0.91      3709
#            1       0.73      0.20      0.32       820
#
#     accuracy                           0.84      4529
#    macro avg       0.79      0.59      0.61      4529
# weighted avg       0.83      0.84      0.80      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.91     14831
#            1       0.77      0.22      0.34      3281
#
#     accuracy                           0.85     18112
#    macro avg       0.81      0.60      0.63     18112
# weighted avg       0.84      0.85      0.81     18112

# %% [markdown]
# ### TF-IDF

# %%
nb = BernoulliNB(alpha=8)
nb.fit(X_train_tf_idf,y_train)
# Out:
# BernoulliNB(alpha=8)

# %%
print("NB MODEL")
eval(nb, X_train_tf_idf, X_test_tf_idf)
# Out:
# NB MODEL
# [[3595  114]
#  [ 593  227]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      3709
#            1       0.67      0.28      0.39       820
#
#     accuracy                           0.84      4529
#    macro avg       0.76      0.62      0.65      4529
# weighted avg       0.82      0.84      0.82      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92     14831
#            1       0.73      0.31      0.44      3281
#
#     accuracy                           0.85     18112
#    macro avg       0.80      0.64      0.68     18112
# weighted avg       0.84      0.85      0.83     18112

# %%
viz = PrecisionRecallCurve(
    nb,
    classes=nb.classes_,     # targettaki class' lar ile aynı isimler döndürsün diye
    cmap="Set1"              # renklendirme
)
viz.fit(X_train_tf_idf,y_train)  # egitim yap
viz.score(X_test_tf_idf, y_test) # skorlari al
viz.show();

# %%
nb.get_params()
# Out:
# {'alpha': 8, 'binarize': 0.0, 'class_prior': None, 'fit_prior': True}

# %% [markdown]
# ## Support Vector Machine (SVM)
#
# ### Countvectorizer

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(C=0.001) 
svc.fit(X_train_count,y_train)
# Out:
# LinearSVC(C=0.001)

# %%
print("SVC MODEL")
eval(svc, X_train_count, X_test_count)
# Out:
# SVC MODEL
# [[3623   86]
#  [ 483  337]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      3709
#            1       0.80      0.41      0.54       820
#
#     accuracy                           0.87      4529
#    macro avg       0.84      0.69      0.73      4529
# weighted avg       0.87      0.87      0.86      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93     14831
#            1       0.82      0.40      0.53      3281
#
#     accuracy                           0.87     18112
#    macro avg       0.85      0.69      0.73     18112
# weighted avg       0.87      0.87      0.86     18112

# %% [markdown]
# ### TD-IDF

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(C=0.04) 
svc.fit(X_train_tf_idf,y_train)
# Out:
# LinearSVC(C=0.04)

# %%
print("SVC MODEL")
eval(svc, X_train_tf_idf, X_test_tf_idf)
# Out:
# SVC MODEL
# [[3632   77]
#  [ 465  355]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93      3709
#            1       0.82      0.43      0.57       820
#
#     accuracy                           0.88      4529
#    macro avg       0.85      0.71      0.75      4529
# weighted avg       0.87      0.88      0.86      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94     14831
#            1       0.87      0.47      0.61      3281
#
#     accuracy                           0.89     18112
#    macro avg       0.88      0.72      0.77     18112
# weighted avg       0.89      0.89      0.88     18112

# %%
svc.get_params()
# Out:
# {'C': 0.04,
#  'class_weight': None,
#  'dual': True,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'loss': 'squared_hinge',
#  'max_iter': 1000,
#  'multi_class': 'ovr',
#  'penalty': 'l2',
#  'random_state': None,
#  'tol': 0.0001,
#  'verbose': 0}

# %%
param_grid = {"C" :[0.01, 0.02, 0.05, 0.1],  'class_weight': ["balanced", None]}

svc_grid = GridSearchCV(svc, param_grid, scoring="recall", cv=10)
svc_grid.fit(X_train_tf_idf, y_train)

svc_grid.best_params_
# Out:
# {'C': 0.02, 'class_weight': 'balanced'}

# %%
svc = LinearSVC(C=0.02, class_weight= "balanced") 
svc.fit(X_train_tf_idf,y_train)
print("SVC MODEL")
eval(svc, X_train_tf_idf, X_test_tf_idf)
# Out:
# SVC MODEL
# [[3154  555]
#  [ 104  716]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.91      3709
#            1       0.56      0.87      0.68       820
#
#     accuracy                           0.85      4529
#    macro avg       0.77      0.86      0.80      4529
# weighted avg       0.89      0.85      0.87      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.98      0.86      0.91     14831
#            1       0.59      0.91      0.71      3281
#
#     accuracy                           0.87     18112
#    macro avg       0.78      0.88      0.81     18112
# weighted avg       0.91      0.87      0.88     18112

# %%
viz = PrecisionRecallCurve(
    svc,
    classes=nb.classes_,     # targettaki class' lar ile aynı isimler döndürsün diye
    cmap="Set1"              # renklendirme
)
viz.fit(X_train_tf_idf,y_train)  # egitim yap
viz.score(X_test_tf_idf, y_test) # skorlari al
viz.show();

# %% [markdown]
# ## Random Forest
#
# ### Countvectorizer

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(100, max_depth = 3, random_state = 42, n_jobs = -1, class_weight="balanced") 
rf.fit(X_train_count, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=3, n_jobs=-1,
#                        random_state=42)

# %%
print("RF MODEL")
eval(rf, X_train_count, X_test_count)
# Out:
# RF MODEL
# [[2944  765]
#  [ 181  639]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      3709
#            1       0.46      0.78      0.57       820
#
#     accuracy                           0.79      4529
#    macro avg       0.70      0.79      0.72      4529
# weighted avg       0.85      0.79      0.81      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.80      0.87     14831
#            1       0.48      0.83      0.61      3281
#
#     accuracy                           0.81     18112
#    macro avg       0.72      0.82      0.74     18112
# weighted avg       0.87      0.81      0.82     18112

# %% [markdown]
# ### TF-IDF

# %%
rf = RandomForestClassifier(1000, max_depth = 3, random_state = 42, n_jobs = -1, class_weight="balanced") 
rf.fit(X_train_tf_idf, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=3, n_estimators=1000,
#                        n_jobs=-1, random_state=42)

# %%
print("RF MODEL")
eval(rf, X_train_tf_idf, X_test_tf_idf)
# Out:
# RF MODEL
# [[3041  668]
#  [ 150  670]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.95      0.82      0.88      3709
#            1       0.50      0.82      0.62       820
#
#     accuracy                           0.82      4529
#    macro avg       0.73      0.82      0.75      4529
# weighted avg       0.87      0.82      0.83      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.96      0.82      0.89     14831
#            1       0.52      0.86      0.65      3281
#
#     accuracy                           0.83     18112
#    macro avg       0.74      0.84      0.77     18112
# weighted avg       0.88      0.83      0.85     18112

# %% [markdown]
# ## Ada Boosting
#
# ### Countvectorizer

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators= 500, random_state = 42)
ada.fit(X_train_count, y_train)
# Out:
# AdaBoostClassifier(n_estimators=500, random_state=42)

# %%
print("Ada MODEL")
eval(ada, X_train_count, X_test_count)
# Out:
# Ada MODEL
# [[3491  218]
#  [ 351  469]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92      3709
#            1       0.68      0.57      0.62       820
#
#     accuracy                           0.87      4529
#    macro avg       0.80      0.76      0.77      4529
# weighted avg       0.87      0.87      0.87      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95     14831
#            1       0.80      0.66      0.73      3281
#
#     accuracy                           0.91     18112
#    macro avg       0.87      0.81      0.84     18112
# weighted avg       0.91      0.91      0.91     18112

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(n_estimators= 1000, random_state = 42, learning_rate=0.1)
ada.fit(X_train_tf_idf, y_train)
# Out:
# AdaBoostClassifier(learning_rate=0.1, n_estimators=1000, random_state=42)

# %%
print("Ada MODEL")
eval(ada, X_train_tf_idf, X_test_tf_idf)
# Out:
# Ada MODEL
# [[3604  105]
#  [ 479  341]]
# Test_Set
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.93      3709
#            1       0.76      0.42      0.54       820
#
#     accuracy                           0.87      4529
#    macro avg       0.82      0.69      0.73      4529
# weighted avg       0.86      0.87      0.86      4529
#
# Train_Set
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.93     14831
#            1       0.83      0.45      0.59      3281
#
#     accuracy                           0.88     18112
#    macro avg       0.86      0.72      0.76     18112
# weighted avg       0.88      0.88      0.87     18112

# %%
ada.get_params()
# Out:
# {'algorithm': 'SAMME.R',
#  'base_estimator': None,
#  'learning_rate': 0.1,
#  'n_estimators': 1000,
#  'random_state': 42}

# %% [markdown]
# ## DL modeling

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Embedding, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ### Tokenization

# %%
num_words = 15000
tokenizer = Tokenizer(num_words=num_words)

# %%
df
# Out:
#                                              Review Text  Recommended IND
# 0            absolutely wonderful silky sexy comfortable                0
# 1      love dress sooo pretty happened find store im ...                0
# 2      high hope dress really wanted work initially o...                1
# 3      love love love jumpsuit fun flirty fabulous ev...                0
# 4      shirt flattering due adjustable front tie perf...                0
# ...                                                  ...              ...
# 23481  happy snag dress great price easy slip flatter...                0
# 23482  reminds maternity clothes soft stretchy shiny ...                0
# 23483  fit well top see never would worked im glad ab...                1
# 23484  bought dress wedding summer cute unfortunately...                0
# 23485  dress lovely platinum feminine fit perfectly e...                0
#
# [22641 rows x 2 columns]

# %%
X = df["Review Text"]
y = df["Recommended IND"]

# %%
tokenizer.fit_on_texts(X)
X
# Out:
# 0              absolutely wonderful silky sexy comfortable
# 1        love dress sooo pretty happened find store im ...
# 2        high hope dress really wanted work initially o...
# 3        love love love jumpsuit fun flirty fabulous ev...
# 4        shirt flattering due adjustable front tie perf...
#                                ...
# 23481    happy snag dress great price easy slip flatter...
# 23482    reminds maternity clothes soft stretchy shiny ...
# 23483    fit well top see never would worked im glad ab...
# 23484    bought dress wedding summer cute unfortunately...
# 23485    dress lovely platinum feminine fit perfectly e...
# Name: Review Text, Length: 22641, dtype: object

# %% [markdown]
# ### Creating word index

# %%
tokenizer.word_index
# Out:
# {'dress': 1,
#  'fit': 2,
#  'not': 3,
#  'size': 4,
#  'love': 5,
#  'top': 6,
#  'like': 7,
#  'color': 8,
#  'look': 9,
#  'wear': 10,
#  'great': 11,
#  'im': 12,
#  'would': 13,
#  'fabric': 14,
#  'small': 15,
#  'really': 16,
#  'ordered': 17,
#  'little': 18,
#  'perfect': 19,
#  'one': 20,
#  'flattering': 21,
#  'soft': 22,
#  'well': 23,
#  'back': 24,
#  'comfortable': 25,
#  'cute': 26,
#  'nice': 27,
#  'bought': 28,
#  'beautiful': 29,
#  'bit': 30,
#  'material': 31,
#  'shirt': 32,
#  'large': 33,
#  'much': 34,
#  'sweater': 35,
#  'length': 36,
#  'run': 37,
#  'jean': 38,
#  'also': 39,
#  'work': 40,
#  'petite': 41,
#  'got': 42,
#  'long': 43,
#  'short': 44,
#  'waist': 45,
#  'quality': 46,
#  'medium': 47,
#  'skirt': 48,
#  'think': 49,
#  'pretty': 50,
#  'even': 51,
#  'retailer': 52,
#  'x': 53,
#  'make': 54,
#  'feel': 55,
#  'tried': 56,
#  'pant': 57,
#  'store': 58,
#  'usually': 59,
#  'get': 60,
#  'way': 61,
#  'sleeve': 62,
#  'good': 63,
#  'could': 64,
#  'big': 65,
#  'made': 66,
#  'cut': 67,
#  'go': 68,
#  'dont': 69,
#  'didnt': 70,
#  'still': 71,
#  'style': 72,
#  'right': 73,
#  'black': 74,
#  'super': 75,
#  'true': 76,
#  'see': 77,
#  'online': 78,
#  'no': 79,
#  'design': 80,
#  'wearing': 81,
#  'purchased': 82,
#  'however': 83,
#  'summer': 84,
#  'arm': 85,
#  'white': 86,
#  'enough': 87,
#  'tight': 88,
#  'perfectly': 89,
#  'model': 90,
#  'time': 91,
#  'sale': 92,
#  'bottom': 93,
#  'definitely': 94,
#  'fall': 95,
#  'shoulder': 96,
#  'looked': 97,
#  'front': 98,
#  'lb': 99,
#  'detail': 100,
#  'though': 101,
#  'jacket': 102,
#  'price': 103,
#  'side': 104,
#  'loved': 105,
#  'person': 106,
#  'blue': 107,
#  'better': 108,
#  'picture': 109,
#  'piece': 110,
#  'review': 111,
#  'first': 112,
#  'body': 113,
#  'going': 114,
#  'try': 115,
#  'loose': 116,
#  'need': 117,
#  'worn': 118,
#  'shape': 119,
#  'around': 120,
#  'day': 121,
#  'regular': 122,
#  'lot': 123,
#  'thought': 124,
#  'pair': 125,
#  'many': 126,
#  'looking': 127,
#  'lovely': 128,
#  'pattern': 129,
#  'light': 130,
#  'wanted': 131,
#  'hip': 132,
#  'saw': 133,
#  'photo': 134,
#  'chest': 135,
#  'gorgeous': 136,
#  'button': 137,
#  'high': 138,
#  'compliment': 139,
#  'recommend': 140,
#  'casual': 141,
#  'thin': 142,
#  'blouse': 143,
#  'doesnt': 144,
#  'without': 145,
#  'want': 146,
#  'bust': 147,
#  'went': 148,
#  'print': 149,
#  'bra': 150,
#  'reviewer': 151,
#  'find': 152,
#  'found': 153,
#  'cant': 154,
#  'sure': 155,
#  'wore': 156,
#  'ive': 157,
#  'wish': 158,
#  'buy': 159,
#  'keep': 160,
#  'since': 161,
#  'usual': 162,
#  'thing': 163,
#  'hit': 164,
#  'say': 165,
#  'weight': 166,
#  'normally': 167,
#  'order': 168,
#  'received': 169,
#  'give': 170,
#  'different': 171,
#  'comfy': 172,
#  'overall': 173,
#  'longer': 174,
#  'absolutely': 175,
#  'may': 176,
#  'quite': 177,
#  'nicely': 178,
#  'slightly': 179,
#  'legging': 180,
#  'return': 181,
#  'fitted': 182,
#  'stretch': 183,
#  'two': 184,
#  'might': 185,
#  'felt': 186,
#  'another': 187,
#  'underneath': 188,
#  'area': 189,
#  'green': 190,
#  'unique': 191,
#  'red': 192,
#  'easy': 193,
#  'wasnt': 194,
#  'tee': 195,
#  'tank': 196,
#  'fun': 197,
#  'wide': 198,
#  'pocket': 199,
#  'probably': 200,
#  'happy': 201,
#  'lace': 202,
#  'extra': 203,
#  'boxy': 204,
#  'sizing': 205,
#  'almost': 206,
#  'actually': 207,
#  'purchase': 208,
#  'knee': 209,
#  'something': 210,
#  'year': 211,
#  'warm': 212,
#  'show': 213,
#  'leg': 214,
#  'fine': 215,
#  'smaller': 216,
#  'unfortunately': 217,
#  'dressed': 218,
#  'worth': 219,
#  'sheer': 220,
#  'flowy': 221,
#  'glad': 222,
#  'boot': 223,
#  'every': 224,
#  'skinny': 225,
#  'part': 226,
#  'come': 227,
#  'shorter': 228,
#  'said': 229,
#  'neck': 230,
#  'put': 231,
#  'problem': 232,
#  'tall': 233,
#  'add': 234,
#  'yet': 235,
#  'always': 236,
#  'disappointed': 237,
#  'reference': 238,
#  'tt': 239,
#  'full': 240,
#  'favorite': 241,
#  'low': 242,
#  'everything': 243,
#  'drape': 244,
#  'wait': 245,
#  'sized': 246,
#  'denim': 247,
#  'maybe': 248,
#  'take': 249,
#  'decided': 250,
#  'larger': 251,
#  'versatile': 252,
#  'liked': 253,
#  'neckline': 254,
#  'adorable': 255,
#  'figure': 256,
#  'huge': 257,
#  'issue': 258,
#  'navy': 259,
#  'id': 260,
#  'thick': 261,
#  'especially': 262,
#  'easily': 263,
#  'wash': 264,
#  'returned': 265,
#  'coat': 266,
#  'came': 267,
#  'best': 268,
#  'isnt': 269,
#  'room': 270,
#  'seems': 271,
#  'line': 272,
#  'inch': 273,
#  'slip': 274,
#  'pink': 275,
#  'snug': 276,
#  'amazing': 277,
#  'hem': 278,
#  'heavy': 279,
#  'cardigan': 280,
#  'lightweight': 281,
#  'normal': 282,
#  'grey': 283,
#  'couldnt': 284,
#  'know': 285,
#  'tunic': 286,
#  'hole': 287,
#  'feminine': 288,
#  'winter': 289,
#  'flat': 290,
#  'knit': 291,
#  'spring': 292,
#  'thats': 293,
#  'cotton': 294,
#  'pictured': 295,
#  'hang': 296,
#  'layer': 297,
#  'kind': 298,
#  'took': 299,
#  'item': 300,
#  'belt': 301,
#  'expected': 302,
#  'ill': 303,
#  'torso': 304,
#  'type': 305,
#  'cami': 306,
#  'frame': 307,
#  'dark': 308,
#  'returning': 309,
#  'embroidery': 310,
#  'beautifully': 311,
#  'extremely': 312,
#  'tie': 313,
#  'fitting': 314,
#  'lining': 315,
#  'typically': 316,
#  'although': 317,
#  'brand': 318,
#  'able': 319,
#  'never': 320,
#  'excited': 321,
#  'xl': 322,
#  'curvy': 323,
#  'lined': 324,
#  'highly': 325,
#  'today': 326,
#  'someone': 327,
#  'anything': 328,
#  'either': 329,
#  'strap': 330,
#  'washed': 331,
#  'shown': 332,
#  'suit': 333,
#  'xx': 334,
#  'bad': 335,
#  'new': 336,
#  'zipper': 337,
#  'ended': 338,
#  'cool': 339,
#  'heel': 340,
#  'sold': 341,
#  'youre': 342,
#  'weather': 343,
#  'trying': 344,
#  'already': 345,
#  'season': 346,
#  'flow': 347,
#  'needed': 348,
#  'stretchy': 349,
#  'last': 350,
#  'agree': 351,
#  'arrived': 352,
#  'vest': 353,
#  'hard': 354,
#  'fell': 355,
#  'otherwise': 356,
#  'hoping': 357,
#  'pull': 358,
#  'exactly': 359,
#  'wardrobe': 360,
#  'ankle': 361,
#  'cozy': 362,
#  'seam': 363,
#  'due': 364,
#  'flare': 365,
#  'swing': 366,
#  'across': 367,
#  'gray': 368,
#  'cheap': 369,
#  'local': 370,
#  'sadly': 371,
#  'place': 372,
#  'away': 373,
#  'skin': 374,
#  'wouldnt': 375,
#  'unflattering': 376,
#  'least': 377,
#  'hot': 378,
#  'tad': 379,
#  'touch': 380,
#  'rather': 381,
#  'keeping': 382,
#  'cover': 383,
#  'plan': 384,
#  'ever': 385,
#  'open': 386,
#  'l': 387,
#  'stylish': 388,
#  'getting': 389,
#  'ran': 390,
#  'hope': 391,
#  'dry': 392,
#  'vibrant': 393,
#  'classic': 394,
#  'others': 395,
#  'theyre': 396,
#  'night': 397,
#  'must': 398,
#  'several': 399,
#  'pound': 400,
#  'orange': 401,
#  'plus': 402,
#  'pilcro': 403,
#  'surprised': 404,
#  'nothing': 405,
#  'delicate': 406,
#  'version': 407,
#  'wonderful': 408,
#  'baggy': 409,
#  'slim': 410,
#  'kept': 411,
#  'le': 412,
#  'stripe': 413,
#  'based': 414,
#  'ordering': 415,
#  'seem': 416,
#  'straight': 417,
#  'simple': 418,
#  'end': 419,
#  'bright': 420,
#  'stunning': 421,
#  'wedding': 422,
#  'roomy': 423,
#  'use': 424,
#  'month': 425,
#  'thigh': 426,
#  'booty': 427,
#  'sometimes': 428,
#  'girl': 429,
#  'cropped': 430,
#  'available': 431,
#  'worked': 432,
#  'paired': 433,
#  'itchy': 434,
#  'woman': 435,
#  'instead': 436,
#  'seemed': 437,
#  'far': 438,
#  'yellow': 439,
#  'bigger': 440,
#  'texture': 441,
#  'wont': 442,
#  'previous': 443,
#  'buying': 444,
#  'jumpsuit': 445,
#  'immediately': 446,
#  'outfit': 447,
#  'oversized': 448,
#  'staple': 449,
#  'tiny': 450,
#  'busty': 451,
#  'mine': 452,
#  'lay': 453,
#  'tights': 454,
#  'mentioned': 455,
#  'making': 456,
#  'curve': 457,
#  'special': 458,
#  'sandal': 459,
#  'hold': 460,
#  'elastic': 461,
#  'second': 462,
#  'completely': 463,
#  'help': 464,
#  'lower': 465,
#  'totally': 466,
#  'cold': 467,
#  'higher': 468,
#  'slit': 469,
#  'collar': 470,
#  'read': 471,
#  'ivory': 472,
#  'reason': 473,
#  'hide': 474,
#  'weird': 475,
#  'eye': 476,
#  'armhole': 477,
#  'there': 478,
#  'basic': 479,
#  'stiff': 480,
#  'people': 481,
#  'often': 482,
#  'knew': 483,
#  'worried': 484,
#  'clothes': 485,
#  'used': 486,
#  'wool': 487,
#  'else': 488,
#  'star': 489,
#  'incredibly': 490,
#  'finally': 491,
#  'complaint': 492,
#  'interesting': 493,
#  'layering': 494,
#  'odd': 495,
#  'neutral': 496,
#  'awesome': 497,
#  'week': 498,
#  'similar': 499,
#  'thinking': 500,
#  'prefer': 501,
#  'slimming': 502,
#  'fact': 503,
#  'clothing': 504,
#  'amount': 505,
#  'athletic': 506,
#  'wrong': 507,
#  'spot': 508,
#  'hand': 509,
#  'mind': 510,
#  'wrinkle': 511,
#  'substantial': 512,
#  'inside': 513,
#  'broad': 514,
#  'sexy': 515,
#  'gotten': 516,
#  'gave': 517,
#  'point': 518,
#  'throw': 519,
#  'half': 520,
#  'dressy': 521,
#  'bulky': 522,
#  'closet': 523,
#  'hourglass': 524,
#  'addition': 525,
#  'product': 526,
#  'elegant': 527,
#  'waisted': 528,
#  'appears': 529,
#  'deep': 530,
#  'rich': 531,
#  'couple': 532,
#  'next': 533,
#  'cream': 534,
#  'upper': 535,
#  'close': 536,
#  'home': 537,
#  'washing': 538,
#  'tell': 539,
#  'romper': 540,
#  'mail': 541,
#  'brown': 542,
#  'linen': 543,
#  'soon': 544,
#  'subtle': 545,
#  'justice': 546,
#  'depending': 547,
#  'except': 548,
#  'ruffle': 549,
#  'option': 550,
#  'peplum': 551,
#  'expect': 552,
#  'thread': 553,
#  'somewhat': 554,
#  'detailing': 555,
#  'blazer': 556,
#  'stay': 557,
#  'left': 558,
#  'appropriate': 559,
#  'sad': 560,
#  'thicker': 561,
#  'case': 562,
#  'weekend': 563,
#  'cup': 564,
#  'form': 565,
#  'forward': 566,
#  'maternity': 567,
#  'ton': 568,
#  'lady': 569,
#  'yes': 570,
#  'flower': 571,
#  'idea': 572,
#  'exchange': 573,
#  'pleased': 574,
#  'nude': 575,
#  'silk': 576,
#  'build': 577,
#  'zip': 578,
#  'perhaps': 579,
#  'tag': 580,
#  'anyway': 581,
#  'party': 582,
#  'fan': 583,
#  'fairly': 584,
#  'havent': 585,
#  'expecting': 586,
#  'baby': 587,
#  'looser': 588,
#  'everywhere': 589,
#  'office': 590,
#  'taller': 591,
#  'ok': 592,
#  'band': 593,
#  'bodice': 594,
#  'motif': 595,
#  'hung': 596,
#  'real': 597,
#  'maeve': 598,
#  'middle': 599,
#  'added': 600,
#  'truly': 601,
#  'darker': 602,
#  'awkward': 603,
#  'occasion': 604,
#  'barely': 605,
#  'sort': 606,
#  'narrow': 607,
#  'sweatshirt': 608,
#  'classy': 609,
#  'together': 610,
#  'opinion': 611,
#  'along': 612,
#  'slight': 613,
#  'floral': 614,
#  'typical': 615,
#  'gone': 616,
#  'colored': 617,
#  'deal': 618,
#  'purple': 619,
#  'necklace': 620,
#  'heavier': 621,
#  'feeling': 622,
#  'fabulous': 623,
#  'pleat': 624,
#  'imagine': 625,
#  'three': 626,
#  'live': 627,
#  'past': 628,
#  'mean': 629,
#  'fantastic': 630,
#  'pulled': 631,
#  'noticed': 632,
#  'waistband': 633,
#  'anyone': 634,
#  'gold': 635,
#  'husband': 636,
#  'reading': 637,
#  'tummy': 638,
#  'pic': 639,
#  'chic': 640,
#  'showing': 641,
#  'seen': 642,
#  'whole': 643,
#  'rise': 644,
#  'stitching': 645,
#  'transition': 646,
#  'unless': 647,
#  'meant': 648,
#  'tent': 649,
#  'holiday': 650,
#  'styling': 651,
#  'v': 652,
#  'cuff': 653,
#  'strange': 654,
#  'leather': 655,
#  'butt': 656,
#  'old': 657,
#  'match': 658,
#  'coverage': 659,
#  'foot': 660,
#  'belly': 661,
#  'comfort': 662,
#  'event': 663,
#  'running': 664,
#  'generally': 665,
#  'snag': 666,
#  'sewn': 667,
#  'rest': 668,
#  'shade': 669,
#  'lighter': 670,
#  'excellent': 671,
#  'let': 672,
#  'please': 673,
#  'scratchy': 674,
#  'p': 675,
#  'portion': 676,
#  'height': 677,
#  'believe': 678,
#  'dinner': 679,
#  'chance': 680,
#  'clingy': 681,
#  'glove': 682,
#  'pregnant': 683,
#  'done': 684,
#  'relaxed': 685,
#  'frumpy': 686,
#  'caught': 687,
#  'stand': 688,
#  'maxi': 689,
#  'difficult': 690,
#  'wider': 691,
#  'ago': 692,
#  'arent': 693,
#  'evening': 694,
#  'beach': 695,
#  'daughter': 696,
#  'silhouette': 697,
#  'airy': 698,
#  'finding': 699,
#  'bag': 700,
#  'care': 701,
#  'tucked': 702,
#  'edge': 703,
#  'forgiving': 704,
#  'solid': 705,
#  'plenty': 706,
#  'money': 707,
#  'house': 708,
#  'description': 709,
#  'u': 710,
#  'hug': 711,
#  'slender': 712,
#  'expensive': 713,
#  'flaw': 714,
#  'dot': 715,
#  'simply': 716,
#  'keeper': 717,
#  'mid': 718,
#  'clean': 719,
#  'hour': 720,
#  'everyone': 721,
#  'chested': 722,
#  'tailored': 723,
#  'shrink': 724,
#  'move': 725,
#  'stomach': 726,
#  'prettier': 727,
#  'surprise': 728,
#  'camisole': 729,
#  'stock': 730,
#  'note': 731,
#  'guess': 732,
#  'b': 733,
#  'life': 734,
#  'silky': 735,
#  'wow': 736,
#  'friend': 737,
#  'cooler': 738,
#  'shoe': 739,
#  'coral': 740,
#  'adore': 741,
#  'website': 742,
#  'ag': 743,
#  'opening': 744,
#  'given': 745,
#  'natural': 746,
#  'snap': 747,
#  'despite': 748,
#  'structured': 749,
#  'hanging': 750,
#  'wedge': 751,
#  'plaid': 752,
#  'send': 753,
#  'sack': 754,
#  'yesterday': 755,
#  'purchasing': 756,
#  'uncomfortable': 757,
#  'tone': 758,
#  'etc': 759,
#  'considering': 760,
#  'originally': 761,
#  'dressing': 762,
#  'garment': 763,
#  'pencil': 764,
#  'average': 765,
#  'plain': 766,
#  'pop': 767,
#  'disappointing': 768,
#  'swingy': 769,
#  'recently': 770,
#  'beading': 771,
#  'oh': 772,
#  'afraid': 773,
#  'wrap': 774,
#  'shapeless': 775,
#  'layered': 776,
#  'pay': 777,
#  'flowing': 778,
#  'sit': 779,
#  'pas': 780,
#  'pricey': 781,
#  'hanger': 782,
#  'poor': 783,
#  'swimming': 784,
#  'scarf': 785,
#  'tend': 786,
#  'sent': 787,
#  'combination': 788,
#  'c': 789,
#  'minute': 790,
#  'stick': 791,
#  'sweet': 792,
#  'stated': 793,
#  'polyester': 794,
#  'start': 795,
#  'pale': 796,
#  'coming': 797,
#  'receive': 798,
#  'twice': 799,
#  'head': 800,
#  'stretched': 801,
#  'okay': 802,
#  'everyday': 803,
#  'section': 804,
#  'consider': 805,
#  'throughout': 806,
#  'supposed': 807,
#  'tuck': 808,
#  'movement': 809,
#  'designer': 810,
#  'flatter': 811,
#  'cuter': 812,
#  'turtleneck': 813,
#  'machine': 814,
#  'package': 815,
#  'crazy': 816,
#  'tighter': 817,
#  'picked': 818,
#  'trim': 819,
#  'difference': 820,
#  'round': 821,
#  'hoped': 822,
#  'hesitant': 823,
#  'bell': 824,
#  'warmer': 825,
#  'water': 826,
#  'fence': 827,
#  'shrunk': 828,
#  'poncho': 829,
#  'th': 830,
#  'w': 831,
#  'billowy': 832,
#  'designed': 833,
#  'attractive': 834,
#  'choice': 835,
#  'embroidered': 836,
#  'crop': 837,
#  'velvet': 838,
#  'moss': 839,
#  'effect': 840,
#  'thrilled': 841,
#  'feature': 842,
#  'beige': 843,
#  'bother': 844,
#  'literally': 845,
#  'unusual': 846,
#  'taking': 847,
#  'likely': 848,
#  'shaped': 849,
#  'comment': 850,
#  'chose': 851,
#  'near': 852,
#  'change': 853,
#  'multiple': 854,
#  'appear': 855,
#  'taken': 856,
#  'careful': 857,
#  'unlike': 858,
#  'overly': 859,
#  'notice': 860,
#  'comfortably': 861,
#  'xsp': 862,
#  'fix': 863,
#  'roll': 864,
#  'mostly': 865,
#  'beauty': 866,
#  'noted': 867,
#  'waistline': 868,
#  'structure': 869,
#  'whether': 870,
#  'sloppy': 871,
#  'rolled': 872,
#  'romantic': 873,
#  'construction': 874,
#  'combo': 875,
#  'outside': 876,
#  'hate': 877,
#  'weigh': 878,
#  'strapless': 879,
#  'blend': 880,
#  'seeing': 881,
#  'trouser': 882,
#  'panel': 883,
#  'pulling': 884,
#  'carry': 885,
#  'attached': 886,
#  'wine': 887,
#  'muted': 888,
#  'terrible': 889,
#  'paid': 890,
#  'wouldve': 891,
#  'negative': 892,
#  'pleasantly': 893,
#  'upon': 894,
#  'attention': 895,
#  'boyfriend': 896,
#  'date': 897,
#  'support': 898,
#  'alone': 899,
#  'gal': 900,
#  'dream': 901,
#  'bump': 902,
#  'disappoint': 903,
#  'bow': 904,
#  'suggest': 905,
#  'breast': 906,
#  'surprisingly': 907,
#  'lost': 908,
#  'chino': 909,
#  'trip': 910,
#  'set': 911,
#  'covered': 912,
#  'turquoise': 913,
#  'youll': 914,
#  'sending': 915,
#  'pajama': 916,
#  'exception': 917,
#  'worry': 918,
#  'initially': 919,
#  'later': 920,
#  'nicer': 921,
#  'walk': 922,
#  'wonderfully': 923,
#  'quickly': 924,
#  'vibe': 925,
#  'awful': 926,
#  'giving': 927,
#  'gap': 928,
#  'overwhelming': 929,
#  'thinner': 930,
#  'calf': 931,
#  'cling': 932,
#  'boob': 933,
#  'adjustable': 934,
#  'mom': 935,
#  'flimsy': 936,
#  'hemmed': 937,
#  'compared': 938,
#  'statement': 939,
#  'vintage': 940,
#  'currently': 941,
#  'concerned': 942,
#  'bathing': 943,
#  'christmas': 944,
#  'whim': 945,
#  'olive': 946,
#  'jersey': 947,
#  'rayon': 948,
#  'become': 949,
#  'entire': 950,
#  'sleeveless': 951,
#  'flair': 952,
#  'interest': 953,
#  'showed': 954,
#  'pear': 955,
#  'busted': 956,
#  'shot': 957,
#  'tan': 958,
#  'honestly': 959,
#  'particularly': 960,
#  'shopping': 961,
#  'errand': 962,
#  'dd': 963,
#  'con': 964,
#  'breezy': 965,
#  'thank': 966,
#  'peach': 967,
#  'trouble': 968,
#  'cloth': 969,
#  'thanks': 970,
#  'appreciate': 971,
#  'armpit': 972,
#  'sits': 973,
#  'turned': 974,
#  'tied': 975,
#  'winner': 976,
#  'closure': 977,
#  'hook': 978,
#  'wrinkled': 979,
#  'early': 980,
#  'mix': 981,
#  'behind': 982,
#  'xxsp': 983,
#  'leave': 984,
#  'swimsuit': 985,
#  'saying': 986,
#  'brighter': 987,
#  'faded': 988,
#  'cleavage': 989,
#  'apart': 990,
#  'bulk': 991,
#  'cord': 992,
#  'rack': 993,
#  'bc': 994,
#  'perfection': 995,
#  'drawn': 996,
#  'hopefully': 997,
#  'moment': 998,
#  'gift': 999,
#  'falling': 1000,
#  ...}

# %%
len(tokenizer.word_index)
# Out:
# 11994

# %% [markdown]
# ### Converting tokens to numeric

# %%
X_num_tokens = tokenizer.texts_to_sequences(X)
X_num_tokens
# Out:
# [[175, 408, 735, 515, 25],
#  [5,
#   1,
#   1392,
#   50,
#   1065,
#   152,
#   58,
#   12,
#   222,
#   994,
#   320,
#   13,
#   17,
#   78,
#   994,
#   41,
#   28,
#   41,
#   5,
#   36,
#   164,
#   18,
#   209,
#   13,
#   94,
#   76,
#   1132,
#   327,
#   601,
#   41],
#  [138,
#   391,
#   1,
#   16,
#   131,
#   40,
#   919,
#   17,
#   41,
#   15,
#   162,
#   4,
#   153,
#   5502,
#   15,
#   15,
#   503,
#   64,
#   3,
#   578,
#   1748,
#   41,
#   47,
#   173,
#   6,
#   520,
#   25,
#   2,
#   178,
#   93,
#   520,
#   88,
#   297,
#   399,
#   554,
#   369,
#   3794,
#   297,
#   1523,
#   1524,
#   80,
#   714,
#   3794,
#   297,
#   667,
#   2709,
#   337,
#   789],
#  [5, 5, 5, 445, 197, 1052, 623, 224, 91, 10, 60, 405, 11, 139],
#  [32, 21, 364, 934, 98, 313, 19, 36, 10, 180, 951, 125, 23, 280, 5, 32],
#  [5,
#   1615,
#   1616,
#   1,
#   20,
#   3,
#   41,
#   660,
#   233,
#   59,
#   10,
#   318,
#   1,
#   50,
#   815,
#   123,
#   1,
#   48,
#   43,
#   240,
#   1995,
#   15,
#   307,
#   3,
#   1810,
#   1374,
#   3112,
#   6964,
#   48,
#   13,
#   249,
#   373,
#   1950,
#   763,
#   5,
#   8,
#   572,
#   72,
#   3,
#   40,
#   265,
#   1],
#  [6965,
#   2444,
#   1095,
#   350,
#   6966,
#   77,
#   13,
#   9,
#   7,
#   106,
#   58,
#   1001,
#   148,
#   2226,
#   6967,
#   8,
#   796,
#   1095,
#   8,
#   16,
#   136,
#   1042,
#   6968,
#   6969,
#   344,
#   5503,
#   18,
#   409,
#   1095,
#   53,
#   1095,
#   6970,
#   4,
#   1053,
#   79,
#   41,
#   250,
#   6971,
#   101,
#   229,
#   6972,
#   243,
#   6973,
#   57,
#   48,
#   6974,
#   344,
#   411,
#   4684],
#  [17,
#   2445,
#   58,
#   1001,
#   568,
#   1563,
#   236,
#   115,
#   486,
#   6,
#   125,
#   48,
#   57,
#   243,
#   148,
#   8,
#   16,
#   27,
#   1427,
#   1479,
#   148,
#   23,
#   764,
#   48,
#   365,
#   57,
#   759,
#   6975,
#   30,
#   65,
#   62,
#   43,
#   144,
#   68,
#   41,
#   39,
#   30,
#   116,
#   79,
#   334,
#   411,
#   2832,
#   6976,
#   920,
#   161,
#   130,
#   8,
#   345,
#   341,
#   1095,
#   1393,
#   4],
#  [5, 1, 59, 60, 53, 37, 18, 276, 147, 17, 4, 21, 288, 162, 52, 952, 72],
#  [12,
#   99,
#   17,
#   41,
#   54,
#   155,
#   36,
#   194,
#   43,
#   316,
#   10,
#   53,
#   122,
#   52,
#   1,
#   342,
#   412,
#   451,
#   564,
#   216,
#   41,
#   2,
#   89,
#   276,
#   3,
#   88,
#   5,
#   64,
#   1,
#   582,
#   40,
#   5,
#   1564,
#   174,
#   14,
#   188],
#  [1,
#   37,
#   15,
#   2710,
#   337,
#   189,
#   37,
#   17,
#   1259,
#   316,
#   2,
#   88,
#   31,
#   6,
#   9,
#   55,
#   369,
#   51,
#   884,
#   1196,
#   1708,
#   14,
#   50,
#   237,
#   114,
#   944,
#   1,
#   211,
#   1749,
#   165,
#   114,
#   24],
#  [1, 995, 50, 21],
#  [152,
#   6977,
#   111,
#   2446,
#   4685,
#   1996,
#   628,
#   73,
#   6978,
#   526,
#   562,
#   3,
#   1288,
#   13,
#   51,
#   56,
#   1,
#   311,
#   66,
#   324,
#   2955,
#   657,
#   52,
#   46,
#   324,
#   705,
#   14,
#   658,
#   1096,
#   14,
#   149,
#   239,
#   95,
#   209,
#   3,
#   2711],
#  [28,
#   74,
#   53,
#   68,
#   5504,
#   1132,
#   1,
#   70,
#   844,
#   315,
#   48,
#   676,
#   6979,
#   1951,
#   53,
#   2,
#   4182,
#   120,
#   135,
#   221,
#   120,
#   465,
#   520,
#   13,
#   165,
#   664,
#   65,
#   330,
#   50,
#   64,
#   263,
#   6980,
#   12,
#   267,
#   209],
#  [27,
#   835,
#   650,
#   1650,
#   7,
#   36,
#   6981,
#   209,
#   1408,
#   87,
#   590,
#   4686,
#   1650,
#   4,
#   15,
#   2,
#   23,
#   59,
#   4,
#   15,
#   147,
#   611,
#   37,
#   15,
#   251,
#   147,
#   94,
#   4,
#   579,
#   45,
#   65,
#   232,
#   1,
#   46,
#   14,
#   889,
#   406,
#   2363,
#   305,
#   14,
#   6,
#   297,
#   48,
#   42,
#   1043,
#   578],
#  [299,
#   815,
#   131,
#   2,
#   1301,
#   64,
#   539,
#   231,
#   375,
#   256,
#   417,
#   45,
#   61,
#   15,
#   113,
#   119,
#   51,
#   246,
#   64,
#   539,
#   13,
#   71,
#   88,
#   45,
#   423,
#   132,
#   229,
#   16,
#   27,
#   1002,
#   14,
#   50,
#   8,
#   23,
#   66,
#   391,
#   54,
#   327,
#   201],
#  [31,
#   8,
#   27,
#   214,
#   744,
#   33,
#   36,
#   164,
#   73,
#   361,
#   214,
#   744,
#   4,
#   45,
#   278,
#   272,
#   361,
#   98,
#   624,
#   54,
#   2164,
#   49,
#   625,
#   3,
#   21,
#   9,
#   377,
#   765,
#   677,
#   591,
#   176,
#   9,
#   63],
#  [299,
#   680,
#   143,
#   222,
#   194,
#   816,
#   143,
#   2712,
#   90,
#   433,
#   4687,
#   86,
#   57,
#   432,
#   89,
#   1220,
#   719,
#   13,
#   1500,
#   3795,
#   23,
#   2,
#   11,
#   244,
#   19,
#   10,
#   702,
#   154,
#   68,
#   507],
#  [21, 75, 362, 266, 40, 23, 467, 392, 121, 9, 63, 38, 1016, 447, 15, 2, 11],
#  [5,
#   9,
#   55,
#   1564,
#   1,
#   127,
#   210,
#   171,
#   3,
#   6,
#   336,
#   211,
#   2534,
#   12,
#   15,
#   722,
#   6,
#   1,
#   565,
#   314,
#   21,
#   9,
#   3291,
#   1564,
#   19,
#   17,
#   862,
#   36,
#   19],
#  [526,
#   41,
#   13,
#   60,
#   41,
#   122,
#   18,
#   43,
#   1017,
#   418,
#   863,
#   2,
#   178,
#   12,
#   683,
#   2956,
#   47,
#   2602,
#   313,
#   98,
#   24,
#   1590,
#   27,
#   2957,
#   565,
#   314],
#  [12,
#   2447,
#   103,
#   1,
#   124,
#   836,
#   79,
#   149,
#   14,
#   49,
#   6982,
#   18,
#   1080,
#   1148,
#   71,
#   3519,
#   50,
#   13,
#   165,
#   76,
#   4,
#   379,
#   30,
#   65,
#   450,
#   71,
#   60,
#   373,
#   8,
#   393,
#   72,
#   191,
#   48,
#   676,
#   50,
#   1591,
#   160,
#   114,
#   24,
#   2364,
#   1676,
#   103,
#   317,
#   46,
#   94,
#   548,
#   158,
#   5505],
#  [112,
#   3,
#   1054,
#   651,
#   104,
#   337,
#   375,
#   82,
#   483,
#   104,
#   337,
#   33,
#   147,
#   104,
#   337,
#   533,
#   1565,
#   462,
#   1564,
#   55,
#   9,
#   369,
#   274,
#   603,
#   88,
#   119,
#   188,
#   3,
#   9,
#   7,
#   1289,
#   371,
#   309,
#   12,
#   155,
#   152,
#   210,
#   573],
#  [26,
#   18,
#   1,
#   2,
#   239,
#   18,
#   138,
#   528,
#   63,
#   36,
#   677,
#   7,
#   1,
#   12,
#   3,
#   5,
#   69,
#   49,
#   9,
#   55,
#   369,
#   529,
#   295],
#  [5,
#   32,
#   112,
#   133,
#   194,
#   155,
#   32,
#   1,
#   161,
#   10,
#   7,
#   1,
#   117,
#   274,
#   10,
#   180,
#   28,
#   274,
#   156,
#   313,
#   24,
#   5506,
#   86,
#   751,
#   64,
#   39,
#   10,
#   353,
#   857,
#   137,
#   585,
#   95,
#   235,
#   55,
#   7,
#   173,
#   11,
#   604,
#   197,
#   10],
#  [105,
#   31,
#   70,
#   16,
#   9,
#   43,
#   1,
#   82,
#   33,
#   47,
#   12,
#   4183,
#   31,
#   660,
#   928,
#   98,
#   34,
#   691,
#   9,
#   186,
#   7,
#   1,
#   355,
#   290,
#   265,
#   12,
#   59,
#   33,
#   1018,
#   2,
#   108,
#   38],
#  [1019,
#   35,
#   266,
#   2535,
#   498,
#   321,
#   1375,
#   266,
#   3,
#   76,
#   4,
#   66,
#   9,
#   44,
#   4184,
#   62,
#   198,
#   317,
#   43,
#   130,
#   166,
#   95,
#   266,
#   62,
#   69,
#   117,
#   198,
#   375,
#   6983,
#   34,
#   188,
#   137,
#   117,
#   2448,
#   377,
#   626,
#   273,
#   921,
#   2,
#   124,
#   6984,
#   137,
#   62,
#   97,
#   51,
#   1044,
#   3520],
#  [8,
#   1097,
#   302,
#   329,
#   308,
#   107,
#   34,
#   393,
#   284,
#   152,
#   328,
#   16,
#   68,
#   14,
#   261,
#   63,
#   46,
#   27,
#   166,
#   809,
#   48,
#   194,
#   419],
#  [399,
#   6985,
#   32,
#   60,
#   126,
#   139,
#   262,
#   20,
#   165,
#   6986,
#   6987,
#   6988,
#   69,
#   1540,
#   159,
#   32,
#   442,
#   1459],
#  [35,
#   172,
#   394,
#   1409,
#   1410,
#   9,
#   29,
#   8,
#   1460,
#   2,
#   30,
#   430,
#   204,
#   226,
#   72,
#   395,
#   455,
#   928,
#   291,
#   54,
#   611,
#   54,
#   19,
#   494,
#   7,
#   174,
#   729,
#   641,
#   188,
#   81,
#   18,
#   1,
#   212,
#   71,
#   142,
#   87,
#   2,
#   102,
#   266],
#  [311, 66, 57, 1045, 1020, 837, 34, 812, 106, 5],
#  [320,
#   13,
#   745,
#   57,
#   462,
#   9,
#   78,
#   106,
#   34,
#   812,
#   413,
#   987,
#   2,
#   21,
#   837,
#   26,
#   365,
#   73,
#   1045,
#   318,
#   236,
#   37,
#   15,
#   885,
#   6989,
#   661,
#   433,
#   5507,
#   116,
#   259,
#   556],
#  [57, 51, 108, 106, 1133, 117, 392, 1750],
#  [17,
#   425,
#   692,
#   491,
#   267,
#   24,
#   168,
#   257,
#   1008,
#   2,
#   34,
#   258,
#   46,
#   487,
#   4688,
#   327,
#   488,
#   455,
#   3113,
#   3114,
#   487,
#   3113,
#   732,
#   1121,
#   845,
#   55,
#   7,
#   186,
#   75,
#   142,
#   434,
#   244,
#   23,
#   55,
#   369,
#   66,
#   3292,
#   42,
#   92,
#   71,
#   3,
#   219,
#   890,
#   94,
#   114,
#   24],
#  [1878,
#   1,
#   8,
#   11,
#   14,
#   75,
#   22,
#   233,
#   43,
#   36,
#   600,
#   1066,
#   94,
#   117,
#   210,
#   188,
#   161,
#   98,
#   928,
#   114,
#   125,
#   1260,
#   196,
#   6,
#   620,
#   223,
#   75,
#   26],
#  [375, 745, 462, 9, 56, 58, 945, 5, 5],
#  [25, 48, 4185, 346, 263, 3, 2713, 80, 63, 40, 48, 433, 126, 6],
#  [17,
#   15,
#   4,
#   47,
#   935,
#   4,
#   136,
#   311,
#   1271,
#   303,
#   117,
#   3293,
#   95,
#   289,
#   9,
#   1244,
#   2227,
#   5508,
#   935,
#   9,
#   277,
#   225,
#   38,
#   180,
#   17,
#   368,
#   76,
#   134],
#  [75, 26, 172, 358, 205, 1176, 31, 18, 30, 183],
#  [11, 141, 6, 365, 9, 26, 283, 403, 1811, 38, 21, 551, 24, 27, 67, 96, 254],
#  [50, 191, 11, 38, 118, 40, 1211, 340, 8, 149, 310, 128, 3115, 1677],
#  [29,
#   6,
#   191,
#   3,
#   1997,
#   28,
#   162,
#   47,
#   153,
#   2,
#   88,
#   367,
#   135,
#   317,
#   587,
#   211,
#   2047,
#   64,
#   28,
#   13,
#   4],
#  [829,
#   26,
#   5,
#   752,
#   1067,
#   80,
#   8,
#   9,
#   7,
#   4186,
#   534,
#   125,
#   23,
#   813,
#   38,
#   764,
#   48,
#   340,
#   5,
#   9,
#   95,
#   864,
#   73,
#   292,
#   11,
#   159],
#  [112,
#   3796,
#   2603,
#   70,
#   552,
#   75,
#   220,
#   16,
#   220,
#   130,
#   14,
#   7,
#   1812,
#   760,
#   185,
#   37,
#   922,
#   120,
#   708,
#   462,
#   33,
#   17,
#   4,
#   27,
#   448,
#   2,
#   400,
#   375,
#   146,
#   68,
#   251,
#   612,
#   220,
#   14,
#   263,
#   801,
#   69,
#   510,
#   562,
#   491,
#   8,
#   9,
#   86,
#   2449,
#   213,
#   1134,
#   107,
#   715],
#  [56,
#   326,
#   370,
#   52,
#   25,
#   21,
#   335,
#   109,
#   78,
#   90,
#   1751,
#   48,
#   154,
#   77,
#   1411,
#   367,
#   98,
#   18,
#   1016,
#   1221,
#   766,
#   195,
#   3115,
#   1677,
#   52,
#   665,
#   10,
#   15,
#   2,
#   23,
#   200,
#   24,
#   74],
#  [28,
#   300,
#   78,
#   2,
#   90,
#   97,
#   18,
#   116,
#   42,
#   452,
#   437,
#   30,
#   88,
#   299,
#   24,
#   58,
#   17,
#   251,
#   4,
#   92,
#   103,
#   11,
#   6],
#  [5, 6, 10, 91, 232, 539, 10, 91, 14, 1081, 2365, 260, 71, 140, 25],
#  [25, 31, 63, 67, 62, 21],
#  [35, 19, 95, 423, 212, 75, 172, 8, 16, 767],
#  [16,
#   26,
#   6,
#   310,
#   470,
#   1709,
#   6,
#   29,
#   191,
#   169,
#   123,
#   139,
#   2048,
#   42,
#   12,
#   381,
#   451,
#   6,
#   47,
#   2,
#   23,
#   15,
#   200,
#   891,
#   2,
#   108,
#   71,
#   75,
#   255],
#  [26,
#   6,
#   646,
#   263,
#   84,
#   95,
#   2,
#   23,
#   27,
#   149,
#   25,
#   56,
#   58,
#   3,
#   208,
#   8,
#   331,
#   3,
#   268,
#   8,
#   1998,
#   13,
#   9,
#   34,
#   108,
#   3521,
#   171,
#   8,
#   848,
#   13,
#   82],
#  [175,
#   5,
#   1709,
#   195,
#   200,
#   241,
#   52,
#   208,
#   91,
#   12,
#   400,
#   15,
#   19,
#   2,
#   316,
#   10,
#   329,
#   6],
#  [5, 8, 72, 31, 666, 263],
#  [22,
#   25,
#   32,
#   846,
#   1177,
#   363,
#   529,
#   612,
#   98,
#   104,
#   763,
#   90,
#   3522,
#   154,
#   77,
#   100,
#   109,
#   886,
#   109,
#   4187,
#   98,
#   363,
#   207,
#   7,
#   363,
#   1437,
#   2049,
#   953,
#   234,
#   18,
#   30,
#   1411,
#   464,
#   474,
#   661,
#   1188,
#   230,
#   23,
#   684,
#   184,
#   297,
#   565,
#   1188,
#   157,
#   153,
#   629,
#   360,
#   6990],
#  [27,
#   6,
#   477,
#   30,
#   448,
#   1678,
#   435,
#   12,
#   2050,
#   149,
#   50,
#   846,
#   70,
#   9,
#   11,
#   478,
#   613,
#   551,
#   24,
#   296,
#   178,
#   281,
#   195,
#   14,
#   293,
#   1617,
#   56,
#   74,
#   150,
#   605,
#   1222,
#   11,
#   825,
#   1618,
#   126,
#   136,
#   6,
#   250,
#   181,
#   161,
#   84,
#   6991,
#   140],
#  [255,
#   6,
#   152,
#   312,
#   25,
#   69,
#   59,
#   159,
#   149,
#   20,
#   288,
#   9,
#   11,
#   308,
#   264,
#   38,
#   47,
#   19,
#   2],
#  [683,
#   124,
#   13,
#   11,
#   1160,
#   150,
#   22,
#   2,
#   802,
#   1541,
#   898,
#   119,
#   13,
#   159,
#   733,
#   564,
#   216,
#   60,
#   373,
#   145,
#   898,
#   13,
#   642,
#   58,
#   13,
#   1197,
#   83,
#   2228,
#   181,
#   81,
#   25,
#   293,
#   4689,
#   46,
#   13,
#   3,
#   140,
#   251,
#   722,
#   569,
#   101],
#  [196, 2, 23, 105, 549, 24, 4188, 98, 3, 63, 9, 4690],
#  [42,
#   41,
#   36,
#   4,
#   2,
#   73,
#   7,
#   70,
#   1009,
#   36,
#   10,
#   290,
#   706,
#   2165,
#   1149,
#   93,
#   278,
#   4189,
#   80,
#   677,
#   45,
#   1057,
#   49,
#   461,
#   633,
#   9,
#   369,
#   16,
#   117,
#   4190,
#   301,
#   235,
#   973,
#   138,
#   845,
#   73,
#   2051,
#   1343,
#   20,
#   358,
#   198,
#   301,
#   606,
#   830],
#  [157,
#   127,
#   4191,
#   1566,
#   898,
#   3,
#   397,
#   91,
#   141,
#   10,
#   130,
#   166,
#   150,
#   64,
#   18,
#   2229,
#   50,
#   8,
#   27,
#   272,
#   1133,
#   52,
#   580,
#   24,
#   434,
#   117,
#   1525],
#  [1,
#   716,
#   29,
#   421,
#   256,
#   21,
#   154,
#   245,
#   10,
#   4,
#   15,
#   432,
#   161,
#   12,
#   233,
#   355,
#   73,
#   361,
#   19,
#   64,
#   3,
#   1245,
#   208,
#   1842,
#   24,
#   29,
#   100],
#  [580,
#   667,
#   15,
#   43,
#   257,
#   53,
#   434,
#   67,
#   553,
#   558,
#   982,
#   5509,
#   51,
#   434,
#   54,
#   5510,
#   300,
#   434,
#   580,
#   3,
#   25,
#   39,
#   5,
#   4191,
#   10,
#   91,
#   1394,
#   40,
#   733,
#   564,
#   83,
#   20,
#   142,
#   936,
#   170,
#   79,
#   898,
#   51,
#   733,
#   564,
#   13,
#   1290,
#   2109,
#   194,
#   434],
#  [770, 42, 92, 127, 1619, 158, 1710, 12, 201, 25, 43, 87, 304, 129, 98, 21],
#  [25, 32, 130, 166, 6, 128, 614, 8, 11, 86, 38, 5, 243, 20, 3523, 54],
#  [105, 6, 16, 201, 152, 92],
#  [29,
#   6,
#   406,
#   156,
#   1567,
#   330,
#   4691,
#   1711,
#   1098,
#   29,
#   393,
#   54,
#   155,
#   693,
#   328,
#   2230,
#   5511,
#   161,
#   14,
#   406],
#  [169,
#   541,
#   56,
#   3116,
#   12,
#   59,
#   387,
#   428,
#   12,
#   322,
#   79,
#   183,
#   52,
#   6,
#   28,
#   20,
#   387,
#   12,
#   155,
#   222,
#   221,
#   349,
#   25,
#   39,
#   28,
#   5512,
#   202,
#   6,
#   20,
#   3523,
#   499,
#   552,
#   143,
#   206,
#   49,
#   1438,
#   516,
#   123,
#   203,
#   14,
#   135,
#   59,
#   320,
#   258],
#  [5,
#   6,
#   411,
#   1161,
#   78,
#   4692,
#   4,
#   161,
#   113,
#   18,
#   3524,
#   148,
#   862,
#   4192,
#   40,
#   89,
#   13,
#   165,
#   37,
#   18,
#   33,
#   5,
#   36,
#   59,
#   3,
#   68,
#   41,
#   4,
#   52,
#   7,
#   174,
#   36,
#   122,
#   19,
#   170,
#   6,
#   9,
#   128,
#   22,
#   25,
#   6,
#   346],
#  [16,
#   105,
#   6,
#   78,
#   131,
#   5,
#   106,
#   22,
#   3117,
#   802,
#   106,
#   254,
#   468,
#   486,
#   39,
#   184,
#   137,
#   24,
#   398,
#   1620,
#   168,
#   10,
#   6,
#   690,
#   137,
#   982,
#   230,
#   6,
#   217,
#   181,
#   300],
#  [16,
#   131,
#   40,
#   1356,
#   654,
#   2,
#   330,
#   13,
#   3,
#   557,
#   475,
#   2,
#   906,
#   432,
#   1752,
#   790,
#   1679,
#   355,
#   96,
#   14,
#   29,
#   105,
#   199],
#  [6,
#   26,
#   4193,
#   3294,
#   849,
#   272,
#   3,
#   1879,
#   109,
#   2290,
#   53,
#   135,
#   4693,
#   13,
#   94,
#   160,
#   6,
#   596,
#   2166,
#   2366,
#   128,
#   14,
#   746,
#   6992,
#   127,
#   12,
#   500,
#   2231,
#   1017,
#   249,
#   104,
#   185,
#   1813,
#   14,
#   5513,
#   67,
#   2167,
#   366,
#   72],
#  [810,
#   160,
#   456,
#   837,
#   6,
#   154,
#   625,
#   13,
#   21,
#   634,
#   262,
#   327,
#   765,
#   677,
#   23,
#   1814,
#   6,
#   97,
#   7,
#   2604,
#   3118,
#   129,
#   14,
#   136,
#   7,
#   233,
#   75,
#   450,
#   2,
#   334,
#   176,
#   40,
#   2,
#   15,
#   257,
#   206,
#   440,
#   93,
#   6,
#   475,
#   67,
#   306,
#   188,
#   1150,
#   213],
#  [44,
#   304,
#   40,
#   23,
#   28,
#   478,
#   3,
#   34,
#   183,
#   14,
#   182,
#   135,
#   3,
#   757,
#   61,
#   94,
#   144,
#   296,
#   203,
#   14,
#   7,
#   90,
#   337,
#   68,
#   206,
#   61,
#   93,
#   1568,
#   60,
#   54,
#   1233,
#   183,
#   1621,
#   14,
#   858,
#   187,
#   151,
#   153,
#   148,
#   16,
#   23,
#   259,
#   57,
#   156,
#   1272,
#   2536,
#   556,
#   1773],
#  [5,
#   6,
#   116,
#   25,
#   3,
#   220,
#   69,
#   117,
#   306,
#   37,
#   18,
#   33,
#   4,
#   146,
#   723,
#   2,
#   2537,
#   1843,
#   2168,
#   1003,
#   301,
#   358,
#   3,
#   857],
#  [1197,
#   1,
#   126,
#   91,
#   58,
#   491,
#   56,
#   326,
#   131,
#   141,
#   1,
#   1651,
#   1526,
#   404,
#   34,
#   812,
#   782,
#   246,
#   60,
#   314,
#   9,
#   16,
#   66,
#   820,
#   72,
#   3,
#   583,
#   61,
#   97,
#   116,
#   90,
#   9,
#   16,
#   26,
#   182,
#   30,
#   515,
#   51,
#   324,
#   172,
#   218,
#   40,
#   1234,
#   678,
#   60,
#   123,
#   10],
#  [996,
#   587,
#   1952,
#   204,
#   32,
#   446,
#   56,
#   58,
#   41,
#   59,
#   32,
#   123,
#   14,
#   2538,
#   643,
#   20,
#   71,
#   26,
#   123,
#   14,
#   109,
#   672,
#   49,
#   71,
#   75,
#   26,
#   21,
#   13,
#   94,
#   1067,
#   4,
#   1844,
#   471,
#   850,
#   77,
#   327,
#   4,
#   709,
#   1109,
#   2367,
#   4,
#   113,
#   305,
#   41,
#   878,
#   99],
#  [13,
#   105,
#   1,
#   147,
#   45,
#   18,
#   182,
#   6,
#   65,
#   2,
#   89,
#   132,
#   202,
#   31,
#   629,
#   3,
#   263,
#   1009,
#   851,
#   181,
#   1,
#   13,
#   94,
#   411,
#   108,
#   2],
#  [337,
#   1652,
#   110,
#   112,
#   91,
#   156,
#   768,
#   161,
#   5,
#   80,
#   12,
#   207,
#   114,
#   115,
#   2169,
#   337,
#   210,
#   4194,
#   1680,
#   227],
#  [59,
#   4,
#   318,
#   15,
#   19,
#   6,
#   1246,
#   141,
#   55,
#   29,
#   1223,
#   146,
#   10,
#   803,
#   10,
#   18,
#   43,
#   1099,
#   18,
#   88,
#   864,
#   85],
#  [1,
#   255,
#   19,
#   141,
#   9,
#   84,
#   46,
#   27,
#   315,
#   101,
#   71,
#   1774,
#   611,
#   313,
#   100,
#   554,
#   934,
#   153,
#   282,
#   4,
#   2,
#   215,
#   60,
#   503,
#   392,
#   719,
#   466,
#   144,
#   54,
#   1344,
#   1,
#   2539,
#   1323,
#   1324,
#   84,
#   185,
#   1055,
#   24,
#   899,
#   161,
#   761,
#   2052,
#   10,
#   123],
#  [59,
#   41,
#   161,
#   1,
#   3,
#   227,
#   41,
#   56,
#   2,
#   12,
#   1,
#   164,
#   6993,
#   209,
#   937,
#   30,
#   3,
#   929,
#   1,
#   9,
#   421,
#   11,
#   393,
#   8,
#   308,
#   1010,
#   54,
#   394,
#   527,
#   1,
#   9,
#   2291,
#   388,
#   56,
#   58,
#   2292,
#   395,
#   1439,
#   77,
#   4694,
#   1592,
#   1125,
#   222,
#   384,
#   10,
#   292,
#   6994],
#  [105, 6, 11, 80, 25, 191, 22, 31],
#  [668,
#   151,
#   73,
#   8,
#   1912,
#   295,
#   17,
#   308,
#   401,
#   8,
#   3525,
#   308,
#   3797,
#   542,
#   617,
#   102,
#   149,
#   11,
#   5,
#   171,
#   102,
#   157,
#   642,
#   102,
#   26,
#   30,
#   522,
#   101,
#   45,
#   313,
#   464,
#   3,
#   279,
#   289,
#   559,
#   3,
#   5514,
#   3295,
#   6995,
#   765,
#   289,
#   121,
#   101,
#   197,
#   550,
#   1953,
#   652],
#  [82,
#   6,
#   2540,
#   58,
#   350,
#   498,
#   46,
#   408,
#   2293,
#   107,
#   8,
#   191,
#   143,
#   29,
#   349,
#   6996,
#   886,
#   96,
#   1569,
#   747,
#   6997,
#   11,
#   118,
#   184,
#   171,
#   61,
#   156,
#   6998,
#   1999,
#   143,
#   93,
#   39,
#   9,
#   11,
#   729,
#   118,
#   158,
#   13,
#   227,
#   41,
#   4,
#   380,
#   65,
#   96,
#   6999],
#  [169,
#   32,
#   615,
#   53,
#   2,
#   89,
#   3,
#   816,
#   5,
#   39,
#   2232,
#   32,
#   142,
#   104,
#   117,
#   10,
#   306,
#   188,
#   79,
#   1082,
#   287,
#   2294,
#   31,
#   64,
#   2958,
#   287,
#   10,
#   264,
#   229,
#   264,
#   32,
#   467,
#   826,
#   296,
#   392,
#   997,
#   2000,
#   287,
#   4195,
#   36,
#   215,
#   7,
#   469,
#   98,
#   234,
#   18,
#   4695],
#  [16,
#   357,
#   7,
#   3,
#   9,
#   61,
#   90,
#   377,
#   3,
#   7000,
#   278,
#   34,
#   2833,
#   588,
#   20,
#   134,
#   9,
#   7,
#   1542,
#   24,
#   59,
#   10,
#   47,
#   33,
#   42,
#   47,
#   123,
#   31,
#   93,
#   520,
#   134,
#   213,
#   66,
#   9,
#   440,
#   3,
#   21,
#   31,
#   27,
#   1046,
#   142,
#   406,
#   28,
#   1815,
#   530,
#   946,
#   107,
#   8],
#  [56,
#   92,
#   804,
#   59,
#   907,
#   4,
#   73,
#   2,
#   182,
#   87,
#   270,
#   2450,
#   2451,
#   107,
#   130,
#   107,
#   206,
#   496,
#   86,
#   310,
#   49,
#   97,
#   388,
#   250,
#   160,
#   551,
#   226,
#   164,
#   73,
#   508,
#   44,
#   41,
#   304,
#   282,
#   4],
#  [1622,
#   1621,
#   49,
#   9,
#   116,
#   90,
#   1954,
#   9,
#   123,
#   21,
#   56,
#   53,
#   58,
#   59,
#   1004,
#   117,
#   41,
#   97,
#   257,
#   4196,
#   24,
#   77,
#   334,
#   13,
#   40,
#   123,
#   14,
#   588,
#   70,
#   9,
#   63,
#   7,
#   1,
#   173,
#   71,
#   140,
#   7,
#   588,
#   9,
#   11,
#   13,
#   83,
#   168,
#   4696,
#   99,
#   963,
#   7001],
#  [16, 26, 110, 257, 17, 334, 41, 217, 312, 198, 3, 21, 309],
#  [28,
#   6,
#   78,
#   1623,
#   401,
#   8,
#   321,
#   60,
#   56,
#   2,
#   215,
#   4197,
#   210,
#   24,
#   18,
#   30,
#   43,
#   98,
#   18,
#   30,
#   44,
#   4197,
#   173,
#   723,
#   9,
#   136,
#   14,
#   6,
#   3,
#   131,
#   210,
#   28,
#   838,
#   286,
#   436],
#  [5,
#   26,
#   84,
#   1,
#   20,
#   262,
#   66,
#   543,
#   191,
#   80,
#   177,
#   21,
#   660,
#   18,
#   323,
#   789,
#   147,
#   42,
#   4,
#   2,
#   23,
#   317,
#   690,
#   578,
#   31,
#   79,
#   170,
#   19,
#   1,
#   10,
#   2541,
#   7002,
#   2170,
#   2959],
#  [6,
#   34,
#   727,
#   597,
#   734,
#   90,
#   129,
#   441,
#   128,
#   551,
#   907,
#   21,
#   94,
#   44,
#   104,
#   49,
#   170,
#   1083,
#   9,
#   14,
#   3,
#   183,
#   71,
#   49,
#   2,
#   239,
#   33,
#   135,
#   176,
#   146,
#   68,
#   4,
#   356,
#   13,
#   168,
#   282,
#   4],
#  [32,
#   687,
#   476,
#   29,
#   5,
#   119,
#   80,
#   8,
#   19,
#   292,
#   84,
#   86,
#   57,
#   217,
#   69,
#   77,
#   2053,
#   32,
#   118,
#   61,
#   438,
#   144,
#   40,
#   38,
#   48,
#   44,
#   59,
#   501,
#   300,
#   1212,
#   447,
#   12,
#   71,
#   827,
#   12,
#   114,
#   160,
#   3,
#   1775,
#   1068,
#   11,
#   46,
#   32,
#   29],
#  [82,
#   6,
#   78,
#   169,
#   574,
#   527,
#   67,
#   235,
#   141,
#   14,
#   5,
#   62,
#   37,
#   174,
#   2605,
#   173,
#   9,
#   39,
#   105,
#   652,
#   254,
#   2368,
#   55,
#   173,
#   72,
#   1712,
#   620,
#   6,
#   5515,
#   550,
#   8,
#   1543,
#   839,
#   59,
#   49,
#   2293,
#   542,
#   153,
#   1011,
#   13,
#   253,
#   190,
#   758,
#   83,
#   71,
#   630,
#   1376],
#  [59,
#   10,
#   47,
#   28,
#   15,
#   2,
#   592,
#   79,
#   119,
#   3,
#   21,
#   5,
#   587,
#   1952,
#   1,
#   6,
#   649,
#   696,
#   133,
#   115,
#   229,
#   293,
#   110,
#   4697,
#   114,
#   24],
#  [321, 168, 6, 192, 53, 26, 257, 775, 898, 142, 68, 24, 1880, 97, 111],
#  [117,
#   193,
#   25,
#   6,
#   803,
#   10,
#   28,
#   6,
#   865,
#   26,
#   137,
#   169,
#   97,
#   359,
#   109,
#   78,
#   83,
#   137,
#   411,
#   2452,
#   537,
#   287,
#   179,
#   65,
#   32,
#   2,
#   379,
#   276,
#   852,
#   535,
#   85,
#   13,
#   183,
#   2606,
#   806,
#   121,
#   94,
#   25,
#   32,
#   186,
#   7,
#   916,
#   6,
#   114,
#   24],
#  [112,
#   194,
#   155,
#   254,
#   34,
#   465,
#   3798,
#   124,
#   81,
#   16,
#   25,
#   183,
#   123,
#   10,
#   306,
#   188,
#   1273,
#   566,
#   12,
#   3,
#   641,
#   1624,
#   304],
#  [152,
#   318,
#   18,
#   30,
#   4,
#   56,
#   106,
#   176,
#   28,
#   15,
#   436,
#   748,
#   30,
#   65,
#   71,
#   9,
#   11,
#   474,
#   714,
#   23,
#   28,
#   187,
#   32,
#   3799,
#   1291,
#   230,
#   32,
#   240,
#   273,
#   216,
#   147,
#   210,
#   160,
#   510,
#   71,
#   11,
#   32,
#   5,
#   496,
#   8],
#  [6,
#   175,
#   421,
#   82,
#   86,
#   20,
#   169,
#   2,
#   18,
#   65,
#   104,
#   678,
#   9,
#   108,
#   61,
#   9,
#   11,
#   243,
#   23,
#   1178,
#   9,
#   191,
#   5],
#  [14, 186, 369, 70, 152, 21, 6, 238, 81, 47, 134, 1110],
#  [37, 65, 97, 376, 41, 185, 40, 327, 591],
#  [28,
#   128,
#   32,
#   3113,
#   1625,
#   3113,
#   8,
#   1035,
#   107,
#   104,
#   1625,
#   107,
#   237,
#   94,
#   602,
#   529,
#   134,
#   71,
#   1246,
#   866,
#   3119,
#   1593,
#   244,
#   7,
#   3296,
#   7003,
#   113,
#   227,
#   3120],
#  [321,
#   168,
#   29,
#   32,
#   8,
#   1625,
#   136,
#   187,
#   151,
#   229,
#   37,
#   15,
#   39,
#   61,
#   44,
#   371,
#   309,
#   517,
#   489,
#   29,
#   11,
#   46,
#   70,
#   2],
#  [17,
#   472,
#   322,
#   318,
#   1412,
#   37,
#   88,
#   342,
#   23,
#   1814,
#   29,
#   8,
#   5,
#   1544,
#   752,
#   315,
#   513,
#   470,
#   653,
#   585,
#   250,
#   382,
#   9,
#   448,
#   362,
#   16,
#   43,
#   206,
#   380,
#   6,
#   209,
#   24,
#   2171,
#   50,
#   101],
#  [32,
#   359,
#   295,
#   1623,
#   401,
#   8,
#   5,
#   169,
#   1776,
#   139,
#   433,
#   38,
#   702,
#   197,
#   48,
#   2,
#   76,
#   4,
#   167,
#   10,
#   15,
#   52,
#   83,
#   2369,
#   30,
#   88,
#   96,
#   13,
#   170,
#   6],
#  [19, 1, 378, 1737, 2453, 343],
#  [142,
#   783,
#   46,
#   262,
#   103,
#   186,
#   7,
#   142,
#   916,
#   6,
#   137,
#   889,
#   18,
#   1713,
#   137,
#   64,
#   3,
#   265,
#   4198],
#  [70,
#   419,
#   382,
#   1,
#   194,
#   73,
#   26,
#   2,
#   23,
#   14,
#   142,
#   2370,
#   324,
#   402,
#   278,
#   272,
#   797,
#   104,
#   66,
#   44,
#   17,
#   41,
#   53,
#   253,
#   36,
#   98,
#   24,
#   23,
#   104,
#   138,
#   1292,
#   313,
#   226,
#   164,
#   19,
#   508,
#   732,
#   70,
#   5,
#   13,
#   381,
#   1845,
#   7004,
#   210,
#   2110],
#  [471,
#   112,
#   111,
#   17,
#   15,
#   47,
#   124,
#   13,
#   37,
#   15,
#   466,
#   1179,
#   151,
#   152,
#   6,
#   37,
#   76,
#   4,
#   51,
#   1100,
#   1625,
#   8,
#   50,
#   6,
#   218,
#   27,
#   340,
#   620,
#   172,
#   141,
#   59,
#   10,
#   15,
#   4698,
#   318,
#   20,
#   76,
#   2,
#   514,
#   96,
#   99],
#  [1, 25, 388, 91, 37, 76, 4, 12, 99, 42, 53, 41, 156, 438, 720, 42, 139],
#  [1,
#   177,
#   21,
#   1052,
#   288,
#   79,
#   61,
#   1,
#   169,
#   336,
#   8,
#   988,
#   331,
#   192,
#   74,
#   1377,
#   301,
#   189,
#   79,
#   580,
#   14,
#   9,
#   2371,
#   2607,
#   3,
#   1220,
#   480,
#   336,
#   237,
#   46,
#   300,
#   169,
#   5516,
#   20,
#   114,
#   24,
#   3121,
#   52,
#   673,
#   54,
#   155,
#   3,
#   753,
#   504,
#   3122],
#  [20, 466, 432, 5, 8, 36, 72],
#  [1738, 151, 4699, 4700, 1, 94, 117, 340, 12, 4, 59, 10, 4, 52, 1563],
#  [19,
#   84,
#   1,
#   218,
#   46,
#   543,
#   14,
#   27,
#   12,
#   164,
#   73,
#   209,
#   153,
#   37,
#   76,
#   4,
#   216,
#   147,
#   185,
#   146,
#   68,
#   4,
#   313,
#   98,
#   2233,
#   128],
#  [112,
#   14,
#   29,
#   128,
#   292,
#   84,
#   16,
#   131,
#   7,
#   6,
#   314,
#   603,
#   316,
#   246,
#   32,
#   4,
#   88,
#   631,
#   1047,
#   367,
#   135,
#   4,
#   39,
#   153,
#   67,
#   96,
#   607,
#   117,
#   879,
#   150,
#   66,
#   9,
#   376,
#   173,
#   181,
#   20,
#   24,
#   58],
#  [8,
#   19,
#   95,
#   289,
#   513,
#   470,
#   134,
#   213,
#   545,
#   752,
#   315,
#   315,
#   1594,
#   1066,
#   234,
#   51,
#   2454,
#   32,
#   62,
#   974,
#   2,
#   76,
#   4,
#   7005,
#   838,
#   14,
#   1681,
#   346,
#   12,
#   114,
#   1293,
#   81,
#   32],
#  [19, 1027, 26, 18, 137, 98, 408, 1180, 20, 171, 5],
#  [11,
#   9,
#   10,
#   353,
#   206,
#   243,
#   167,
#   10,
#   15,
#   47,
#   2,
#   215,
#   7,
#   975,
#   557,
#   523,
#   211,
#   821,
#   9,
#   7,
#   511,
#   263,
#   144,
#   844,
#   398,
#   159],
#  [11,
#   358,
#   1,
#   263,
#   218,
#   10,
#   40,
#   4701,
#   201,
#   720,
#   33,
#   135,
#   428,
#   54,
#   2,
#   9,
#   7,
#   649,
#   14,
#   244,
#   178,
#   163,
#   13,
#   731,
#   254,
#   179,
#   468,
#   90],
#  [637, 443, 111, 17, 4, 251, 222, 2, 89, 148, 122, 29, 154, 245, 10],
#  [321,
#   115,
#   6,
#   161,
#   2455,
#   496,
#   217,
#   119,
#   272,
#   1428,
#   132,
#   189,
#   30,
#   152,
#   21,
#   265],
#  [7,
#   395,
#   151,
#   455,
#   1,
#   312,
#   23,
#   66,
#   126,
#   964,
#   23,
#   13,
#   1069,
#   40,
#   307,
#   233,
#   451,
#   1413,
#   429,
#   973,
#   507,
#   372,
#   217,
#   8,
#   128,
#   612,
#   27,
#   470,
#   313,
#   24,
#   16,
#   66,
#   1,
#   688,
#   83,
#   12,
#   153,
#   226,
#   33,
#   522,
#   66,
#   9,
#   440,
#   6,
#   7006],
#  [471,
#   443,
#   111,
#   822,
#   7007,
#   8,
#   5517,
#   83,
#   371,
#   76,
#   672,
#   1777,
#   29,
#   25,
#   110,
#   231,
#   55,
#   261,
#   63,
#   46,
#   129,
#   493,
#   50,
#   308,
#   401,
#   8,
#   586,
#   207,
#   5518,
#   542,
#   49,
#   1778,
#   52,
#   5519,
#   1816,
#   1753,
#   102,
#   7008],
#  [266,
#   29,
#   5,
#   8,
#   80,
#   94,
#   37,
#   18,
#   33,
#   59,
#   10,
#   15,
#   1541,
#   10,
#   15,
#   5520,
#   33,
#   35,
#   188,
#   79,
#   232,
#   185,
#   131,
#   203,
#   15,
#   1043,
#   15,
#   348,
#   266,
#   345,
#   353,
#   160,
#   212,
#   62,
#   693,
#   324,
#   467,
#   647,
#   27,
#   35,
#   188,
#   342,
#   114,
#   467,
#   343],
#  [27,
#   353,
#   50,
#   946,
#   8,
#   296,
#   27,
#   1378,
#   1047,
#   296,
#   16,
#   9,
#   495,
#   975,
#   7,
#   2542,
#   110,
#   1714,
#   4702],
#  [6, 75, 172, 141, 98, 170, 388, 9, 765, 86, 43, 62, 195, 13, 94, 140],
#  [7009,
#   4703,
#   331,
#   814,
#   467,
#   826,
#   790,
#   1294,
#   231,
#   1151,
#   790,
#   4704,
#   596,
#   148,
#   144,
#   117,
#   1881,
#   70,
#   724,
#   570,
#   366,
#   5521,
#   226,
#   2001,
#   125,
#   182,
#   110,
#   93,
#   79,
#   20,
#   49,
#   207,
#   2456,
#   34,
#   31,
#   383,
#   328,
#   49,
#   197,
#   210,
#   424,
#   211,
#   923,
#   662],
#  [592,
#   2,
#   144,
#   736,
#   113,
#   135,
#   198,
#   132,
#   9,
#   607,
#   244,
#   367,
#   24,
#   1429,
#   262,
#   61,
#   1101,
#   66,
#   113,
#   9,
#   11,
#   226,
#   1,
#   172,
#   474,
#   638,
#   2111,
#   874,
#   1325,
#   684,
#   1544,
#   1058,
#   2295,
#   20,
#   104,
#   278,
#   7010,
#   187,
#   892,
#   518,
#   392,
#   719,
#   2234,
#   12],
#  [52,
#   596,
#   2235,
#   804,
#   16,
#   5522,
#   6,
#   55,
#   22,
#   142,
#   349,
#   75,
#   362,
#   25,
#   244,
#   16,
#   27,
#   452,
#   271,
#   801,
#   18,
#   262,
#   254,
#   18,
#   137,
#   354,
#   91,
#   2172,
#   1135,
#   12,
#   201,
#   101,
#   11,
#   141,
#   121],
#  [5,
#   353,
#   126,
#   61,
#   72,
#   386,
#   975,
#   1135,
#   1,
#   1324,
#   38,
#   60,
#   139,
#   224,
#   91,
#   10,
#   22,
#   130,
#   87,
#   234,
#   953,
#   447,
#   145,
#   10,
#   121],
#  [143,
#   19,
#   4199,
#   294,
#   126,
#   126,
#   100,
#   8,
#   89,
#   2714,
#   478,
#   1682,
#   113,
#   94,
#   193,
#   10,
#   378,
#   1737,
#   2457,
#   84,
#   13,
#   193,
#   125,
#   126,
#   163,
#   345,
#   141,
#   235,
#   3297,
#   9,
#   478,
#   79,
#   7011,
#   46,
#   9,
#   110,
#   28,
#   47,
#   4,
#   307,
#   143,
#   211,
#   1293],
#  [5,
#   353,
#   8,
#   9,
#   18,
#   542,
#   109,
#   16,
#   530,
#   2458,
#   190,
#   68,
#   11,
#   38,
#   74,
#   57,
#   11,
#   110,
#   1244,
#   141,
#   72,
#   14,
#   27,
#   22,
#   1570,
#   179,
#   468,
#   164,
#   76,
#   746,
#   45,
#   13,
#   60,
#   5523,
#   489,
#   428,
#   10,
#   41,
#   4,
#   185,
#   258,
#   71,
#   9,
#   63,
#   975],
#  [169,
#   1625,
#   8,
#   78,
#   5524,
#   382,
#   29,
#   83,
#   158,
#   66,
#   18,
#   412,
#   198,
#   43,
#   64,
#   466,
#   4,
#   51,
#   677,
#   13,
#   44,
#   7,
#   837,
#   6,
#   45,
#   1653,
#   6,
#   123,
#   2608,
#   20,
#   9,
#   7,
#   828,
#   1151],
#  [1223,
#   551,
#   266,
#   20,
#   59,
#   77,
#   79,
#   119,
#   312,
#   376,
#   321,
#   1375,
#   177,
#   27,
#   9,
#   288,
#   266,
#   266,
#   37,
#   76,
#   32,
#   4,
#   3,
#   146,
#   266,
#   309,
#   4,
#   146,
#   10,
#   35,
#   377,
#   248,
#   561,
#   32,
#   262,
#   289,
#   95,
#   14,
#   1357,
#   878],
#  [697,
#   36,
#   48,
#   36,
#   21,
#   394,
#   25,
#   8,
#   166,
#   48,
#   54,
#   252,
#   64,
#   118,
#   43,
#   3,
#   1683,
#   30,
#   166,
#   20,
#   241,
#   110,
#   523,
#   1102,
#   171,
#   61,
#   125,
#   195,
#   196,
#   247,
#   102,
#   35,
#   246],
#  [19,
#   40,
#   114,
#   776,
#   2112,
#   196,
#   47,
#   275,
#   13,
#   40,
#   559,
#   3,
#   55,
#   674,
#   248,
#   776,
#   11,
#   159,
#   262,
#   1048,
#   55,
#   7,
#   3800],
#  [50,
#   6,
#   37,
#   44,
#   24,
#   39,
#   50,
#   77,
#   12,
#   3,
#   155,
#   160,
#   1274,
#   96,
#   88,
#   115,
#   207,
#   10,
#   96,
#   11,
#   80,
#   3,
#   155,
#   160,
#   364,
#   36],
#  [7012,
#   3,
#   59,
#   65,
#   202,
#   191,
#   252,
#   148,
#   9,
#   63,
#   218,
#   27,
#   6,
#   141,
#   195,
#   118,
#   2054,
#   211,
#   5],
#  [7013,
#   56,
#   112,
#   850,
#   249,
#   674,
#   70,
#   844,
#   344,
#   83,
#   29,
#   3,
#   1440,
#   674,
#   31,
#   2,
#   76,
#   4],
#  [1261,
#   115,
#   6,
#   96,
#   298,
#   276,
#   579,
#   70,
#   2,
#   73,
#   3,
#   96,
#   109,
#   67,
#   116,
#   97,
#   65,
#   114,
#   216,
#   13,
#   3,
#   432,
#   61,
#   176,
#   170,
#   187,
#   115,
#   53,
#   65,
#   13,
#   117,
#   115,
#   334,
#   533,
#   91,
#   96,
#   97,
#   27,
#   569,
#   216,
#   1181,
#   533,
#   8,
#   27,
#   130,
#   559,
#   95,
#   84,
#   130,
#   3801],
#  [151,
#   153,
#   48,
#   216,
#   104,
#   65,
#   335,
#   216,
#   4,
#   341,
#   23,
#   7014,
#   341,
#   36,
#   39,
#   50,
#   43,
#   209,
#   607,
#   226,
#   71,
#   319,
#   160,
#   8,
#   11,
#   1501,
#   58,
#   115,
#   98,
#   2296,
#   1261,
#   1913,
#   105,
#   1592,
#   160,
#   976,
#   155],
#  [82,
#   48,
#   52,
#   58,
#   1715,
#   355,
#   5,
#   161,
#   133,
#   14,
#   27,
#   8,
#   50,
#   2459,
#   199,
#   104,
#   69,
#   5,
#   199,
#   1460,
#   281],
#  [50,
#   48,
#   8,
#   108,
#   597,
#   734,
#   205,
#   865,
#   76,
#   4,
#   179,
#   88,
#   45,
#   561,
#   45,
#   938,
#   132,
#   12,
#   17,
#   4,
#   59,
#   4,
#   52,
#   764,
#   48,
#   200,
#   13,
#   2,
#   23,
#   262,
#   45,
#   70,
#   146,
#   65,
#   132,
#   36,
#   19,
#   209],
#  [48,
#   408,
#   103,
#   518,
#   271,
#   30,
#   138,
#   765,
#   590,
#   900,
#   46,
#   2609,
#   16,
#   1293,
#   127,
#   1502,
#   81,
#   48,
#   218,
#   218,
#   118,
#   346,
#   2960,
#   1461,
#   145,
#   647,
#   146,
#   1036,
#   2,
#   76,
#   4,
#   406,
#   100,
#   128],
#  [7,
#   151,
#   867,
#   639,
#   69,
#   48,
#   546,
#   601,
#   29,
#   1395,
#   202,
#   129,
#   531,
#   8,
#   154,
#   245,
#   10,
#   40],
#  [5, 48, 100, 277, 37, 15, 17, 12, 59, 71, 18, 276],
#  [3,
#   382,
#   20,
#   14,
#   30,
#   106,
#   67,
#   495,
#   3,
#   2,
#   215,
#   747,
#   160,
#   254,
#   290,
#   849,
#   8,
#   332,
#   63,
#   36,
#   95,
#   6,
#   132,
#   716,
#   3,
#   7,
#   1084,
#   127,
#   248],
#  [6,
#   7015,
#   6,
#   23,
#   1414,
#   31,
#   757,
#   33,
#   147,
#   18,
#   7016,
#   176,
#   5525,
#   10,
#   210,
#   188,
#   9,
#   1136,
#   853,
#   119,
#   6],
#  [5,
#   1084,
#   8,
#   6,
#   1111,
#   64,
#   10,
#   2297,
#   102,
#   2236,
#   48,
#   40,
#   7017,
#   293,
#   1882,
#   80,
#   783,
#   20,
#   3,
#   110,
#   41,
#   435,
#   79,
#   304,
#   69,
#   285,
#   634,
#   174,
#   304,
#   10,
#   164,
#   661,
#   7018,
#   42,
#   7019,
#   79,
#   304,
#   145,
#   102,
#   13,
#   320,
#   10,
#   242,
#   67,
#   24,
#   242,
#   18,
#   116,
#   37],
#  [6, 34, 108, 106, 3, 351, 111, 14, 674, 3, 1440, 374, 5, 6, 42, 123, 139],
#  [128,
#   764,
#   48,
#   16,
#   4200,
#   40,
#   121,
#   7,
#   123,
#   48,
#   854,
#   8,
#   123,
#   6,
#   55,
#   7,
#   658,
#   115,
#   16,
#   40,
#   48,
#   9,
#   60,
#   73,
#   3526],
#  [237,
#   79,
#   5526,
#   1085,
#   333,
#   3527,
#   4,
#   17,
#   12,
#   59,
#   341,
#   333,
#   2834,
#   144,
#   51,
#   2372,
#   132,
#   1302,
#   1462,
#   165,
#   3527,
#   710,
#   7020,
#   181,
#   333,
#   205,
#   258,
#   333,
#   9,
#   23,
#   66,
#   80,
#   255],
#  [133,
#   6,
#   78,
#   471,
#   111,
#   1197,
#   148,
#   58,
#   148,
#   124,
#   13,
#   170,
#   115,
#   222,
#   2,
#   11,
#   61,
#   61,
#   727,
#   106,
#   338,
#   444,
#   222],
#  [50,
#   6,
#   393,
#   1084,
#   8,
#   13,
#   19,
#   650,
#   582,
#   114,
#   679,
#   194,
#   674,
#   124,
#   13,
#   414,
#   111,
#   83,
#   390,
#   18,
#   65,
#   12,
#   400,
#   206,
#   236,
#   10,
#   4,
#   1162,
#   65,
#   260,
#   140,
#   205,
#   39,
#   465,
#   67,
#   124,
#   13,
#   954,
#   123,
#   989,
#   12,
#   3,
#   40,
#   559],
#  [5,
#   243,
#   29,
#   266,
#   548,
#   61,
#   2,
#   19,
#   96,
#   365,
#   93,
#   9,
#   7,
#   2610,
#   2237,
#   4,
#   3,
#   2,
#   96,
#   579,
#   1017,
#   4705,
#   2543,
#   658,
#   254,
#   2543,
#   104,
#   266,
#   1137,
#   365,
#   187,
#   731,
#   2543,
#   254,
#   55,
#   354,
#   2961,
#   3,
#   155,
#   597,
#   655],
#  [2173,
#   165,
#   14,
#   6,
#   268,
#   1626,
#   226,
#   80,
#   8,
#   393,
#   788,
#   31,
#   96,
#   291,
#   259,
#   14,
#   493,
#   83,
#   1198,
#   850,
#   419,
#   20,
#   6,
#   674,
#   480,
#   3123,
#   757,
#   3,
#   625,
#   1396,
#   10,
#   64,
#   3124,
#   315,
#   185,
#   2055,
#   232,
#   674,
#   434,
#   14,
#   480,
#   14,
#   2835],
#  [162,
#   4,
#   2,
#   89,
#   570,
#   1084,
#   1480,
#   513,
#   674,
#   306,
#   3125,
#   232,
#   415,
#   1059,
#   5527,
#   3,
#   68,
#   879,
#   2611,
#   10,
#   20,
#   691,
#   330,
#   2836,
#   259,
#   74,
#   383,
#   150,
#   330,
#   189,
#   1571,
#   606,
#   3802,
#   102,
#   348,
#   2611,
#   383,
#   330,
#   189,
#   581,
#   39,
#   17,
#   1234,
#   472,
#   10,
#   6,
#   1234,
#   7021,
#   227,
#   1247,
#   39],
#  [78,
#   109,
#   3,
#   48,
#   546,
#   50,
#   191,
#   80,
#   49,
#   118,
#   817,
#   32,
#   702,
#   858,
#   109,
#   601,
#   50,
#   764,
#   48],
#  [28,
#   7,
#   111,
#   351,
#   46,
#   200,
#   64,
#   108,
#   71,
#   5,
#   87,
#   160,
#   2543,
#   355,
#   990,
#   319,
#   863,
#   337,
#   271,
#   18,
#   3528,
#   2113,
#   14,
#   1397,
#   70,
#   51,
#   860,
#   471,
#   111,
#   97,
#   24,
#   102,
#   19,
#   47,
#   266,
#   1415,
#   147,
#   2056,
#   2057,
#   2058,
#   289,
#   60,
#   139,
#   224,
#   91,
#   10,
#   5],
#  [28,
#   41,
#   4,
#   99,
#   2,
#   19,
#   450,
#   30,
#   270,
#   9,
#   7,
#   20,
#   295,
#   36,
#   273,
#   465,
#   90,
#   420,
#   854,
#   8,
#   27,
#   183,
#   26],
#  [19, 2114, 95, 343, 1715, 130, 166, 5, 6, 18, 182, 93, 366],
#  [5,
#   1,
#   598,
#   20,
#   79,
#   917,
#   893,
#   404,
#   894,
#   1379,
#   1,
#   194,
#   155,
#   149,
#   4,
#   8,
#   133,
#   78,
#   149,
#   29,
#   418,
#   527,
#   72,
#   549,
#   24,
#   234,
#   203,
#   380,
#   953,
#   7,
#   87,
#   659,
#   6,
#   98,
#   24,
#   2544,
#   3,
#   95,
#   242,
#   324,
#   48,
#   811,
#   113,
#   305,
#   14,
#   173,
#   4706],
#  [57, 197, 424, 1160, 57, 4, 45, 593, 18, 88, 662],
#  [17, 53, 12, 120, 2, 89, 31, 22, 3, 540, 158, 267, 1955, 260, 159],
#  [82,
#   210,
#   1545,
#   10,
#   429,
#   60,
#   373,
#   563,
#   25,
#   21,
#   737,
#   1592,
#   64,
#   10,
#   679,
#   14,
#   29,
#   105,
#   61,
#   1271,
#   2962,
#   67,
#   214,
#   26,
#   210,
#   30,
#   171,
#   64,
#   19,
#   378,
#   84,
#   694,
#   679,
#   14,
#   130,
#   965,
#   1,
#   196,
#   6,
#   1914,
#   290,
#   342,
#   63,
#   68],
#  [5,
#   534,
#   951,
#   6,
#   68,
#   243,
#   1,
#   68,
#   6,
#   84,
#   43,
#   200,
#   10,
#   1213,
#   95,
#   23,
#   776,
#   35,
#   348,
#   316,
#   10,
#   15,
#   47,
#   4,
#   42,
#   47,
#   357,
#   18,
#   174,
#   36,
#   173,
#   7022,
#   2715,
#   99,
#   2,
#   178,
#   966,
#   52],
#  [48,
#   29,
#   262,
#   8,
#   9,
#   23,
#   66,
#   83,
#   955,
#   849,
#   48,
#   417,
#   21,
#   351,
#   37,
#   15,
#   51,
#   246,
#   71,
#   194,
#   21,
#   625,
#   3,
#   7023,
#   1956,
#   132,
#   9,
#   128],
#  [201,
#   179,
#   930,
#   31,
#   586,
#   5528,
#   215,
#   378,
#   84,
#   42,
#   259,
#   1027,
#   50,
#   312,
#   22,
#   264,
#   23,
#   10,
#   196,
#   188,
#   101,
#   994,
#   477,
#   179,
#   33,
#   77,
#   226,
#   150],
#  [5,
#   2,
#   35,
#   206,
#   2,
#   7,
#   608,
#   94,
#   3,
#   43,
#   90,
#   164,
#   132,
#   2115,
#   12,
#   12,
#   760,
#   389,
#   8,
#   26,
#   25,
#   64,
#   218,
#   37,
#   76,
#   236,
#   15,
#   2,
#   89,
#   423],
#  [5,
#   35,
#   7,
#   35,
#   607,
#   6,
#   1754,
#   144,
#   9,
#   7,
#   754,
#   402,
#   19,
#   166,
#   158,
#   13,
#   28,
#   20,
#   171,
#   8,
#   25],
#  [8,
#   1546,
#   89,
#   5529,
#   2,
#   1430,
#   173,
#   33,
#   868,
#   457,
#   98,
#   95,
#   15,
#   624,
#   7024,
#   633,
#   561,
#   1,
#   1679,
#   373,
#   113,
#   31,
#   7025,
#   1915,
#   1096,
#   1,
#   66,
#   31,
#   315,
#   13,
#   253,
#   108,
#   2460,
#   977,
#   402,
#   1,
#   345,
#   2174,
#   299],
#  [5,
#   286,
#   323,
#   900,
#   203,
#   457,
#   599,
#   19,
#   6,
#   3126,
#   63,
#   5530,
#   892,
#   82,
#   275,
#   8,
#   136,
#   275,
#   34,
#   1883,
#   8,
#   3298,
#   109,
#   153,
#   76,
#   4,
#   316,
#   10,
#   47,
#   33,
#   547,
#   869,
#   47,
#   2,
#   23,
#   18,
#   182,
#   6,
#   588,
#   120,
#   45,
#   267,
#   24,
#   159,
#   187,
#   472,
#   1356],
#  [105,
#   190,
#   8,
#   67,
#   75,
#   21,
#   1356,
#   117,
#   1095,
#   41,
#   1684,
#   30,
#   43,
#   97,
#   18,
#   908,
#   7026,
#   8,
#   341,
#   41],
#  [124,
#   202,
#   441,
#   129,
#   122,
#   14,
#   8,
#   27,
#   545,
#   571,
#   420,
#   8,
#   129,
#   2,
#   27,
#   2,
#   1884,
#   87,
#   69,
#   49,
#   34,
#   170,
#   25,
#   87,
#   41,
#   36,
#   419,
#   209,
#   332,
#   49,
#   13,
#   921,
#   228,
#   69,
#   146,
#   777,
#   203,
#   7027,
#   558,
#   20,
#   982,
#   248,
#   92],
#  [7,
#   35,
#   34,
#   28,
#   462,
#   8,
#   624,
#   54,
#   35,
#   4707,
#   119,
#   87,
#   21,
#   156,
#   626,
#   171,
#   1,
#   498,
#   185,
#   186,
#   1846,
#   40,
#   738,
#   343,
#   627,
#   378,
#   1618,
#   73,
#   166,
#   738,
#   425,
#   1084,
#   553,
#   170,
#   18,
#   30,
#   952,
#   283,
#   8,
#   68,
#   243,
#   12,
#   4,
#   33,
#   2,
#   73],
#  [29,
#   8,
#   11,
#   46,
#   11,
#   2,
#   4,
#   2963,
#   4201,
#   443,
#   208,
#   246,
#   471,
#   37,
#   15,
#   59,
#   10,
#   299,
#   1380,
#   148,
#   2,
#   89,
#   45],
#  [78,
#   9,
#   7,
#   11,
#   35,
#   17,
#   983,
#   153,
#   35,
#   34,
#   691,
#   599,
#   295,
#   503,
#   12,
#   50,
#   155,
#   1542,
#   32,
#   24,
#   109,
#   54,
#   855,
#   1199,
#   217,
#   35,
#   3,
#   40,
#   524,
#   119,
#   32,
#   54,
#   9,
#   400,
#   621],
#  [484,
#   300,
#   17,
#   9,
#   109,
#   7028,
#   500,
#   616,
#   4708,
#   32,
#   3,
#   46,
#   52,
#   208,
#   936,
#   93,
#   7,
#   109,
#   296,
#   495,
#   3529,
#   61,
#   6,
#   21,
#   101,
#   1112,
#   93,
#   2,
#   921,
#   7,
#   526,
#   64,
#   516,
#   373,
#   81,
#   306,
#   54,
#   3803],
#  [48, 11, 36, 27, 110, 5, 8, 2, 7, 138, 528, 48, 13, 82, 533, 4],
#  [7029, 2612, 716, 277, 697, 2, 4, 119, 4202, 191, 1],
#  [267,
#   326,
#   149,
#   136,
#   1303,
#   1016,
#   1,
#   1627,
#   964,
#   104,
#   1627,
#   406,
#   1200,
#   263,
#   344,
#   478,
#   1503,
#   703,
#   633,
#   348,
#   4709,
#   1381,
#   815,
#   1326,
#   2,
#   45,
#   15,
#   147,
#   1326,
#   2,
#   147,
#   65,
#   45,
#   1326,
#   361,
#   36,
#   164,
#   1149,
#   585,
#   250,
#   303,
#   160,
#   115,
#   2238],
#  [45,
#   2002,
#   4,
#   276,
#   2,
#   167,
#   159,
#   4,
#   52,
#   48,
#   5531,
#   88,
#   26,
#   48,
#   101,
#   7,
#   814,
#   1103,
#   46,
#   9,
#   63],
#  [5,
#   14,
#   8,
#   28,
#   190,
#   20,
#   492,
#   2003,
#   691,
#   109,
#   213,
#   9,
#   182,
#   90,
#   119,
#   1595,
#   691,
#   132],
#  [7030,
#   1527,
#   870,
#   181,
#   1248,
#   114,
#   24,
#   291,
#   142,
#   124,
#   13,
#   362,
#   282,
#   35,
#   166,
#   3,
#   130,
#   366,
#   840,
#   144,
#   16,
#   227,
#   405,
#   458],
#  [5, 8, 48, 14, 408, 30, 174, 1547, 2, 23],
#  [1, 390, 33, 224, 61, 29, 80, 315, 46, 31, 246, 4, 300, 341],
#  [491,
#   366,
#   6,
#   144,
#   9,
#   7,
#   754,
#   157,
#   1396,
#   7031,
#   1681,
#   72,
#   243,
#   157,
#   56,
#   438,
#   9,
#   2175,
#   3,
#   6,
#   288,
#   21,
#   99,
#   15,
#   45,
#   317,
#   366,
#   72,
#   71,
#   213,
#   45,
#   144,
#   4710,
#   39,
#   128,
#   14,
#   262,
#   22,
#   275,
#   42,
#   12,
#   500,
#   114,
#   24,
#   8],
#  [28,
#   32,
#   496,
#   86,
#   5,
#   126,
#   481,
#   139,
#   59,
#   125,
#   86,
#   57,
#   26,
#   751,
#   1,
#   1398,
#   939,
#   620,
#   3299,
#   163,
#   32,
#   503,
#   39,
#   1,
#   31,
#   623,
#   3,
#   331,
#   235,
#   3,
#   155,
#   114,
#   724,
#   391,
#   144,
#   20,
#   241,
#   110,
#   858,
#   151,
#   3,
#   49],
#  [858,
#   151,
#   3,
#   232,
#   205,
#   2,
#   36,
#   48,
#   1132,
#   48,
#   49,
#   1441,
#   18,
#   30,
#   174,
#   2,
#   76,
#   4,
#   238,
#   400,
#   4,
#   2,
#   89,
#   49,
#   8,
#   29,
#   46,
#   63],
#  [55, 172, 23, 66, 11, 835],
#  [48,
#   9,
#   359,
#   295,
#   2,
#   11,
#   82,
#   498,
#   692,
#   42,
#   123,
#   139,
#   83,
#   1304,
#   10,
#   104,
#   337,
#   1275,
#   198,
#   386,
#   1749,
#   165,
#   265],
#  [4711,
#   42,
#   15,
#   71,
#   784,
#   66,
#   14,
#   5532,
#   271,
#   14,
#   835,
#   163,
#   22,
#   30,
#   3300,
#   260,
#   381,
#   245,
#   210,
#   3804,
#   24,
#   148],
#  [28,
#   300,
#   92,
#   237,
#   46,
#   1122,
#   14,
#   55,
#   369,
#   7,
#   666,
#   263,
#   183,
#   924,
#   3,
#   811,
#   3301,
#   186,
#   7,
#   4203,
#   754,
#   136,
#   107,
#   8,
#   3,
#   219,
#   103,
#   580,
#   265],
#  [27,
#   166,
#   35,
#   1086,
#   20,
#   10,
#   180,
#   1885,
#   225,
#   38,
#   145,
#   127,
#   7,
#   12,
#   683,
#   3,
#   478,
#   328,
#   507,
#   288,
#   130,
#   166,
#   87,
#   10,
#   306,
#   188,
#   50,
#   785],
#  [105,
#   6,
#   1548,
#   20,
#   52,
#   4712,
#   74,
#   86,
#   83,
#   20,
#   135,
#   189,
#   65,
#   51,
#   153,
#   3530,
#   4713,
#   14,
#   160,
#   372,
#   45,
#   461,
#   39,
#   65,
#   200,
#   117,
#   4,
#   1572,
#   13,
#   217,
#   3,
#   39,
#   62,
#   34,
#   440,
#   7032,
#   855,
#   134],
#  [5,
#   531,
#   530,
#   8,
#   72,
#   318,
#   37,
#   16,
#   15,
#   45,
#   167,
#   52,
#   48,
#   4,
#   88,
#   45,
#   87,
#   64,
#   3,
#   137,
#   55,
#   25,
#   46,
#   592,
#   210,
#   55,
#   13,
#   77,
#   187,
#   305,
#   1048,
#   58,
#   48,
#   3,
#   40,
#   8,
#   1170,
#   14,
#   402],
#  [11,
#   32,
#   10,
#   86,
#   57,
#   751,
#   12,
#   1755,
#   19,
#   825,
#   425,
#   1567,
#   141,
#   694,
#   37,
#   65,
#   95,
#   61,
#   144,
#   54,
#   2716,
#   9,
#   65,
#   95,
#   3302,
#   21,
#   61,
#   11,
#   252,
#   32],
#  [105,
#   48,
#   151,
#   37,
#   15,
#   45,
#   2461,
#   2454,
#   48,
#   338,
#   389,
#   748,
#   503,
#   817,
#   45,
#   36,
#   677,
#   505,
#   31,
#   1504,
#   929,
#   13,
#   97,
#   108,
#   179,
#   228,
#   67,
#   187,
#   151,
#   793,
#   23],
#  [136,
#   6,
#   27,
#   100,
#   40,
#   22,
#   21,
#   69,
#   49,
#   240,
#   93,
#   452,
#   116,
#   50,
#   417,
#   697,
#   1382,
#   2004,
#   22,
#   275,
#   3,
#   275,
#   967,
#   275,
#   94,
#   3,
#   8,
#   967,
#   269,
#   21,
#   4714,
#   151,
#   850,
#   3805,
#   1505,
#   329,
#   181,
#   86,
#   1235,
#   14,
#   21,
#   669,
#   1053,
#   124,
#   151,
#   185],
#  [5,
#   14,
#   32,
#   51,
#   101,
#   930,
#   302,
#   22,
#   374,
#   21,
#   83,
#   265,
#   66,
#   435,
#   43,
#   304,
#   228,
#   96],
#  [345, 118, 399, 91, 21, 281, 193, 10, 521, 39, 22, 25],
#  [50,
#   14,
#   29,
#   8,
#   351,
#   151,
#   2,
#   30,
#   654,
#   45,
#   15,
#   117,
#   4,
#   377,
#   20,
#   4,
#   2,
#   668,
#   2,
#   178,
#   39,
#   18,
#   174,
#   302,
#   606,
#   9,
#   7,
#   532,
#   273,
#   228,
#   12],
#  [321,
#   1685,
#   7033,
#   1,
#   34,
#   728,
#   31,
#   3,
#   749,
#   124,
#   13,
#   134,
#   2,
#   88,
#   3,
#   95,
#   178,
#   1547,
#   105,
#   394,
#   80,
#   250,
#   170,
#   187,
#   680,
#   265,
#   533,
#   4,
#   355,
#   5,
#   386,
#   62,
#   27,
#   728,
#   380,
#   1739,
#   98,
#   137,
#   600,
#   30,
#   657,
#   2001,
#   288,
#   1593,
#   31,
#   3,
#   652],
#  [12,
#   99,
#   28,
#   47,
#   49,
#   64,
#   516,
#   15,
#   70,
#   91,
#   2,
#   215,
#   64,
#   18,
#   276,
#   120,
#   6,
#   520,
#   5,
#   36,
#   14],
#  [48,
#   169,
#   18,
#   107,
#   190,
#   865,
#   86,
#   439,
#   192,
#   2,
#   215,
#   46,
#   103,
#   3,
#   1233,
#   46,
#   1008,
#   46,
#   4204,
#   181],
#  [3806,
#   80,
#   4205,
#   1163,
#   1,
#   79,
#   917,
#   9,
#   7,
#   109,
#   917,
#   2460,
#   978,
#   530,
#   62,
#   220,
#   461,
#   653,
#   1,
#   3,
#   183,
#   594,
#   186,
#   182,
#   88,
#   262,
#   45,
#   593,
#   37,
#   239,
#   15,
#   342,
#   1957,
#   4,
#   5533,
#   104,
#   578,
#   1138,
#   324,
#   2116,
#   14,
#   2234,
#   82,
#   4,
#   1951],
#  [28, 33, 64, 605, 358, 656, 37, 312, 15, 26, 3, 791, 256, 3, 333],
#  [255,
#   1431,
#   10,
#   899,
#   26,
#   383,
#   259,
#   5534,
#   38,
#   102,
#   2837,
#   592,
#   101,
#   4,
#   2,
#   89,
#   9,
#   50,
#   34,
#   639,
#   5,
#   752,
#   294,
#   880,
#   6,
#   1886,
#   549,
#   255,
#   12,
#   3,
#   65,
#   5,
#   9,
#   112,
#   1569,
#   6,
#   2059,
#   495,
#   3531,
#   1235,
#   49,
#   750,
#   121,
#   1236,
#   5535,
#   510,
#   10,
#   7034],
#  [1, 54, 55, 7, 1303, 2717, 95, 73, 189, 175, 255, 1, 1847, 1817, 701],
#  [336, 241, 6, 9, 2, 1289],
#  [350,
#   790,
#   348,
#   6,
#   1431,
#   397,
#   56,
#   532,
#   221,
#   35,
#   52,
#   717,
#   153,
#   72,
#   30,
#   204,
#   522,
#   44,
#   304,
#   27,
#   119,
#   517,
#   410,
#   2176,
#   71,
#   704,
#   402,
#   100,
#   6,
#   288,
#   253,
#   3,
#   14,
#   7035,
#   120,
#   230,
#   59,
#   15,
#   131,
#   2,
#   7,
#   90,
#   246,
#   47,
#   3303,
#   90],
#  [5, 8, 48, 10, 195, 290, 459, 74, 102, 340, 193, 110, 10, 126, 61, 11, 46],
#  [286,
#   7036,
#   642,
#   346,
#   72,
#   406,
#   386,
#   7037,
#   120,
#   535,
#   135,
#   517,
#   177,
#   288,
#   1593,
#   262,
#   5,
#   166,
#   14,
#   130,
#   104,
#   442,
#   918,
#   378,
#   3127,
#   7,
#   81,
#   561,
#   14,
#   212,
#   145,
#   522,
#   6,
#   92,
#   319,
#   1125,
#   184,
#   8,
#   286,
#   39,
#   1060,
#   559,
#   21,
#   634,
#   4206,
#   165,
#   377],
#  [348,
#   1,
#   193,
#   519,
#   84,
#   121,
#   1,
#   19,
#   21,
#   130,
#   166,
#   191,
#   157,
#   169,
#   3532,
#   139,
#   81,
#   1,
#   99,
#   524,
#   256,
#   316,
#   208,
#   15,
#   47,
#   851,
#   15,
#   1,
#   260,
#   165,
#   71,
#   116,
#   501,
#   1291,
#   230,
#   67,
#   1086,
#   10,
#   282,
#   150,
#   83,
#   157,
#   632,
#   12,
#   25,
#   81,
#   729],
#  [1070,
#   2177,
#   7,
#   357,
#   44,
#   481,
#   327,
#   43,
#   214,
#   663,
#   5536,
#   340,
#   260,
#   60,
#   937,
#   2004,
#   44,
#   737,
#   46,
#   2,
#   9,
#   11,
#   61,
#   61,
#   61,
#   43],
#  [5,
#   1305,
#   318,
#   22,
#   25,
#   704,
#   5,
#   146,
#   1301,
#   71,
#   88,
#   61,
#   209,
#   68,
#   21,
#   690,
#   152,
#   19,
#   2,
#   210,
#   7,
#   1305,
#   684,
#   408,
#   1249,
#   113,
#   58,
#   3,
#   885,
#   41,
#   56,
#   122,
#   36,
#   1595,
#   43,
#   200,
#   273,
#   43,
#   357,
#   92,
#   159,
#   41],
#  [6, 16, 50, 27, 46, 37, 65, 148, 4, 19, 1250, 545, 106, 134],
#  [5,
#   403,
#   10,
#   91,
#   59,
#   4,
#   2602,
#   81,
#   56,
#   162,
#   4,
#   186,
#   7,
#   88,
#   3,
#   155,
#   60,
#   588,
#   31,
#   55,
#   16,
#   63,
#   281,
#   413,
#   545,
#   26,
#   3,
#   155,
#   303,
#   160,
#   248,
#   4],
#  [26,
#   6,
#   38,
#   292,
#   84,
#   825,
#   1618,
#   1381,
#   698,
#   14,
#   296,
#   178,
#   317,
#   281,
#   3,
#   142,
#   77,
#   3304,
#   3,
#   60,
#   859,
#   979,
#   329,
#   72,
#   21,
#   113,
#   305,
#   218,
#   652,
#   230,
#   73,
#   3,
#   530,
#   55,
#   7,
#   641,
#   34,
#   989,
#   530,
#   87,
#   288,
#   502,
#   167,
#   10,
#   4,
#   52,
#   6,
#   143],
#  [41,
#   57,
#   7038,
#   319,
#   2,
#   44,
#   7039,
#   273,
#   1070,
#   57,
#   137,
#   7040,
#   154,
#   51,
#   7041,
#   937,
#   1053,
#   1070,
#   273,
#   13,
#   117,
#   273,
#   340,
#   356,
#   136,
#   7042,
#   2,
#   76,
#   4,
#   426,
#   30,
#   276,
#   7043,
#   349,
#   87,
#   2,
#   500,
#   382,
#   152,
#   65,
#   7044,
#   7045],
#  [56,
#   41,
#   4,
#   162,
#   53,
#   1913,
#   207,
#   68,
#   334,
#   97,
#   7046,
#   32,
#   12,
#   67,
#   221,
#   3,
#   536,
#   113,
#   62,
#   2373,
#   71,
#   592,
#   506,
#   1181,
#   8,
#   130,
#   20,
#   11,
#   900,
#   602,
#   1916,
#   1010,
#   796,
#   1573,
#   602,
#   20,
#   108,
#   154,
#   68,
#   507,
#   17,
#   8,
#   253,
#   549,
#   11,
#   525],
#  [56,
#   945,
#   253,
#   32,
#   2060,
#   58,
#   404,
#   34,
#   253,
#   11,
#   670,
#   166,
#   1221,
#   403,
#   1506,
#   909,
#   11,
#   378,
#   121,
#   84,
#   545,
#   1917,
#   413,
#   68,
#   243,
#   464,
#   3807,
#   214,
#   173,
#   16,
#   21,
#   67,
#   45,
#   3,
#   242,
#   3,
#   1345,
#   1756,
#   6],
#  [32,
#   175,
#   26,
#   127,
#   293,
#   9,
#   12,
#   4,
#   10,
#   387,
#   6,
#   56,
#   47,
#   58,
#   381,
#   778,
#   253,
#   70,
#   7,
#   2,
#   2545,
#   189,
#   596,
#   242,
#   17,
#   41,
#   71,
#   402,
#   58,
#   2838,
#   308,
#   70,
#   1028,
#   77,
#   32,
#   181],
#  [38,
#   56,
#   525,
#   138,
#   644,
#   1305,
#   247,
#   509,
#   394,
#   21,
#   2,
#   1012,
#   1753,
#   5537,
#   1481,
#   278,
#   43,
#   87,
#   12,
#   653,
#   361,
#   69,
#   146,
#   1442,
#   9,
#   1029,
#   121,
#   179,
#   349,
#   7,
#   1012,
#   247,
#   3,
#   34,
#   13,
#   4,
#   1021,
#   931,
#   426,
#   327,
#   3,
#   64,
#   848,
#   4,
#   201],
#  [17,
#   6,
#   162,
#   4,
#   1139,
#   20,
#   4,
#   216,
#   37,
#   1100,
#   205,
#   18,
#   72,
#   46,
#   29,
#   3533,
#   798,
#   216,
#   4],
#  [1740, 413, 545, 94, 170, 4207, 840, 214, 25, 125, 837, 57, 931, 94, 622, 88],
#  [42, 15, 1416, 2, 11, 36, 19, 273, 209, 26, 362, 7047],
#  [499, 125, 1182, 52, 17, 124, 171, 8, 412, 21, 176, 3, 160],
#  [197,
#   100,
#   771,
#   202,
#   85,
#   18,
#   174,
#   113,
#   608,
#   18,
#   228,
#   302,
#   293,
#   72,
#   110,
#   2,
#   239,
#   1044,
#   510,
#   569,
#   58,
#   229,
#   17,
#   4,
#   185,
#   18,
#   174,
#   113,
#   85,
#   96,
#   13,
#   1327,
#   853,
#   31,
#   269,
#   261,
#   27,
#   670,
#   297,
#   16,
#   5],
#  [5,
#   72,
#   6,
#   174,
#   36,
#   13,
#   11,
#   180,
#   182,
#   44,
#   554,
#   182,
#   6,
#   235,
#   119,
#   170,
#   240,
#   366,
#   93,
#   1779,
#   50,
#   7,
#   174,
#   36,
#   44,
#   62,
#   5538,
#   217,
#   67,
#   477,
#   16,
#   65,
#   231,
#   85,
#   566,
#   62,
#   358,
#   85,
#   344,
#   1004,
#   160,
#   581,
#   2178,
#   142],
#  [17,
#   78,
#   2,
#   89,
#   127,
#   281,
#   57,
#   378,
#   1737,
#   84,
#   121,
#   125,
#   359,
#   348,
#   1027,
#   129,
#   26,
#   234,
#   8],
#  [105,
#   1,
#   998,
#   56,
#   21,
#   1958,
#   113,
#   145,
#   257,
#   649,
#   22,
#   14,
#   1027,
#   1,
#   3,
#   220,
#   12,
#   1071,
#   538,
#   799,
#   1399,
#   1189,
#   264,
#   1463,
#   1294,
#   242,
#   2839,
#   392,
#   287,
#   1081,
#   3534,
#   589,
#   534,
#   1482,
#   278,
#   98,
#   93,
#   367,
#   135,
#   86,
#   226,
#   14,
#   9,
#   7,
#   74,
#   413,
#   1152,
#   287,
#   5539],
#  [148,
#   1443,
#   17,
#   4,
#   414,
#   443,
#   111,
#   17,
#   4,
#   396,
#   30,
#   116,
#   120,
#   45,
#   57,
#   255,
#   4715,
#   21,
#   94,
#   140],
#  [16,
#   146,
#   5,
#   32,
#   15,
#   61,
#   65,
#   238,
#   12,
#   70,
#   146,
#   4,
#   34,
#   15,
#   12,
#   2546,
#   12,
#   114,
#   115,
#   171,
#   93,
#   1248,
#   160,
#   5,
#   46,
#   4,
#   532,
#   4],
#  [5,
#   403,
#   5,
#   413,
#   36,
#   1029,
#   125,
#   75,
#   88,
#   314,
#   148,
#   4,
#   162,
#   71,
#   186,
#   88,
#   732,
#   875,
#   131,
#   179,
#   412,
#   565,
#   314,
#   55,
#   176,
#   40,
#   83],
#  [359, 586, 26, 25, 141, 635, 1400, 4208, 40, 70, 77, 78, 75, 50, 106],
#  [56,
#   58,
#   75,
#   26,
#   37,
#   15,
#   316,
#   10,
#   4,
#   12,
#   99,
#   88,
#   7,
#   14,
#   67,
#   49,
#   1432,
#   11,
#   20,
#   4,
#   58,
#   70],
#  [16,
#   27,
#   512,
#   1138,
#   324,
#   35,
#   266,
#   5,
#   749,
#   9,
#   2061,
#   120,
#   337,
#   199,
#   46,
#   271,
#   63,
#   37,
#   76,
#   4,
#   248,
#   179,
#   15,
#   104,
#   262,
#   251,
#   4,
#   68,
#   851,
#   15,
#   73,
#   375,
#   319,
#   578,
#   120,
#   132,
#   1401,
#   1818,
#   103,
#   2239,
#   20,
#   489,
#   3,
#   16,
#   152,
#   2062,
#   35,
#   266],
#  [16, 50, 37, 377, 240, 4, 15],
#  [5,
#   57,
#   118,
#   1013,
#   91,
#   345,
#   346,
#   937,
#   908,
#   93,
#   137,
#   2840,
#   71,
#   57,
#   69,
#   49,
#   9,
#   495,
#   39,
#   10,
#   138,
#   223,
#   57,
#   464,
#   1220,
#   86,
#   143,
#   74,
#   655,
#   102,
#   186,
#   7,
#   2005,
#   2374],
#  [5, 286, 746, 8, 286, 2, 18, 33, 411, 1009, 16, 5, 6],
#  [430,
#   57,
#   130,
#   166,
#   75,
#   26,
#   416,
#   37,
#   30,
#   15,
#   246,
#   20,
#   4,
#   162,
#   69,
#   416,
#   183,
#   4,
#   251,
#   665,
#   249,
#   176,
#   1444,
#   142,
#   1224,
#   413,
#   80,
#   130,
#   8,
#   177,
#   252],
#  [1,
#   326,
#   86,
#   797,
#   24,
#   159,
#   462,
#   8,
#   51,
#   101,
#   275,
#   3,
#   241,
#   11,
#   172,
#   141,
#   1,
#   125,
#   23,
#   1306,
#   739,
#   1003,
#   1,
#   325,
#   140,
#   84],
#  [4, 5, 300, 68, 19, 180, 316, 15, 13, 117, 168, 203, 15, 2364, 997, 264, 724],
#  [26,
#   366,
#   6,
#   13,
#   21,
#   5,
#   149,
#   86,
#   8,
#   22,
#   144,
#   511,
#   193,
#   37,
#   65,
#   12,
#   59,
#   52,
#   2546,
#   4],
#  [82,
#   6,
#   122,
#   15,
#   907,
#   2,
#   23,
#   12,
#   45,
#   132,
#   278,
#   95,
#   184,
#   273,
#   174,
#   332,
#   90,
#   7,
#   549,
#   3,
#   34,
#   3,
#   242,
#   67,
#   82,
#   86,
#   8,
#   49,
#   129,
#   191,
#   987,
#   49,
#   225,
#   38,
#   361,
#   223,
#   751,
#   13,
#   54,
#   9,
#   388,
#   61,
#   14,
#   75,
#   22,
#   3,
#   831],
#  [48,
#   16,
#   29,
#   351,
#   151,
#   37,
#   15,
#   12,
#   316,
#   60,
#   59,
#   30,
#   270,
#   300,
#   250,
#   60,
#   48,
#   562,
#   42,
#   1262,
#   13,
#   968,
#   2841,
#   694,
#   156,
#   199,
#   408,
#   14,
#   2718,
#   16,
#   128],
#  [2, 23, 96, 85, 1541, 45, 9, 7, 1030, 203, 14, 750, 6, 75, 26, 181],
#  [109,
#   194,
#   155,
#   13,
#   2,
#   42,
#   541,
#   5,
#   2,
#   276,
#   112,
#   231,
#   60,
#   588,
#   10,
#   94,
#   516,
#   33],
#  [823,
#   208,
#   266,
#   103,
#   169,
#   1887,
#   18,
#   237,
#   46,
#   266,
#   62,
#   66,
#   22,
#   3114,
#   31,
#   77,
#   1098,
#   263,
#   697,
#   266,
#   19,
#   3,
#   204,
#   39,
#   3,
#   279,
#   10,
#   95,
#   112,
#   425,
#   289,
#   5],
#  [6,
#   26,
#   42,
#   670,
#   8,
#   2,
#   11,
#   68,
#   126,
#   163,
#   4,
#   47,
#   3,
#   730,
#   107,
#   8,
#   13,
#   82,
#   20,
#   39],
#  [16,
#   131,
#   5,
#   321,
#   798,
#   541,
#   124,
#   3535,
#   2719,
#   13,
#   554,
#   220,
#   745,
#   144,
#   416,
#   435,
#   86,
#   7048,
#   269,
#   121,
#   83,
#   16,
#   220,
#   2,
#   39,
#   44,
#   204,
#   797,
#   435,
#   402,
#   4,
#   31,
#   312,
#   22,
#   80,
#   26,
#   248,
#   1483,
#   69,
#   510,
#   1888,
#   219,
#   7049],
#  [19, 102, 32, 195, 1, 102, 23, 66, 68, 328],
#  [17,
#   1,
#   8,
#   967,
#   8,
#   29,
#   106,
#   12,
#   1201,
#   10,
#   1,
#   1918,
#   679,
#   419,
#   84,
#   460,
#   94,
#   219,
#   103],
#  [1,
#   1358,
#   133,
#   92,
#   429,
#   81,
#   370,
#   52,
#   105,
#   28,
# ...
#   60,
#   47,
#   1100,
#   302,
#   1308,
#   1438,
#   51,
#   616,
#   15,
#   185,
#   115,
#   301,
#   329,
#   61,
#   12,
#   201,
#   1,
#   62,
#   3,
#   43,
#   70,
#   60,
#   41,
#   131,
#   36,
#   48,
#   315,
#   54],
#  [35,
#   266,
#   398,
#   115,
#   11,
#   95,
#   289,
#   266,
#   984,
#   121,
#   117,
#   28,
#   308,
#   190,
#   308,
#   235,
#   136,
#   29,
#   740,
#   3581,
#   2398,
#   23,
#   17,
#   4,
#   15,
#   706,
#   270,
#   3,
#   146,
#   88,
#   131,
#   319,
#   10,
#   261,
#   297],
#  [82,
#   740,
#   266,
#   326,
#   8,
#   29,
#   46,
#   671,
#   266,
#   281,
#   11,
#   1040,
#   11,
#   208,
#   13,
#   140,
#   444,
#   114,
#   336,
#   4254,
#   154,
#   245,
#   10,
#   5,
#   5,
#   266],
#  [732, 76, 4, 59, 17, 2, 11, 24, 16, 50, 51, 101, 450, 30, 588, 250, 160],
#  [56,
#   181,
#   58,
#   371,
#   2,
#   11,
#   589,
#   7181,
#   45,
#   206,
#   273,
#   1145,
#   45,
#   162,
#   4,
#   668,
#   57,
#   175,
#   497,
#   101,
#   238,
#   56,
#   1621,
#   99,
#   44,
#   1053,
#   3166,
#   69,
#   227,
#   41],
#  [133,
#   58,
#   740,
#   8,
#   336,
#   115,
#   5,
#   19,
#   362,
#   26,
#   35,
#   8,
#   29,
#   2,
#   11,
#   99,
#   56,
#   15,
#   203,
#   15,
#   148,
#   53,
#   21,
#   2,
#   5],
#  [5,
#   55,
#   80,
#   1054,
#   312,
#   22,
#   172,
#   10,
#   83,
#   152,
#   37,
#   179,
#   33,
#   30,
#   204,
#   62,
#   30,
#   4255,
#   200,
#   3,
#   268,
#   41,
#   307,
#   344,
#   1004,
#   160,
#   101,
#   716,
#   1170,
#   1402,
#   81,
#   1590],
#  [761,
#   42,
#   41,
#   124,
#   2,
#   11,
#   73,
#   700,
#   12,
#   59,
#   1314,
#   720,
#   81,
#   52,
#   207,
#   209,
#   516,
#   409,
#   97,
#   175,
#   1074,
#   157,
#   320,
#   38,
#   2292,
#   52,
#   2326,
#   437,
#   495,
#   1104,
#   2755,
#   877,
#   260,
#   165,
#   216,
#   4,
#   271,
#   224,
#   179,
#   15,
#   405,
#   1524,
#   45,
#   207,
#   1137],
#  [5, 6, 8, 129, 16, 50, 22, 212, 172, 362, 39, 204, 261, 3, 21, 67],
#  [48,
#   3,
#   586,
#   3829,
#   37,
#   33,
#   302,
#   779,
#   746,
#   45,
#   94,
#   66,
#   63,
#   184,
#   273,
#   65,
#   1329,
#   375,
#   453,
#   290,
#   3167,
#   98,
#   79,
#   5611,
#   1327,
#   2195,
#   101,
#   8,
#   9,
#   405,
#   7,
#   109,
#   433,
#   472,
#   6,
#   184,
#   9,
#   7,
#   658,
#   23,
#   3,
#   3554,
#   1146,
#   8,
#   48,
#   3,
#   51,
#   536],
#  [16,
#   3,
#   117,
#   187,
#   266,
#   284,
#   1351,
#   42,
#   190,
#   308,
#   7182,
#   210,
#   4772,
#   1424,
#   7183,
#   2079,
#   64,
#   10,
#   2458,
#   9,
#   55,
#   388,
#   869,
#   73,
#   266,
#   22,
#   362,
#   2327,
#   39,
#   723,
#   87,
#   10,
#   1272,
#   141,
#   2064,
#   1795,
#   10,
#   289,
#   2534,
#   2196,
#   922,
#   2604,
#   2551,
#   2746,
#   1406,
#   5612,
#   876,
#   2756,
#   40,
#   360],
#  [131, 5, 57, 251, 302, 14, 279, 206, 7, 261, 35],
#  [1386,
#   18,
#   85,
#   1001,
#   1780,
#   466,
#   219,
#   623,
#   35,
#   266,
#   798,
#   139,
#   3342,
#   68,
#   362,
#   212,
#   3007,
#   3,
#   378,
#   10,
#   2310,
#   329,
#   1158,
#   5,
#   28,
#   190,
#   74,
#   1405,
#   92,
#   325,
#   140],
#  [2328, 158, 267, 8],
#  [1,
#   29,
#   2,
#   3343,
#   1403,
#   2138,
#   1,
#   92,
#   1371,
#   2399,
#   120,
#   230,
#   14,
#   486,
#   2478,
#   7184,
#   120,
#   58,
#   338,
#   389,
#   1270,
#   78,
#   208],
#  [175, 29, 544, 133, 8, 9, 11, 1352, 8, 29, 5613, 66, 172, 1424, 3, 522],
#  [369, 127, 31, 9, 369, 1122],
#  [157,
#   583,
#   403,
#   909,
#   211,
#   38,
#   3,
#   73,
#   2,
#   59,
#   2021,
#   65,
#   45,
#   1435,
#   132,
#   23,
#   3344,
#   7185,
#   3818,
#   66,
#   2,
#   429,
#   59,
#   10,
#   2,
#   861,
#   64,
#   200,
#   51,
#   68,
#   4,
#   966,
#   52,
#   673,
#   54,
#   72],
#  [1,
#   67,
#   613,
#   145,
#   1171,
#   991,
#   129,
#   502,
#   315,
#   54,
#   50,
#   63,
#   550,
#   738,
#   343,
#   230,
#   50,
#   198,
#   395,
#   867,
#   152,
#   279,
#   534,
#   617,
#   785,
#   50,
#   63,
#   1180,
#   37,
#   18,
#   33,
#   12,
#   148,
#   862],
#  [919, 1530, 8],
#  [266,
#   19,
#   95,
#   289,
#   646,
#   266,
#   907,
#   212,
#   1683,
#   343,
#   12,
#   155,
#   212,
#   87,
#   1683,
#   343,
#   600,
#   297,
#   163,
#   731,
#   1186,
#   31,
#   22,
#   176,
#   1973,
#   1098,
#   118,
#   1172,
#   40,
#   218],
#  [56,
#   1,
#   58,
#   338,
#   415,
#   78,
#   1,
#   92,
#   312,
#   21,
#   16,
#   1428,
#   45,
#   25,
#   66,
#   27,
#   22,
#   14,
#   605,
#   2869,
#   450,
#   30,
#   989,
#   69,
#   152,
#   254,
#   242,
#   384,
#   10,
#   454,
#   427,
#   122,
#   53,
#   227,
#   30,
#   209,
#   114,
#   1293,
#   81,
#   128,
#   1],
#  [61,
#   812,
#   106,
#   90,
#   75,
#   22,
#   2164,
#   35,
#   8,
#   50,
#   288,
#   169,
#   944,
#   999,
#   345,
#   118,
#   799,
#   19,
#   225,
#   38,
#   7186,
#   223,
#   1974,
#   53,
#   15,
#   52,
#   35,
#   30,
#   204,
#   246,
#   53,
#   2,
#   19],
#  [8,
#   1,
#   34,
#   412,
#   393,
#   106,
#   1291,
#   254,
#   198,
#   530,
#   285,
#   395,
#   2077,
#   11,
#   1,
#   40,
#   3,
#   3150],
#  [741,
#   4773,
#   1656,
#   487,
#   3851,
#   531,
#   530,
#   190,
#   46,
#   11,
#   1775,
#   137,
#   7187,
#   1317,
#   11,
#   1096,
#   297,
#   212,
#   3852,
#   1486,
#   12,
#   81,
#   326,
#   44,
#   1383,
#   1656,
#   487,
#   1,
#   1124,
#   2534,
#   1727,
#   622,
#   609,
#   2479,
#   362,
#   212],
#  [224,
#   211,
#   12,
#   321,
#   343,
#   60,
#   339,
#   87,
#   35,
#   1,
#   5,
#   20,
#   174,
#   36,
#   502,
#   2,
#   129,
#   1142,
#   362,
#   22,
#   14,
#   2648,
#   4774,
#   7188,
#   7189,
#   7190,
#   570,
#   97,
#   5599,
#   688,
#   148,
#   325,
#   1109,
#   2,
#   1796,
#   239],
#  [741,
#   35,
#   266,
#   112,
#   28,
#   190,
#   8,
#   282,
#   4,
#   78,
#   945,
#   865,
#   364,
#   1198,
#   111,
#   3,
#   237,
#   35,
#   266,
#   22,
#   1656,
#   487,
#   190,
#   8,
#   530,
#   2458,
#   9,
#   1358,
#   74,
#   368,
#   2757,
#   8,
#   2,
#   529,
#   2649,
#   2758,
#   423,
#   256,
#   21,
#   1343,
#   256,
#   524,
#   786,
#   117,
#   2139,
#   45,
#   1185,
#   266,
#   2758,
#   502],
#  [35,
#   1,
#   128,
#   1410,
#   25,
#   1930,
#   96,
#   254,
#   19,
#   317,
#   200,
#   419,
#   81,
#   785,
#   160,
#   230,
#   212,
#   1,
#   1258,
#   21,
#   61,
#   112,
#   4256,
#   194,
#   3804,
#   244,
#   178,
#   59,
#   10,
#   4,
#   1193,
#   1,
#   851,
#   15,
#   1,
#   268,
#   49,
#   1181,
#   274,
#   30,
#   936,
#   200,
#   10,
#   43,
#   576,
#   20,
#   830],
#  [26, 25, 105, 8, 22, 32],
#  [171,
#   328,
#   523,
#   198,
#   29,
#   244,
#   14,
#   22,
#   512,
#   1553,
#   740,
#   8,
#   315,
#   1788,
#   513,
#   465,
#   62,
#   246,
#   47,
#   64,
#   616,
#   15,
#   5,
#   36,
#   244,
#   185,
#   3,
#   4257,
#   2,
#   216,
#   4,
#   26],
#  [16, 7, 38, 168, 4, 12, 316, 65, 183, 317, 1975, 2, 5614],
#  [102,
#   219,
#   224,
#   1286,
#   130,
#   87,
#   10,
#   7,
#   63,
#   35,
#   188,
#   2,
#   80,
#   266,
#   277,
#   5,
#   240,
#   470,
#   9,
#   293,
#   241,
#   100,
#   102,
#   105,
#   190,
#   34,
#   28,
#   740,
#   167,
#   10,
#   485,
#   33,
#   19],
#  [17,
#   266,
#   275,
#   8,
#   207,
#   4775,
#   8,
#   7191,
#   408,
#   368,
#   74,
#   1728,
#   11,
#   2324,
#   149,
#   1115,
#   2,
#   9,
#   78,
#   79,
#   728,
#   266,
#   834,
#   1051,
#   1620,
#   470,
#   834,
#   1051,
#   1620,
#   1656,
#   487,
#   130,
#   166,
#   183,
#   34,
#   1203,
#   1656,
#   487,
#   7192,
#   102,
#   634,
#   7193,
#   20,
#   1082,
#   161,
#   487,
#   130],
#  [2329,
#   163,
#   3851,
#   3,
#   266,
#   3,
#   210,
#   303,
#   319,
#   10,
#   7194,
#   419,
#   4776,
#   101,
#   12,
#   3008,
#   1656,
#   487,
#   3,
#   324,
#   101,
#   362,
#   212,
#   87,
#   1434,
#   922,
#   4258,
#   138,
#   4259,
#   114,
#   419,
#   718,
#   297,
#   12,
#   39,
#   3008,
#   81,
#   1,
#   57,
#   40,
#   5615,
#   298,
#   788,
#   82,
#   275,
#   133,
#   78,
#   112],
#  [268,
#   38,
#   385,
#   354,
#   152,
#   63,
#   41,
#   38,
#   1406,
#   7195,
#   777,
#   60,
#   1009,
#   2,
#   36,
#   19,
#   5,
#   5,
#   5],
#  [16,
#   7,
#   3582,
#   318,
#   83,
#   142,
#   1833,
#   52,
#   195,
#   9,
#   255,
#   109,
#   83,
#   1250,
#   61,
#   259,
#   206,
#   74,
#   308,
#   4777,
#   413,
#   190,
#   405,
#   7,
#   822,
#   13,
#   14,
#   142,
#   7,
#   916,
#   6,
#   237,
#   68,
#   24,
#   3,
#   54,
#   5616,
#   5617,
#   526,
#   83,
#   3583,
#   1061,
#   103,
#   580,
#   175,
#   889],
#  [25,
#   35,
#   1,
#   46,
#   31,
#   271,
#   63,
#   705,
#   107,
#   1898,
#   98,
#   54,
#   9,
#   2870,
#   49,
#   13,
#   117,
#   762,
#   620,
#   785,
#   250,
#   780],
#  [17,
#   401,
#   8,
#   78,
#   341,
#   41,
#   17,
#   47,
#   122,
#   253,
#   3,
#   21,
#   266,
#   65,
#   62,
#   628,
#   509,
#   49,
#   12,
#   323,
#   417,
#   67,
#   266,
#   13,
#   3,
#   97,
#   63,
#   4,
#   15,
#   27,
#   266,
#   3],
#  [169,
#   944,
#   999,
#   696,
#   408,
#   212,
#   362,
#   26,
#   4,
#   379,
#   409,
#   12,
#   155,
#   64,
#   118,
#   15,
#   79,
#   1153,
#   10,
#   482,
#   5,
#   2078],
#  [224,
#   211,
#   120,
#   91,
#   4778,
#   52,
#   227,
#   487,
#   35,
#   266,
#   157,
#   642,
#   224,
#   72,
#   350,
#   1493,
#   211,
#   211,
#   5618,
#   266,
#   901,
#   3,
#   142,
#   3,
#   261,
#   19,
#   494,
#   110,
#   14,
#   19,
#   183,
#   8,
#   128,
#   338,
#   534,
#   8,
#   105,
#   190,
#   126,
#   35,
#   266,
#   501,
#   322,
#   183,
#   387,
#   19,
#   12,
#   164,
#   4779],
#  [56,
#   35,
#   58,
#   446,
#   17,
#   4,
#   42,
#   41,
#   15,
#   746,
#   2330,
#   2180,
#   399,
#   121,
#   920,
#   312,
#   574,
#   2,
#   423,
#   87,
#   297,
#   3,
#   33,
#   204,
#   487,
#   2164,
#   1246,
#   1976,
#   1593,
#   60,
#   139,
#   224,
#   91,
#   10,
#   394,
#   1323,
#   5619,
#   1313,
#   3345,
#   486,
#   1500,
#   241,
#   336,
#   35,
#   266,
#   66,
#   47,
#   166,
#   487,
#   200,
#   3,
#   648,
#   2080],
#  [75, 22, 25, 37, 18, 33, 362],
#  [10,
#   470,
#   2081,
#   3584,
#   2650,
#   358,
#   448,
#   1424,
#   281,
#   362,
#   110,
#   2558,
#   243,
#   5,
#   35,
#   266,
#   20],
#  [2861, 75, 22, 5],
#  [5,
#   138,
#   45,
#   7196,
#   1170,
#   685,
#   2,
#   167,
#   10,
#   403,
#   246,
#   112,
#   91,
#   1060,
#   125,
#   38,
#   7197,
#   1835,
#   138,
#   868,
#   13,
#   320,
#   808,
#   328,
#   144,
#   1153,
#   138,
#   528,
#   69,
#   918,
#   3156,
#   1756,
#   6,
#   219,
#   224,
#   1286],
#  [27, 38, 181, 88, 65, 45],
#  [12,
#   17,
#   15,
#   7,
#   33,
#   70,
#   34,
#   869,
#   487,
#   22,
#   349,
#   7,
#   395,
#   1378,
#   3,
#   76,
#   740,
#   8,
#   2,
#   7,
#   519,
#   114,
#   24,
#   155,
#   185,
#   208,
#   41,
#   53,
#   24,
#   730,
#   1797],
#  [400,
#   17,
#   47,
#   266,
#   30,
#   440,
#   302,
#   616,
#   4,
#   12,
#   382,
#   4,
#   83,
#   490,
#   25,
#   423,
#   19,
#   2114,
#   289,
#   487,
#   160,
#   212,
#   1683,
#   343],
#  [133,
#   56,
#   245,
#   68,
#   92,
#   341,
#   1318,
#   131,
#   74,
#   1067,
#   803,
#   4,
#   5,
#   266,
#   1316,
#   245,
#   68,
#   120,
#   230,
#   161,
#   3,
#   785,
#   106,
#   26,
#   12,
#   222,
#   42,
#   51,
#   240,
#   103],
#  [1215,
#   136,
#   51,
#   1,
#   46,
#   1170,
#   277,
#   713,
#   127,
#   2,
#   19,
#   3,
#   1085,
#   503,
#   21,
#   16,
#   483,
#   790,
#   133,
#   13,
#   5,
#   165,
#   128,
#   90,
#   81,
#   90,
#   887,
#   617,
#   32,
#   497,
#   192,
#   700,
#   28,
#   65,
#   2847,
#   341,
#   126,
#   970,
#   52,
#   1513,
#   1261,
#   7198,
#   7199,
#   236,
#   7200],
#  [5,
#   35,
#   291,
#   1,
#   112,
#   20,
#   157,
#   1025,
#   365,
#   72,
#   40,
#   129,
#   1142,
#   3009,
#   684,
#   502,
#   61,
#   49,
#   14,
#   22,
#   212,
#   158,
#   1291,
#   254,
#   379,
#   30,
#   468,
#   2460,
#   5620,
#   176,
#   146,
#   4,
#   342,
#   3,
#   451,
#   41,
#   19,
#   36,
#   3853,
#   5621,
#   4780,
#   1015,
#   389,
#   277,
#   1,
#   121],
#  [408, 35, 266, 626, 4, 1259, 740, 190],
#  [772,
#   1959,
#   169,
#   266,
#   3010,
#   5,
#   29,
#   388,
#   42,
#   190,
#   277,
#   12,
#   878,
#   17,
#   53,
#   12,
#   382,
#   270,
#   562,
#   621,
#   35,
#   60,
#   394,
#   2847],
#  [194,
#   155,
#   552,
#   57,
#   284,
#   256,
#   109,
#   31,
#   13,
#   207,
#   7,
#   947,
#   2729,
#   3346,
#   1508,
#   31,
#   2191,
#   1042,
#   396,
#   7,
#   81,
#   57,
#   66,
#   1762,
#   5622,
#   35,
#   7,
#   5623,
#   5624,
#   454,
#   385,
#   728,
#   4260,
#   57,
#   157,
#   385,
#   1025,
#   155,
#   207,
#   16,
#   7,
#   396,
#   75,
#   25,
#   362,
#   212,
#   179],
#  [1,
#   596,
#   178,
#   256,
#   15,
#   6,
#   440,
#   132,
#   284,
#   780,
#   272,
#   21,
#   106,
#   134,
#   185,
#   37,
#   18,
#   15,
#   12,
#   167,
#   203,
#   15,
#   18,
#   276,
#   85,
#   83,
#   15,
#   65,
#   13,
#   905,
#   2140,
#   162,
#   4,
#   5625,
#   229,
#   13,
#   183,
#   18,
#   13,
#   105,
#   115,
#   41,
#   58,
#   70,
#   885,
#   41,
#   4,
#   650,
#   1],
#  [3347,
#   300,
#   161,
#   112,
#   133,
#   2259,
#   491,
#   28,
#   740,
#   29,
#   266,
#   8,
#   128,
#   7,
#   61,
#   1424,
#   54,
#   26,
#   470,
#   118,
#   232,
#   9,
#   7,
#   2999,
#   10,
#   4,
#   28,
#   47,
#   484,
#   15,
#   13,
#   3,
#   137,
#   62,
#   438,
#   43,
#   3,
#   146,
#   68,
#   968,
#   309,
#   517,
#   696,
#   1193,
#   273,
#   591,
#   9,
#   26],
#  [5,
#   281,
#   266,
#   339,
#   467,
#   121,
#   5,
#   4261,
#   22,
#   55,
#   31,
#   40,
#   23,
#   35,
#   5,
#   530,
#   199,
#   40,
#   5626,
#   402,
#   3585,
#   5,
#   418,
#   1460,
#   266,
#   1424,
#   3,
#   486,
#   1424,
#   54,
#   27,
#   470,
#   230,
#   800],
#  [1930,
#   96,
#   261,
#   85,
#   1,
#   277,
#   1249,
#   502,
#   85,
#   3,
#   456,
#   855,
#   6,
#   279,
#   12,
#   99,
#   53,
#   2,
#   89],
#  [303,
#   795,
#   986,
#   29,
#   60,
#   568,
#   139,
#   5,
#   8,
#   37,
#   18,
#   65,
#   648,
#   1128,
#   448,
#   46,
#   492,
#   157,
#   498,
#   345,
#   20,
#   137,
#   463,
#   2480,
#   184,
#   513,
#   3815,
#   345,
#   55,
#   116,
#   406,
#   478,
#   79,
#   203,
#   137,
#   2169,
#   657,
#   20,
#   12,
#   484,
#   266,
#   114,
#   95,
#   990,
#   75,
#   1071,
#   874,
#   3803],
#  [150, 23, 66, 2, 311],
#  [2227,
#   792,
#   3854,
#   370,
#   92,
#   270,
#   1093,
#   623,
#   740,
#   8,
#   2082,
#   4200,
#   7201,
#   4,
#   44,
#   15,
#   62,
#   61,
#   43,
#   307,
#   37,
#   30,
#   33,
#   10,
#   621,
#   210,
#   64,
#   77,
#   389,
#   282,
#   4,
#   46,
#   11,
#   72,
#   128,
#   11,
#   5,
#   5],
#  [5, 266, 11, 95, 110, 28, 190, 8, 9, 332, 109, 11, 52, 208],
#  [28,
#   1676,
#   10,
#   266,
#   49,
#   1729,
#   11,
#   180,
#   223,
#   23,
#   146,
#   749,
#   9,
#   68,
#   4,
#   216,
#   384,
#   81,
#   1096,
#   10,
#   148,
#   33,
#   740,
#   29],
#  [286,
#   27,
#   21,
#   63,
#   80,
#   118,
#   289,
#   292,
#   2,
#   23,
#   323,
#   256,
#   2,
#   23,
#   158,
#   267,
#   213,
#   714,
#   179,
#   2,
#   23,
#   349],
#  [6,
#   169,
#   33,
#   16,
#   43,
#   36,
#   199,
#   98,
#   612,
#   363,
#   123,
#   1088,
#   24,
#   145,
#   2260,
#   363,
#   170,
#   119,
#   260,
#   2141,
#   293,
#   265],
#  [112,
#   124,
#   35,
#   185,
#   204,
#   3586,
#   45,
#   21,
#   470,
#   740,
#   1029,
#   16,
#   2083,
#   4186,
#   669,
#   1594,
#   3011,
#   289,
#   65,
#   2006,
#   518,
#   1164,
#   1635,
#   199,
#   1501,
#   336,
#   3854,
#   537,
#   944,
#   35,
#   19,
#   494,
#   397,
#   910,
#   193,
#   372,
#   4262,
#   2142,
#   2078,
#   28,
#   740,
#   275],
#  [5,
#   35,
#   1075,
#   11,
#   119,
#   807,
#   18,
#   448,
#   127,
#   11,
#   8,
#   472,
#   29,
#   2,
#   23,
#   35,
#   9,
#   204,
#   231,
#   347,
#   73,
#   372,
#   35,
#   3,
#   22,
#   964,
#   9,
#   22,
#   134,
#   35,
#   169,
#   3,
#   22,
#   362,
#   212,
#   11,
#   289,
#   11,
#   125,
#   180,
#   48,
#   38],
#  [5,
#   1,
#   81,
#   112,
#   91,
#   2400,
#   2,
#   23,
#   230,
#   272,
#   30,
#   242,
#   49,
#   13,
#   9,
#   268,
#   327,
#   135,
#   81,
#   289,
#   86,
#   4263,
#   785,
#   332,
#   90,
#   99,
#   15,
#   73],
#  [5,
#   35,
#   102,
#   75,
#   25,
#   212,
#   42,
#   53,
#   41,
#   2,
#   89,
#   36,
#   62,
#   190,
#   8,
#   75,
#   531,
#   19,
#   346,
#   193,
#   10,
#   10,
#   971,
#   3,
#   75,
#   522,
#   773,
#   241,
#   102,
#   346,
#   438],
#  [99,
#   506,
#   113,
#   305,
#   17,
#   4,
#   15,
#   16,
#   409,
#   189,
#   66,
#   426,
#   9,
#   522,
#   14,
#   46,
#   27,
#   7,
#   572,
#   1413,
#   113,
#   305,
#   2559,
#   1555,
#   97,
#   7,
#   916,
#   57,
#   2326],
#  [29,
#   1,
#   132,
#   176,
#   152,
#   690,
#   152,
#   73,
#   4,
#   59,
#   10,
#   675,
#   153,
#   4781,
#   276,
#   93,
#   116,
#   6,
#   238,
#   89,
#   2167,
#   64,
#   40,
#   39,
#   731,
#   764,
#   1,
#   410,
#   314,
#   200,
#   268,
#   1763,
#   1727,
#   582],
#  [82, 35, 107, 8, 37, 33, 53, 71, 177, 423, 113, 317, 85, 276, 11, 46],
#  [28, 1077, 999, 696, 222, 8, 29, 31, 22, 12, 155, 1861, 114, 5],
#  [133,
#   35,
#   65,
#   5627,
#   2058,
#   98,
#   483,
#   398,
#   452,
#   17,
#   4724,
#   4725,
#   1685,
#   5627,
#   149,
#   8,
#   35,
#   2,
#   35,
#   1538,
#   210,
#   2022,
#   12,
#   963,
#   865,
#   4,
#   387,
#   293,
#   17,
#   194,
#   276,
#   70,
#   67,
#   358,
#   448,
#   1099,
#   9,
#   189,
#   116,
#   97,
#   654,
#   62,
#   16,
#   43,
#   64,
#   7202],
#  [355,
#   5,
#   6,
#   35,
#   64,
#   51,
#   17,
#   90,
#   57,
#   431,
#   168,
#   562,
#   920,
#   17,
#   107,
#   595,
#   78,
#   8,
#   51,
#   29,
#   106,
#   107,
#   39,
#   3348,
#   1480,
#   887,
#   50,
#   368,
#   22,
#   669,
#   46,
#   128,
#   964,
#   4222,
#   381,
#   279,
#   11,
#   1252,
#   289,
#   425,
#   337,
#   24,
#   177,
#   7203,
#   83,
#   229],
#  [5,
#   288,
#   651,
#   394,
#   286,
#   195,
#   303,
#   10,
#   74,
#   180,
#   95,
#   75,
#   26,
#   10,
#   1172,
#   1,
#   30,
#   1003,
#   785],
#  [6,
#   240,
#   277,
#   100,
#   134,
#   16,
#   69,
#   546,
#   221,
#   37,
#   33,
#   50,
#   22,
#   29,
#   669,
#   107,
#   28,
#   15,
#   584,
#   43,
#   24,
#   307,
#   555,
#   40],
#  [858,
#   112,
#   626,
#   111,
#   105,
#   35,
#   8,
#   29,
#   433,
#   190,
#   992,
#   3,
#   152,
#   35,
#   434,
#   25,
#   2,
#   7204,
#   4],
#  [11,
#   2,
#   51,
#   451,
#   435,
#   17,
#   59,
#   117,
#   270,
#   135,
#   189,
#   1,
#   2,
#   178,
#   145,
#   88,
#   185,
#   319,
#   4,
#   70,
#   146,
#   1380,
#   88,
#   21,
#   262,
#   457,
#   27,
#   2291,
#   590,
#   458,
#   604,
#   7,
#   80,
#   442,
#   237],
#  [5,
#   6,
#   82,
#   740,
#   8,
#   12,
#   94,
#   1396,
#   107,
#   161,
#   11,
#   143,
#   1899,
#   95,
#   166,
#   6,
#   63,
#   161,
#   627,
#   1764,
#   1715,
#   94,
#   2456,
#   281,
#   43,
#   62,
#   343,
#   12,
#   155,
#   91,
#   227,
#   1171,
#   43,
#   280,
#   556,
#   348,
#   738,
#   343,
#   9,
#   11,
#   2,
#   76,
#   4],
#  [175,
#   5,
#   333,
#   93,
#   25,
#   383,
#   243,
#   260,
#   7,
#   3,
#   1150,
#   206,
#   320,
#   1640,
#   1470,
#   333,
#   12,
#   114,
#   168,
#   171,
#   8,
#   533,
#   346,
#   433,
#   93,
#   551,
#   6,
#   169,
#   126,
#   139],
#  [5,
#   1,
#   299,
#   415,
#   1013,
#   41,
#   122,
#   152,
#   268,
#   2,
#   185,
#   71,
#   6,
#   1009,
#   169,
#   123,
#   5628,
#   40,
#   74,
#   655,
#   751],
#  [42,
#   619,
#   8,
#   175,
#   5,
#   250,
#   41,
#   4,
#   131,
#   30,
#   174,
#   39,
#   148,
#   334,
#   53,
#   30,
#   116,
#   85,
#   94,
#   1453,
#   159,
#   35,
#   97,
#   128],
#  [5, 8, 22, 191, 9, 154, 245, 10, 95],
#  [42,
#   7205,
#   407,
#   8,
#   716,
#   136,
#   12,
#   3,
#   34,
#   81,
#   4264,
#   2324,
#   1038,
#   8,
#   1338,
#   780,
#   35,
#   239,
#   179,
#   409,
#   2,
#   3,
#   152,
#   674],
#  ...]

# %%
print(X[175])
print()
print(X_num_tokens[175])
# Out:
# happy slightly thinner material expecting thatll fine hot summer got navy striped pretty extremely soft wash well wear tank underneath though bc armhole slightly large see part bra
#
# [7, 35, 34, 28, 462, 8, 624, 54, 35, 4707, 119, 87, 21, 156, 626, 171, 1, 498, 185, 186, 1846, 40, 738, 343, 627, 378, 1618, 73, 166, 738, 425, 1084, 553, 170, 18, 30, 952, 283, 8, 68, 243, 12, 4, 33, 2, 73]

# %% [markdown]
# ### Maximum number of tokens for all documents¶

# %%
num_tokens = [len(tokens) for tokens in X_num_tokens]
num_tokens = np.array(num_tokens)
len(num_tokens)
# Out:
# 22641

# %%
num_tokens.mean()
# Out:
# 28.82809946557131

# %%
num_tokens.argmax()
# Out:
# 11957

# %%
num_tokens[11957]
# Out:
# 59

# %% [markdown]
# ### Fixing token counts of all documents (pad_sequences)

# %%
max_tokens = 50
sum(num_tokens < max_tokens) / len(num_tokens)
# Out:
# 0.9620158120224371

# %%
X_pad = pad_sequences(X_num_tokens, maxlen=max_tokens)

# %%
X_pad.shape
# Out:
# (22641, 50)

# %% [markdown]
# ### Train Set Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pad, y, test_size=0.2, stratify=y, random_state=0)

# %% [markdown]
# ### Modeling

# %%
model = Sequential()

# %%
embedding_size = 25

# %%
model.add(Embedding(input_dim=num_words,         # 15000 .Giriş boyutu.input_dim: Eğitim de datamda en fazla geçen ilk 15000 tokeni kullan 
                    output_dim=embedding_size,   # 50    .Çıkış boyutu. embedding_size : Dönüştüreceğim word_embeddingler kaç boyutlu olsun
                    input_length=max_tokens))    # 50    .Dataya girecek olan inputumub uzunluğu. Kendisine verilecek olan her bir yorumların kaç boyutlu olacağı

model.add(Dropout(0.3))                        

model.add(GRU(units=48, return_sequences=True)) 

model.add(Dropout(0.5))

model.add(GRU(units=24, return_sequences=True))
model.add(Dropout(0.5))

model.add(GRU(units=12))

model.add(Dense(1, activation='sigmoid'))

# %%
optimizer = Adam(learning_rate=0.01)

# %%
model.compile(loss='binary_crossentropy', 
              optimizer=optimizer, # optimizer : DL arka planda hangi gradient descent algoritmasını kullansın --> Adam
              metrics=['Recall'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 50, 25)            375000
#
#  dropout (Dropout)           (None, 50, 25)            0
#
#  gru (GRU)                   (None, 50, 48)            10800
#
#  dropout_1 (Dropout)         (None, 50, 48)            0
#
#  gru_1 (GRU)                 (None, 50, 24)            5328
#
#  dropout_2 (Dropout)         (None, 50, 24)            0
#
#  gru_2 (GRU)                 (None, 12)                1368
#
#  dense (Dense)               (None, 1)                 13
#
# =================================================================
# Total params: 392,509
# Trainable params: 392,509
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor="val_recall", mode="max", 
                           verbose=1, patience = 1, restore_best_weights=True)

# %%
from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(class_weight='balanced', y=y_train)
pd.Series(classes_weights).unique()
# Out:
# array([0.61061291, 2.76013411])

# %%
model.fit(X_train, y_train, epochs=10, batch_size=1024, sample_weight= classes_weights,
         validation_data=(X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/10
# 18/18 [==============================] - 12s 329ms/step - loss: 0.5589 - recall: 0.7415 - val_loss: 0.4941 - val_recall: 0.8805
# Epoch 2/10
# 18/18 [==============================] - ETA: 0s - loss: 0.3382 - recall: 0.8824Restoring model weights from the end of the best epoch: 1.
# 18/18 [==============================] - 4s 237ms/step - loss: 0.3382 - recall: 0.8824 - val_loss: 0.3607 - val_recall: 0.8256
# Epoch 2: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.head()
# Out:
#        loss    recall  val_loss  val_recall
# 0  0.558900  0.741542  0.494134    0.880488
# 1  0.338189  0.882353  0.360708    0.825610

# %%
model_loss.plot()

# %%
model.evaluate(X_test, y_test)
# Out:
# 142/142 [==============================] - 3s 18ms/step - loss: 0.4941 - recall: 0.8805
# [0.4941336214542389, 0.8804877996444702]

# %%
model.evaluate(X_train, y_train)
# Out:
# 566/566 [==============================] - 10s 17ms/step - loss: 0.4520 - recall: 0.9183
# [0.4519781172275543, 0.9183175563812256]

# %% [markdown]
# ## BERT Modeling

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, stratify=y, random_state=42)

# %% [markdown]
# ### Tokenization

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 5.2 MB/s
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 31.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 52.0 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %% [markdown]
# ### Transformation text to tensor

# %%
def transformation(X):
  # set array dimensions
  seq_len = 50
  num_samples = len(X)

  # initialize empty zero arrays
  Xids = np.zeros((num_samples, seq_len))
  Xmask = np.zeros((num_samples, seq_len))

    
  for i, phrase in enumerate(X):
      tokens = tokenizer.encode_plus(phrase, max_length=seq_len, truncation=True,
                                      padding='max_length', add_special_tokens=True) 
      
      # assign tokenized outputs to respective rows in numpy arrays
      Xids[i] = tokens['input_ids']
      Xmask[i] = tokens['attention_mask']
  return Xids, Xmask

# %%
Xids_train, Xmask_train = transformation(X_train) 
Xids_test, Xmask_test = transformation(X_test)

# %%
print("Xids_train.shape  :", Xids_train.shape)
print("Xmask_train.shape :", Xmask_train.shape)
print("Xids_test.shape   :", Xids_test.shape)
print("Xmask_test.shape  :", Xmask_test.shape)
# Out:
# Xids_train.shape  : (20376, 50)
# Xmask_train.shape : (20376, 50)
# Xids_test.shape   : (2265, 50)
# Xmask_test.shape  : (2265, 50)

# %%
labels_train = y_train.values.reshape(-1,1)
 # -1: satır sayısı ne ise kendin ayarla, 1: feature/sütun sayısı
labels_train
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
labels_test = y_test.values.reshape(-1,1)
labels_test
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
dataset_train = tf.data.Dataset.from_tensor_slices((Xids_train, Xmask_train, labels_train))
dataset_train
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(50,), dtype=tf.float64, name=None), TensorSpec(shape=(50,), dtype=tf.float64, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))>

# %%
dataset_test = tf.data.Dataset.from_tensor_slices((Xids_test, Xmask_test, labels_test))
dataset_test
# Out:
# <TensorSliceDataset element_spec=(TensorSpec(shape=(50,), dtype=tf.float64, name=None), TensorSpec(shape=(50,), dtype=tf.float64, name=None), TensorSpec(shape=(1,), dtype=tf.int64, name=None))>

# %%
def map_func(Xids, Xmask, labels):
    # we convert our three-item tuple into a two-item tuple where the input item is a dictionary
    return {'input_ids': Xids, 'attention_mask': Xmask}, labels

# %%
dataset_train = dataset_train.map(map_func)
dataset_test = dataset_test.map(map_func)

# %% [markdown]
# ### Batch Size

# %%
batch_size = 32 # 16, 32

# batch_size 
# fit into a batch of 32
train_ds = dataset_train.batch(batch_size) 
val_ds = dataset_test.batch(batch_size)

length = len(X_train)

# %% [markdown]
# ### Creating Model

# %%
def create_model():
    from transformers import TFAutoModel  
    model = TFAutoModel.from_pretrained("bert-base-uncased")
    input_ids = tf.keras.layers.Input(shape=(50,), name='input_ids', dtype='int32')
    attention_mask = tf.keras.layers.Input(shape=(50,), name='attention_mask', dtype='int32')

    embeddings = model.bert(input_ids=input_ids, attention_mask=attention_mask)["pooler_output"]

    x = tf.keras.layers.Dense(50, activation='relu')(embeddings)  
    x = tf.keras.layers.Dropout(0.1, name="dropout")(x)
    y = tf.keras.layers.Dense(1, activation='sigmoid', name='outputs')(x) 

    return tf.keras.Model(inputs=[input_ids, attention_mask], outputs=y)

# %%
strategy = tf.distribute.TPUStrategy(resolver)

# %%
with strategy.scope():
  optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5) #3e-5, 5e-5
  loss = tf.keras.losses.BinaryCrossentropy()
  recall = tf.keras.metrics.Recall()
  model3 = create_model()
  model3.compile(optimizer=optimizer, loss=loss, metrics=[recall])
# Out:
# Downloading:   0%|          | 0.00/536M [00:00<?, ?B/s]
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['mlm___cls', 'nsp___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
model3.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 50)]         0           []
#
#  attention_mask (InputLayer)    [(None, 50)]         0           []
#
#  bert (TFBertMainLayer)         TFBaseModelOutputWi  109482240   ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 50,
#                                 768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  dense_1 (Dense)                (None, 50)           38450       ['bert[0][1]']
#
#  dropout (Dropout)              (None, 50)           0           ['dense_1[0][0]']
#
#  outputs (Dense)                (None, 1)            51          ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 109,520,741
# Trainable params: 109,520,741
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
history = model3.fit(
    train_ds2, validation_data= val_ds, class_weight= {0:1, 1:4},
    epochs=1)
# Out:
# 637/637 [==============================] - 206s 162ms/step - loss: 0.5690 - recall: 0.8431 - val_loss: 0.3179 - val_recall: 0.9098

# %% [markdown]
# ### Model evaluation

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model3.predict(val_ds) >= 0.5


print(classification_report(y_test, y_pred))
# Out:
# 71/71 [==============================] - 12s 92ms/step
#               precision    recall  f1-score   support
#
#            0       0.98      0.84      0.90      1855
#            1       0.55      0.91      0.69       410
#
#     accuracy                           0.85      2265
#    macro avg       0.76      0.87      0.79      2265
# weighted avg       0.90      0.85      0.86      2265

# %%
y_train_pred = model3.predict(train_ds) >= 0.5


print(classification_report(y_train, y_train_pred))

# %%
y_train_pred = model3.predict(train_ds) >= 0.5


print(classification_report(y_train, y_train_pred))
# Out:
# 637/637 [==============================] - 22s 30ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.86      0.92     16685
#            1       0.60      0.96      0.74      3691
#
#     accuracy                           0.88     20376
#    macro avg       0.80      0.91      0.83     20376
# weighted avg       0.92      0.88      0.89     20376

# %%
from sklearn.metrics import PrecisionRecallDisplay

y_pred_proba = model3.predict(val_ds)

PrecisionRecallDisplay.from_predictions(y_test, y_pred_proba)
plt.show();
# Out:
# 71/71 [==============================] - 5s 26ms/step

# %%
y_pred.ravel()
# Out:
# array([False, False, False, ..., False, False, False])

# %%
data = {"review": X_test.values,  "actual": y_test, "pred_1": y_pred.ravel()}
eval_df = pd.DataFrame.from_dict(data)
eval_df
# Out:
#                                                   review  actual  pred_1
# 9045   twice year retailer don true masterpiece sweat...       0   False
# 13217  love dress purchasing pattern fit incredibly f...       0   False
# 16138  love everything dress pattern gorgeous mixture...       0   False
# 14718  saw dress online immediately fell love bow des...       1    True
# 1363   beautiful feminine look run big lb curvy size ...       0   False
# ...                                                  ...     ...     ...
# 4609   romper fit like dream gorgeous unique sexy rat...       1    True
# 17769  size top look big shoulder get normal size don...       0   False
# 12502  soon saw dress online knew wanted immediately ...       0   False
# 2016   pleasantly surprised top looser flowy not bagg...       0   False
# 5605   jacket extremely good quality gorgeous detaili...       0   False
#
# [2265 rows x 3 columns]

# %%
pd.set_option('display.max_colwidth', None)
eval_df[(eval_df["actual"] == 1) & (eval_df["pred_1"] == False)]
# Out:
#                                                                                                                                                                                                                                                                                                                                                       review  \
# 480                                                                                                                                                                                                                                                              nice fabric versatile knit top style accentuates bust probably not issue attention may want
# 22434                                                                                                                                                                             love design top however quality lackluster shirt pretty short would flattering least inch also pretty sheer figuring garment dilemma still wear love look great denim vest
# 16815                                                                                                                                                                                                                                                     ahhh listened previous review indeed top run large style wise would say could much better retailer
# 8920                                                                                                                                       wonderful pencil skirt subtle design pair variety top sweater fabric nice true fitted design however sizing run small long im wait denim skirt tight past knee length like upper calf would way long disappointed
# 10345                                                                                                                                                                                                                      love sweater rich color good quality fabric thick heavy neck opening wide length short flattering not tall not model skinny frame
# 4788   run sooo big normally wear large due limited sizing small medium chose small looked big model style dress seem run large size small ordered couldve fit two people easily together loved pattern color slip underneath actually fit well dont want look like im wearing tent lol also back slightly longer front something couldnt see picture online
# 17468                                                                                            got coral reef color size medium reference say easier explaining really bra place recently lost weight buying small medium anywhere retailer wanted love suit still love fabric color everything medium fit except bra cup not especially big zero cup room
# 13264                                                            waited got sweater winter sale ordered navy medium design pretty said surprised short love detail tie back nice weight not found itchy sweater received store return little wrinkled fuzzy considered hunt perfect navy pullover need wear cami underneath side revealing picture first day
# 6055                                                                                                          really loved vest online decided try store really cute fit nicely purchased normal size took vacation first time wearing color transferred white shirt even though say disappointed considering expensive overall cute may ruin clothes beware
# 16665                                                                                                                                                                                                                                                  normally wear regular even xsp wide really maternity wear also since material thin ivory shear liking
# 9043                                                                                                                                              cute plaid print couldnt resist ordering petite size sold went x based review huge ended returning think x petite may worked sold ill never know boxy may need careful fit work body not color magnificent
# 3863                                                                                                                                                                                                                                                                                                        also dress sleeve tegan tunic love dress dressed
# 22227                                                                                                                                                                                                            tight bust typical size fit le everywhere else material no give unless precise measurement dress hard dress wear color really lovely though
# 18923                                                                                                                                                                                                                                                                                     cute dress akward fit sleeve bit sung rest dress little large size
# 18279                                                                            loved tried fit well flattering size tall bubble butt thicker thigh narrow waist tried little tight bum thigh waist perfect tried much comfortable leg worked waist well thought good wearing not even ten minute started slipping constantly loosed around area especially
# 14877                                                                                                                                                                                                                                          pretty tank embroidered flower pictured slightly see cami would must price show stopper unfortunately average
# 4409                                                                                                                                                                                                                                                                         pretty short age look well made green dress beautiful short comfortable wearing
# 17301                                                                                                                                                                               suit absolutely gorgeous really fit short waisted gal fit perfectly body bust not long enough lift arm size c cup boob not pop sad return size c cup boob ordered medium
# 6712                                                                                                                                                                                                   love look dress love way cut one thing not love thickness material much summer dress felt heavy hot still love brand hopeful great option come summer
# 21297                                                                                                                                                                                                                          love cut way drape size fit great wear hour sudden became practically falling plan wash see shrink wish held shape since cute
# 9750                                                                                                                                                                                   top look great model petite frame body large bust curvy hip top hit wrong place front look cropped frumpy large bust width top boxy top soft comfortable color pretty
# 21776                                                                                                                                                                                                                                                                received love style fall little waist like top longer itll definitely fit shorter torso
# 4977                                                               lovely cardigan especially dress legging sock boot ecstatic get black friday price description say white like cream reason initially reconsidered purchase hoping winter white appears model except looked great dress suitable southern california winter didnt care wrap belt looked li
# 7784                                                                   ill start saying fabric concept beautiful top sheer thats pretty clear image not surprising lightweight white blouse problem arm fitted torso not chest cut fairly wide im usually wear depending relaxed want fit purchased arm workable slightly fitted torso fit like chest expect
# 4100                                                          really like great layering super cute hide traditional holiday year pregnancy weight gain think cute legging boot unfortunately back panel dress not seem vary based size may sound weird ive tried ability reach forward didnt change two size returned hopeful ordered slightly roomier back
# 9271                                                                                                                                      fell love instantly upon looking mirror percent see least black love enough going try put cami underneath however maynt work shirt lovely dont need see shirt also defiantly size larger expected size almost good
# 7038                                                                                                              pant wonderful season yes almost pop dont even last full year loved much bit bullet bought pair started rip spot tried contact ag directly not back product day fortunately retailer wonderful always buy pilcro much better product money
# 18731                                                                                                                                                                  love pattern red motif sizing dress way top fit fine hip area tight standing leg apart way looked normal stood foot together thigh touching ordered usual size reference bra size hip
# 8257                                                                              pant gorgeous first see fit beautifully first put wear one day snag everything little string start come pant hem begin unravel pant beautiful light summer pant appropriate work brunch frumpy worn pant million snag string hanging one day cant begin tell annoyed spent
# 19293                                                                        maybe wrong body type jean even though technically fit felt like looked like mom jean fine high waist actually made comfortable ankle loose long ag ankle jean perfect length quality good though fabric substantial bit stiffer ag color nice saturated black tried size im lb
# 2231                                                                                                                                                    really looking forward sweater not cardigan poncho cant decide odd gorgeously made extremely soft wish actually sleeve havent decided something wear not husband referred batwing depicted one photo
# 15811                                                                                                             love design thats im going back smaller size bought medium size made someone lb heavier usually im good choosing size online not today curvy round like still go smaller size dress lot room also wish clothes would come store try please
# 7829                                         dress absolutely beautiful person blue stripe bit brighter print top muted unique sure turn head tried small petite size usually perfect lengthwise however dress long another complaint style top half model picture seems hiding puffiness top half top half puff made appear much wider not good look anyone
# 12831                                                                                    great color not voluminous lined whig great fall downside huge elastic waist bc itll require belt something look v casual alone even perfect fit give bit muffin bc huge piece elastic ive literally tried two occasion trying convince lol not worth current price
# 22579                                                            flattering thick legging would keep warm fall winter pulled got big hole seam waistband first trip bathroom obviously might expect rip tight fit perfectly even looser side ripped effortlessly pretty embarrassing given price bringing back reference decide try luck normal size perfect
# 4816                                                                                                                                                                                                                                                                             im bough size regular short wear jean see midriff cute pattern im returning
# 20477                                                okay top redeeming quality promise gave star really wanted give two not worth im sure work people quality impeccable people purchase last forever sturdy cotton not thin like many retailer tee material lace detail texture point neckline nice great looking top issue though wasnt bust reviewer hav
#
#        actual  pred_1
# 480         1   False
# 22434       1   False
# 16815       1   False
# 8920        1   False
# 10345       1   False
# 4788        1   False
# 17468       1   False
# 13264       1   False
# 6055        1   False
# 16665       1   False
# 9043        1   False
# 3863        1   False
# 22227       1   False
# 18923       1   False
# 18279       1   False
# 14877       1   False
# 4409        1   False
# 17301       1   False
# 6712        1   False
# 21297       1   False
# 9750        1   False
# 21776       1   False
# 4977        1   False
# 7784        1   False
# 4100        1   False
# 9271        1   False
# 7038        1   False
# 18731       1   False
# 8257        1   False
# 19293       1   False
# 2231        1   False
# 15811       1   False
# 7829        1   False
# 12831       1   False
# 22579       1   False
# 4816        1   False
# 20477       1   False

# %%
pd.DataFrame()

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
